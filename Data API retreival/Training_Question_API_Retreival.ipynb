# %% [markdown]
# # Initial API retreival.
# ### Note: THIS CAN BE USED ONLY FOR TRAINING AND BATCH_1 TEST BECAUSE THEY CONTAIN GOLDEN ANSWERS AND THEREFORE THE STRUCTURE IS DIFFERENT.
# ### FOR BATCH_2, BATCH_3, BATCH_4 USE THE TEST_QUESTION_API_RETREVAL.IPYNB

# %%
from Bio import Entrez
from keybert import KeyBERT
import json
import warnings
warnings.filterwarnings("ignore")
from tqdm import tqdm
import xml.etree.ElementTree as ET
import re
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
import random
import time
from datetime import datetime

# Load spaCy model only once
'''nlp = spacy.load("en_core_web_sm")

INTENT_TERMS = {
    "synonym", "definition", "define", "meaning",
    "cause", "treatment", "therapy",
    "effect", "role", "impact", "mechanism",
    "list"
}

GENERIC_MEDICAL_TERMS = {
    "disease", "disorder", "condition", "syndrome", "illness", "diagnosis"
}'''



data_file_path = "../datasets/test/batch_1/BioASQ-task13bPhaseA-testset1"
base_pid_url = 'http://www.ncbi.nlm.nih.gov/pubmed/' 
Entrez.email = "kasapovic.m@hotmail.com"  # validan email

# %%
def load_question_from_file(file_path):
    """
    Loads the BioASQ-style JSON and extracts the list of questions.
    
    Parameters:
        file_path (str): Path to the JSON file.
    
    Returns:
        List[dict]: A list of question dictionaries.
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        questions = data.get("questions", [])
        print(f"Loaded {len(questions)} questions from {file_path}")
        return questions
    except Exception as e:
        print(f"Failed to load questions: {e}")
        return []

# %%
questions = load_question_from_file(file_path=data_file_path)
questions[0]
# Out:
# ✅ Loaded 85 questions from ../datasets/test/batch_2/BioASQ-task13bPhaseA-testset2
# {'id': '67dedd6818b1e36f2e000061',
#  'type': 'factoid',
#  'body': 'Which ensemble machine-learning framework has been developed harnessing UK biobank data?'}

# %%
def parse_question(questions):
    """
    Parses the questions to extract relevant information.
    
    Parameters:
        questions (List[dict]): A list of question dictionaries.
    
    Returns:
        List[dict]: A list of parsed question dictionaries.
    """
    parsed_questions = []
    for question in questions:
        parsed_questions.append({
            "id": question["id"],
            "body": question["body"],
            "documents": [doc.replace(base_pid_url, '') for doc in question["documents"]],
            "snippets": question["snippets"],
        })
    return parsed_questions

# %%
def get_questions_text(questions):
    """
    Extracts the text of the questions from the parsed questions.
    
    Parameters:
        parsed_questions (List[dict]): A list of parsed question dictionaries.
    
    Returns:
        List[str]: A list of question texts.
    """
    return [{'id': question['id'],
              'body': question["body"]} for question in questions]

def get_ground_truth_documents(questions):
    """
    Extracts the ground truth from the parsed questions.
    
    Parameters:
        parsed_questions (List[dict]): A list of parsed question dictionaries.
    
    Returns:
        List[str]: A list of ground truth texts.
    """
    ground_truth = {}
    for question in questions:
        ground_truth[question['id']] = set(question["documents"])
    return ground_truth

# %%
parsed_questions = parse_question(questions=questions)
#parsed_questions[0:3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 parsed_questions = parse_question(questions=questions)
#       2 #parsed_questions[0:3]
#
# Cell In[20], line 16, in parse_question(questions)
#      11 parsed_questions = []
#      12 for question in questions:
#      13     parsed_questions.append({
#      14         "id": question["id"],
#      15         "body": question["body"],
# ---> 16         "documents": [doc.replace(base_pid_url, '') for doc in question["documents"]],
#      17         "snippets": question["snippets"],
#      18     })
#      19 return parsed_questions
#
# KeyError: 'documents'

# %%
ground_truth_documents = get_ground_truth_documents(questions=parsed_questions)
#ground_truth_documents

# %%
questions_texts = get_questions_text(questions=parsed_questions)

# %%
# compare the length of the questions and the ground truth documents
print(f"Number of questions: {len(questions_texts)}")
print(f"Number of ground truth documents: {len(ground_truth_documents)}")
# Out:
# Number of questions: 85
# Number of ground truth documents: 85

# %%
def save_to_json(data, file_path):
    """
    Saves the data to a JSON file.
    
    Parameters:
        data (any): The data to save.
        file_path (str): Path to the JSON file.
    """
    try:
        with open(file_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=4)
        print(f"Saved data to {file_path}")
    except Exception as e:
        print(f"Failed to save data: {e}")

# %%
save_to_json(data=parsed_questions, file_path="parsed_questions.json")
# Out:
# ✅ Saved data to parsed_questions.json

# %%
def parse_pubmed_abstracts_from_xml(xml_string):
    """
    Parse PubMed XML and extract PMID, title, and abstract.

    Args:
        xml_string (str): XML data as string from Entrez.efetch(..., retmode="xml")

    Returns:
        List[Dict]: List of articles with keys: 'pid', 'title', 'abstract'
    """
    root = ET.fromstring(xml_string)
    articles = []

    for article in root.findall(".//PubmedArticle"):
        pid = article.findtext(".//PMID")
        title = article.findtext(".//ArticleTitle")

        # Handle multiple AbstractText parts (can have labels, e.g. "BACKGROUND", "METHODS", etc.)
        abstract_parts = article.findall(".//Abstract/AbstractText")
        abstract = " ".join([part.text for part in abstract_parts if part.text])

        articles.append({
            "pid": pid,
            "title": title,
            "abstract": abstract
        })

    return articles

# %%
# Generate semantic queries
def generate_queries_BERT(question, model, keyphrase_ngram_range=(1, 3), top_n=7):
    keywords = model.extract_keywords(question, keyphrase_ngram_range=keyphrase_ngram_range, stop_words='english', top_n=top_n)
    return [kw for kw, _ in keywords]

'''
def generate_queries_BERT(question, model=KeyBERT('all-MiniLM-L6-v2'), keyphrase_ngram_range=(1, 3), top_n=7):
    keywords = model.extract_keywords(question, keyphrase_ngram_range=keyphrase_ngram_range, stop_words='english', top_n=top_n)

    cleaned_keywords = []

    for phrase, _ in keywords:
        doc = nlp(phrase)

        # Remove verbs, auxiliaries, stopwords, and short words
        filtered_tokens = [
            token.lemma_.lower()
            for token in doc
            if token.pos_ not in {"VERB", "AUX"}
            and token.lemma_.lower() not in ENGLISH_STOP_WORDS
            and len(token.lemma_) > 2
        ]

        # Reconstruct cleaned phrase
        cleaned_phrase = " ".join(filtered_tokens).strip()

        if cleaned_phrase:  # Only keep non-empty results
            cleaned_keywords.append(cleaned_phrase)

    return list(sorted(set(cleaned_keywords)))  # deduplicate + sort
'''

# Search PubMed for each query
def search_pubmed(query, retmax=500):
    handle = Entrez.esearch(db="pubmed", term=query, retmax=retmax)
    record = Entrez.read(handle)
    handle.close()
    return record["IdList"]

# Fetch details in JSON and decode
def fetch_details(id_list):
    ids = ",".join(id_list)
    handle = Entrez.efetch(db="pubmed", id=ids, rettype="medline", retmode="xml")
    xml_data = handle.read()  
    handle.close()
    records = parse_pubmed_abstracts_from_xml(xml_data)
    return records

# %%
questions = get_questions_text(questions=parsed_questions)
for i in range(len(questions)):
    if questions[i]['id'] == "516c0ebc298dcd4e5100006e":
        print(i)

# %%
import random
import time
import json
import os
import shutil
from datetime import datetime

# 🔧 Parameters
BATCH_SIZE = 5
RESULTS_FILE = "retrieved_articles_sampled.json"
CHECKPOINT_FILE = "checkpoint.json"

# 📌 Load checkpoint if it exists
if os.path.exists(CHECKPOINT_FILE):
    with open(CHECKPOINT_FILE, "r") as f:
        checkpoint = json.load(f)
        start_index = checkpoint.get("last_index", 0) + 1
else:
    start_index = 0

# 🚀 Initialize
questions = get_questions_text(questions=parsed_questions)
kw_model = KeyBERT(model='all-MiniLM-L6-v2')
results = []

# 📝 Resume from saved results file if available
if os.path.exists(RESULTS_FILE):
    try:
        with open(RESULTS_FILE, "r") as f:
            results = json.load(f)["results"]
    except json.JSONDecodeError:
        print("⚡ Warning: Results file is corrupted. Starting with empty results.")
        results = []

# 🔁 Process from start_index
for i in range(start_index, len(questions)):
    question = questions[i]
    qid = question['id']
    print(f"❓[{i+1}/{len(questions)}] Question: {question['body']}")
    
    queries = generate_queries_BERT(question['body'], keyphrase_ngram_range=(1, 10), top_n=20, model=kw_model)
    print(f"🧠 Generated Queries: {queries}")
    
    all_ids = set()
    for q in queries:
        try:
            ids = search_pubmed(q, retmax=20000)
            all_ids.update(ids)
            time.sleep(0.7)
        except Exception as e:
            print(f"⚠️ Failed to search PubMed with query '{q}': {e}")
    
    print(f"✅ Found {len(all_ids)} unique PMIDs for this question.")
    
    ground_truth = ground_truth_documents[qid]
    found_gt = ground_truth.intersection(all_ids)
    print(f"🎯 Found {len(found_gt)} out of {len(ground_truth)} ground truth PMIDs.")
    
    non_gt = list(all_ids - found_gt)
    sampled_random = random.sample(non_gt, min(150, len(non_gt)))
    
    selected_ids = list(found_gt) + sampled_random
    print(f"📦 Fetching details for {len(selected_ids)} PMIDs (GT + Random Sample)")

    try:
        details = fetch_details(selected_ids)
    except Exception as e:
        print(f"❌ Error fetching details: {e}")
        details = []

    results.append({
        "qid": qid,
        "question": question['body'],
        "queries": queries,
        "ground_truth": list(ground_truth),
        "ground_truth_total": len(ground_truth),
        "ground_truth_found": list(found_gt),
        "ground_truth_found_count": len(found_gt),
        "random_sampled_count": len(sampled_random),
        "random_sampled_pmids": sampled_random,
        "selected_pmids": selected_ids,
        "error_rate": {
            "value": len(found_gt) / len(ground_truth) if len(ground_truth) > 0 else 0,
            "details": f"{len(found_gt)} found out of {len(ground_truth)}"
        },
        "details": details
    })

    print(f"✅ Saved result for question \"{question['body']}\"\n")

    # 💾 Save batch and update checkpoint
    if (i + 1) % BATCH_SIZE == 0 or i == len(questions) - 1:
        print(f"📁 Saving batch at question {i+1}...")

        # Save to a temporary file first
        temp_file = RESULTS_FILE + ".tmp"
        with open(temp_file, "w") as f:
            json.dump({"results": results}, f, indent=2)

        # Move temp file to final results file (atomic save)
        shutil.move(temp_file, RESULTS_FILE)

        # Save checkpoint
        with open(CHECKPOINT_FILE, "w") as f:
            json.dump({"last_index": i}, f)

        print(f"✅ Batch saved and checkpoint updated at index {i}\n")
# Out:
# ❓[1/85] Question: Describe RankMHC
# 🧠 Generated Queries: ['rankmhc']
# ✅ Found 1 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 1 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Describe RankMHC"
#
# ❓[2/85] Question: What proportion of colorectal cancer cases are not assignable to any of the consensus molecular subtype (CMS) groups?
# 🧠 Generated Queries: ['proportion colorectal cancer cases assignable consensus molecular subtype cms groups', 'proportion colorectal cancer cases assignable consensus molecular subtype cms', 'proportion colorectal cancer cases assignable consensus molecular subtype', 'colorectal cancer cases assignable consensus molecular subtype cms groups', 'colorectal cancer cases assignable consensus molecular subtype cms', 'colorectal cancer cases assignable consensus molecular subtype', 'proportion colorectal cancer cases assignable consensus molecular', 'proportion colorectal cancer cases assignable consensus', 'cancer cases assignable consensus molecular subtype cms groups', 'proportion colorectal cancer cases assignable', 'colorectal cancer cases assignable consensus molecular', 'cancer cases assignable consensus molecular subtype cms', 'colorectal cancer cases assignable consensus', 'proportion colorectal cancer cases', 'proportion colorectal cancer', 'cancer cases assignable consensus molecular subtype', 'colorectal cancer cases assignable', 'consensus molecular subtype cms groups', 'cancer cases assignable consensus molecular', 'colorectal cancer cases']
# ✅ Found 18117 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What proportion of colorectal cancer cases are not assignable to any of the consensus molecular subtype (CMS) groups?"
#
# ❓[3/85] Question: Please list the short half life Phosphodiesterase 5 inhibitors.
# 🧠 Generated Queries: ['list short half life phosphodiesterase inhibitors', 'short half life phosphodiesterase inhibitors', 'half life phosphodiesterase inhibitors', 'list short half life phosphodiesterase', 'short half life phosphodiesterase', 'half life phosphodiesterase', 'life phosphodiesterase inhibitors', 'phosphodiesterase inhibitors', 'life phosphodiesterase', 'phosphodiesterase', 'inhibitors', 'list short half life', 'short half life', 'half life', 'list short half', 'short half', 'list short', 'half', 'list', 'short']
# ✅ Found 89670 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Please list the short half life Phosphodiesterase 5 inhibitors."
#
# ❓[4/85] Question: Pathophysiology of irritable bowel syndrome (IBS).
# 🧠 Generated Queries: ['pathophysiology irritable bowel syndrome ibs', 'irritable bowel syndrome ibs', 'pathophysiology irritable bowel syndrome', 'irritable bowel syndrome', 'pathophysiology irritable bowel', 'bowel syndrome ibs', 'irritable bowel', 'syndrome ibs', 'bowel syndrome', 'ibs', 'pathophysiology irritable', 'bowel', 'irritable', 'syndrome', 'pathophysiology']
# ✅ Found 60795 unique PMIDs for this question.
# 🎯 Found 6 out of 6 ground truth PMIDs.
# 📦 Fetching details for 156 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Pathophysiology of irritable bowel syndrome (IBS)."
#
# ❓[5/85] Question: What is the role of the receptor tyrosine kinase AXL in malignancy?
# 🧠 Generated Queries: ['role receptor tyrosine kinase axl malignancy', 'receptor tyrosine kinase axl malignancy', 'receptor tyrosine kinase axl', 'role receptor tyrosine kinase axl', 'tyrosine kinase axl malignancy', 'tyrosine kinase axl', 'kinase axl malignancy', 'kinase axl', 'role receptor tyrosine kinase', 'receptor tyrosine kinase', 'tyrosine kinase', 'axl malignancy', 'role receptor tyrosine', 'receptor tyrosine', 'kinase', 'axl', 'role receptor', 'receptor', 'malignancy', 'tyrosine']
# ✅ Found 66666 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the role of the receptor tyrosine kinase AXL in malignancy?"
#
# 📁 Saving batch at question 5...
# ✅ Batch saved and checkpoint updated at index 4
#
# ❓[6/85] Question: Are respiratory measurements correlated with disease severity in Duchenne Muscular Dystrophy?
# 🧠 Generated Queries: ['respiratory measurements correlated disease severity duchenne muscular dystrophy', 'respiratory measurements correlated disease severity duchenne muscular', 'measurements correlated disease severity duchenne muscular dystrophy', 'correlated disease severity duchenne muscular dystrophy', 'measurements correlated disease severity duchenne muscular', 'disease severity duchenne muscular dystrophy', 'correlated disease severity duchenne muscular', 'severity duchenne muscular dystrophy', 'respiratory measurements correlated disease severity duchenne', 'disease severity duchenne muscular', 'duchenne muscular dystrophy', 'measurements correlated disease severity duchenne', 'respiratory measurements correlated disease severity', 'severity duchenne muscular', 'respiratory measurements correlated disease', 'muscular dystrophy', 'correlated disease severity duchenne', 'disease severity duchenne', 'respiratory measurements correlated', 'measurements correlated disease severity']
# ✅ Found 39760 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Are respiratory measurements correlated with disease severity in Duchenne Muscular Dystrophy?"
#
# ❓[7/85] Question: Which disease is caused by heterozygous UCHL1 loss-of-function variants?
# 🧠 Generated Queries: ['disease caused heterozygous uchl1 loss function variants', 'disease caused heterozygous uchl1 loss function', 'caused heterozygous uchl1 loss function variants', 'disease caused heterozygous uchl1 loss', 'disease caused heterozygous uchl1', 'heterozygous uchl1 loss function variants', 'caused heterozygous uchl1 loss function', 'caused heterozygous uchl1 loss', 'caused heterozygous uchl1', 'heterozygous uchl1 loss', 'heterozygous uchl1 loss function', 'heterozygous uchl1', 'uchl1 loss function variants', 'disease caused heterozygous', 'uchl1 loss function', 'caused heterozygous', 'uchl1 loss', 'uchl1', 'disease caused', 'heterozygous']
# ✅ Found 28253 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which disease is caused by heterozygous UCHL1 loss-of-function variants?"
#
# ❓[8/85] Question: What is the most appropriate systemic treatment for conversion therapy in colorectal cancer with potentially resectable liver metastasis?
# 🧠 Generated Queries: ['systemic treatment conversion therapy colorectal cancer potentially resectable liver metastasis', 'appropriate systemic treatment conversion therapy colorectal cancer potentially resectable liver', 'treatment conversion therapy colorectal cancer potentially resectable liver metastasis', 'conversion therapy colorectal cancer potentially resectable liver metastasis', 'systemic treatment conversion therapy colorectal cancer potentially resectable liver', 'treatment conversion therapy colorectal cancer potentially resectable liver', 'appropriate systemic treatment conversion therapy colorectal cancer', 'conversion therapy colorectal cancer potentially resectable liver', 'appropriate systemic treatment conversion therapy colorectal cancer potentially', 'appropriate systemic treatment conversion therapy colorectal cancer potentially resectable', 'systemic treatment conversion therapy colorectal cancer', 'therapy colorectal cancer potentially resectable liver metastasis', 'systemic treatment conversion therapy colorectal cancer potentially resectable', 'systemic treatment conversion therapy colorectal cancer potentially', 'appropriate systemic treatment conversion therapy colorectal', 'treatment conversion therapy colorectal cancer', 'conversion therapy colorectal cancer', 'systemic treatment conversion therapy colorectal', 'treatment conversion therapy colorectal cancer potentially resectable', 'therapy colorectal cancer potentially resectable liver']
# ✅ Found 4301 unique PMIDs for this question.
# 🎯 Found 1 out of 3 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the most appropriate systemic treatment for conversion therapy in colorectal cancer with potentially resectable liver metastasis?"
#
# ❓[9/85] Question: Is age an underlying factor in the eye disease AMD?
# 🧠 Generated Queries: ['age underlying factor eye disease amd', 'age underlying factor eye disease', 'underlying factor eye disease amd', 'factor eye disease amd', 'age underlying factor eye', 'eye disease amd', 'factor eye disease', 'underlying factor eye disease', 'eye disease', 'disease amd', 'age underlying factor', 'underlying factor eye', 'factor eye', 'age underlying', 'amd', 'eye', 'disease', 'age', 'underlying factor', 'factor']
# ✅ Found 92999 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is age an underlying factor in the eye disease AMD?"
#
# ❓[10/85] Question: Vector of zika virus.
# 🧠 Generated Queries: ['vector zika virus', 'zika virus', 'vector zika', 'zika', 'virus', 'vector']
# ✅ Found 30657 unique PMIDs for this question.
# 🎯 Found 5 out of 5 ground truth PMIDs.
# 📦 Fetching details for 155 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Vector of zika virus."
#
# 📁 Saving batch at question 10...
# ✅ Batch saved and checkpoint updated at index 9
#
# ❓[11/85] Question: What are the main transcription factors driving the mesenchymal-like (MES-like) state of glioblastoma multiforme?
# 🧠 Generated Queries: ['transcription factors driving mesenchymal like mes like state glioblastoma multiforme', 'main transcription factors driving mesenchymal like mes like state glioblastoma', 'transcription factors driving mesenchymal like mes like state glioblastoma', 'factors driving mesenchymal like mes like state glioblastoma multiforme', 'factors driving mesenchymal like mes like state glioblastoma', 'driving mesenchymal like mes like state glioblastoma multiforme', 'mesenchymal like mes like state glioblastoma multiforme', 'mes like state glioblastoma multiforme', 'main transcription factors driving mesenchymal like', 'like state glioblastoma multiforme', 'main transcription factors driving mesenchymal', 'state glioblastoma multiforme', 'main transcription factors driving mesenchymal like mes like state', 'driving mesenchymal like mes like state glioblastoma', 'main transcription factors driving mesenchymal like mes', 'mesenchymal like mes like state glioblastoma', 'transcription factors driving mesenchymal like', 'transcription factors driving mesenchymal', 'main transcription factors driving mesenchymal like mes like', 'transcription factors driving mesenchymal like mes like state']
# ✅ Found 12319 unique PMIDs for this question.
# 🎯 Found 2 out of 4 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are the main transcription factors driving the mesenchymal-like (MES-like) state of glioblastoma multiforme?"
#
# ❓[12/85] Question: Which role does AAAGG have in RFC1 repeat expansions?
# 🧠 Generated Queries: ['role does aaagg rfc1 repeat expansions', 'does aaagg rfc1 repeat expansions', 'aaagg rfc1 repeat expansions', 'role does aaagg rfc1 repeat', 'does aaagg rfc1 repeat', 'rfc1 repeat expansions', 'aaagg rfc1 repeat', 'does aaagg rfc1', 'role does aaagg rfc1', 'rfc1 repeat', 'aaagg rfc1', 'rfc1', 'repeat expansions', 'does aaagg', 'role does aaagg', 'expansions', 'aaagg', 'repeat', 'does', 'role does']
# ✅ Found 39071 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which role does AAAGG have in RFC1 repeat expansions?"
#
# ❓[13/85] Question: Does the consensus molecular subtype (CMS) classification for colorectal cancer any use in routine clinical practice?
# 🧠 Generated Queries: ['does consensus molecular subtype cms classification colorectal cancer use', 'does consensus molecular subtype cms classification colorectal cancer use routine', 'consensus molecular subtype cms classification colorectal cancer use routine clinical', 'consensus molecular subtype cms classification colorectal cancer use', 'molecular subtype cms classification colorectal cancer use routine clinical practice', 'consensus molecular subtype cms classification colorectal cancer use routine', 'does consensus molecular subtype cms classification colorectal cancer', 'molecular subtype cms classification colorectal cancer use routine clinical', 'subtype cms classification colorectal cancer use routine clinical practice', 'subtype cms classification colorectal cancer use routine clinical', 'molecular subtype cms classification colorectal cancer use', 'molecular subtype cms classification colorectal cancer use routine', 'consensus molecular subtype cms classification colorectal cancer', 'subtype cms classification colorectal cancer use', 'subtype cms classification colorectal cancer use routine', 'does consensus molecular subtype cms classification colorectal', 'molecular subtype cms classification colorectal cancer', 'subtype cms classification colorectal cancer', 'consensus molecular subtype cms classification colorectal', 'cms classification colorectal cancer use routine clinical practice']
# ✅ Found 148 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 148 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Does the consensus molecular subtype (CMS) classification for colorectal cancer any use in routine clinical practice?"
#
# ❓[14/85] Question: Please list major complications of Clostridum Difficile infection.
# 🧠 Generated Queries: ['list major complications clostridum difficile infection', 'list major complications clostridum difficile', 'major complications clostridum difficile infection', 'major complications clostridum difficile', 'complications clostridum difficile infection', 'list major complications clostridum', 'complications clostridum difficile', 'major complications clostridum', 'complications clostridum', 'clostridum difficile infection', 'clostridum difficile', 'difficile infection', 'clostridum', 'list major complications', 'major complications', 'complications', 'infection', 'difficile', 'list major', 'list']
# ✅ Found 57668 unique PMIDs for this question.
# 🎯 Found 6 out of 6 ground truth PMIDs.
# 📦 Fetching details for 156 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Please list major complications of Clostridum Difficile infection."
#
# ❓[15/85] Question: Symptoms of polycystic ovarian syndrome.
# 🧠 Generated Queries: ['symptoms polycystic ovarian syndrome', 'symptoms polycystic ovarian', 'polycystic ovarian syndrome', 'symptoms polycystic', 'polycystic ovarian', 'ovarian syndrome', 'polycystic', 'ovarian', 'symptoms', 'syndrome']
# ✅ Found 57102 unique PMIDs for this question.
# 🎯 Found 5 out of 5 ground truth PMIDs.
# 📦 Fetching details for 155 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Symptoms of polycystic ovarian syndrome."
#
# 📁 Saving batch at question 15...
# ✅ Batch saved and checkpoint updated at index 14
#
# ❓[16/85] Question: What are the lineage transcription factors of oligodendrocyte progenitor cells (OPCs)?
# 🧠 Generated Queries: ['lineage transcription factors oligodendrocyte progenitor cells opcs', 'transcription factors oligodendrocyte progenitor cells opcs', 'factors oligodendrocyte progenitor cells opcs', 'lineage transcription factors oligodendrocyte progenitor cells', 'transcription factors oligodendrocyte progenitor cells', 'lineage transcription factors oligodendrocyte progenitor', 'oligodendrocyte progenitor cells opcs', 'transcription factors oligodendrocyte progenitor', 'lineage transcription factors oligodendrocyte', 'factors oligodendrocyte progenitor cells', 'transcription factors oligodendrocyte', 'progenitor cells opcs', 'factors oligodendrocyte progenitor', 'oligodendrocyte progenitor cells', 'oligodendrocyte progenitor', 'cells opcs', 'lineage transcription factors', 'factors oligodendrocyte', 'lineage transcription', 'progenitor cells']
# ✅ Found 38069 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are the lineage transcription factors of oligodendrocyte progenitor cells (OPCs)?"
#
# ❓[17/85] Question: Data from which clinical trials have been used to demonstrate use of knowledge graphs for NSCLC survival prediction?
# 🧠 Generated Queries: ['clinical trials used demonstrate use knowledge graphs nsclc survival prediction', 'data clinical trials used demonstrate use knowledge graphs nsclc survival', 'clinical trials used demonstrate use knowledge graphs nsclc survival', 'trials used demonstrate use knowledge graphs nsclc survival prediction', 'data clinical trials used demonstrate use knowledge graphs nsclc', 'trials used demonstrate use knowledge graphs nsclc survival', 'clinical trials used demonstrate use knowledge graphs nsclc', 'used demonstrate use knowledge graphs nsclc survival prediction', 'demonstrate use knowledge graphs nsclc survival prediction', 'use knowledge graphs nsclc survival prediction', 'knowledge graphs nsclc survival prediction', 'use knowledge graphs nsclc survival', 'used demonstrate use knowledge graphs nsclc survival', 'demonstrate use knowledge graphs nsclc survival', 'knowledge graphs nsclc survival', 'graphs nsclc survival prediction', 'data clinical trials used demonstrate use knowledge graphs', 'trials used demonstrate use knowledge graphs nsclc', 'clinical trials used demonstrate use knowledge graphs', 'graphs nsclc survival']
# ✅ Found 79 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 79 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Data from which clinical trials have been used to demonstrate use of knowledge graphs for NSCLC survival prediction?"
#
# ❓[18/85] Question: What are the colorectal surgical options for patients with Familial Polyposis?
# 🧠 Generated Queries: ['colorectal surgical options patients familial polyposis', 'surgical options patients familial polyposis', 'options patients familial polyposis', 'colorectal surgical options patients familial', 'patients familial polyposis', 'familial polyposis', 'colorectal surgical options patients', 'colorectal surgical options', 'surgical options patients familial', 'colorectal surgical', 'polyposis', 'options patients familial', 'surgical options', 'patients familial', 'colorectal', 'surgical options patients', 'familial', 'surgical', 'options patients', 'patients']
# ✅ Found 97568 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are the colorectal surgical options for patients with Familial Polyposis?"
#
# ❓[19/85] Question: Is mucopolysaccharidosis-plus syndrome (MPSPS) a X-linked disease?
# 🧠 Generated Queries: ['mucopolysaccharidosis plus syndrome mpsps linked disease', 'mucopolysaccharidosis plus syndrome mpsps linked', 'mucopolysaccharidosis plus syndrome mpsps', 'mucopolysaccharidosis plus syndrome', 'mucopolysaccharidosis plus', 'mucopolysaccharidosis', 'syndrome mpsps linked disease', 'plus syndrome mpsps linked disease', 'mpsps linked disease', 'syndrome mpsps linked', 'plus syndrome mpsps linked', 'plus syndrome mpsps', 'syndrome mpsps', 'linked disease', 'plus syndrome', 'syndrome', 'mpsps linked', 'disease', 'mpsps', 'plus']
# ✅ Found 56113 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is mucopolysaccharidosis-plus syndrome (MPSPS) a X-linked disease?"
#
# ❓[20/85] Question: Indications of cesarean section.
# 🧠 Generated Queries: ['indications cesarean section', 'indications cesarean', 'cesarean section', 'cesarean', 'indications', 'section']
# ✅ Found 36573 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Indications of cesarean section."
#
# 📁 Saving batch at question 20...
# ✅ Batch saved and checkpoint updated at index 19
#
# ❓[21/85] Question: What are the main transcriptional cell states found in melanoma?
# 🧠 Generated Queries: ['main transcriptional cell states melanoma', 'transcriptional cell states melanoma', 'cell states melanoma', 'main transcriptional cell states', 'transcriptional cell states', 'main transcriptional cell', 'states melanoma', 'transcriptional cell', 'main transcriptional', 'transcriptional', 'cell states', 'melanoma', 'cell', 'states', 'main']
# ✅ Found 92583 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are the main transcriptional cell states found in melanoma?"
#
# ❓[22/85] Question: Which biomedical challenge has been designed to facilitate interaction between biomedical experts and automated question-answering systems in order to promote COVID-19 research?
# 🧠 Generated Queries: ['biomedical experts automated question answering systems order promote covid 19', 'interaction biomedical experts automated question answering systems order promote covid', 'challenge designed facilitate interaction biomedical experts automated question answering systems', 'biomedical challenge designed facilitate interaction biomedical experts automated question answering', 'challenge designed facilitate interaction biomedical experts automated question answering', 'biomedical experts automated question answering systems order promote covid', 'biomedical challenge designed facilitate interaction biomedical experts automated question', 'challenge designed facilitate interaction biomedical experts automated question', 'facilitate interaction biomedical experts automated question answering systems', 'facilitate interaction biomedical experts automated question answering', 'designed facilitate interaction biomedical experts automated question answering systems', 'designed facilitate interaction biomedical experts automated question answering', 'interaction biomedical experts automated question answering systems', 'interaction biomedical experts automated question answering', 'facilitate interaction biomedical experts automated question', 'facilitate interaction biomedical experts automated question answering systems order promote', 'facilitate interaction biomedical experts automated question answering systems order', 'experts automated question answering systems order promote covid 19 research', 'designed facilitate interaction biomedical experts automated question answering systems order', 'interaction biomedical experts automated question answering systems order promote']
# ✅ Found 5 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 5 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which biomedical challenge has been designed to facilitate interaction between biomedical experts and automated question-answering systems in order to promote COVID-19 research?"
#
# ❓[23/85] Question: Why is Trifluridine/Tipiracil more active than other fluorpyrimidines in colorectal cancer patients?
# 🧠 Generated Queries: ['trifluridine tipiracil active fluorpyrimidines colorectal cancer patients', 'trifluridine tipiracil active fluorpyrimidines colorectal cancer', 'trifluridine tipiracil active fluorpyrimidines colorectal', 'tipiracil active fluorpyrimidines colorectal cancer patients', 'trifluridine tipiracil active fluorpyrimidines', 'tipiracil active fluorpyrimidines colorectal cancer', 'tipiracil active fluorpyrimidines colorectal', 'active fluorpyrimidines colorectal cancer patients', 'fluorpyrimidines colorectal cancer patients', 'trifluridine tipiracil active', 'active fluorpyrimidines colorectal cancer', 'active fluorpyrimidines colorectal', 'fluorpyrimidines colorectal cancer', 'tipiracil active fluorpyrimidines', 'fluorpyrimidines colorectal', 'trifluridine tipiracil', 'trifluridine', 'active fluorpyrimidines', 'fluorpyrimidines', 'colorectal cancer patients']
# ✅ Found 39732 unique PMIDs for this question.
# 🎯 Found 1 out of 2 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Why is Trifluridine/Tipiracil more active than other fluorpyrimidines in colorectal cancer patients?"
#
# ❓[24/85] Question: Is the inactivation of the X chromsome linked to cognition?
# 🧠 Generated Queries: ['inactivation chromsome linked cognition', 'chromsome linked cognition', 'inactivation chromsome linked', 'inactivation chromsome', 'chromsome linked', 'chromsome', 'linked cognition', 'cognition', 'inactivation', 'linked']
# ✅ Found 38319 unique PMIDs for this question.
# 🎯 Found 0 out of 3 ground truth PMIDs.
# 📦 Fetching details for 150 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is the inactivation of the X chromsome linked to cognition?"
#
# ❓[25/85] Question: Prevalence of Premenstrual Dysphoric Disorder
# 🧠 Generated Queries: ['prevalence premenstrual dysphoric disorder', 'prevalence premenstrual dysphoric', 'premenstrual dysphoric disorder', 'premenstrual dysphoric', 'prevalence premenstrual', 'premenstrual', 'dysphoric disorder', 'dysphoric', 'disorder', 'prevalence']
# ✅ Found 26981 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Prevalence of Premenstrual Dysphoric Disorder"
#
# 📁 Saving batch at question 25...
# ✅ Batch saved and checkpoint updated at index 24
#
# ❓[26/85] Question: Are transcription factors of the GATA family found in the brain?
# 🧠 Generated Queries: ['transcription factors gata family brain', 'transcription factors gata family', 'transcription factors gata', 'factors gata family brain', 'gata family brain', 'factors gata family', 'factors gata', 'transcription factors', 'gata family', 'gata', 'transcription', 'family brain', 'brain', 'factors', 'family']
# ✅ Found 63629 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Are transcription factors of the GATA family found in the brain?"
#
# ❓[27/85] Question: Is there any role between AGRN and Myasthenia gravis?
# 🧠 Generated Queries: ['agrn myasthenia gravis', 'role agrn myasthenia gravis', 'agrn myasthenia', 'myasthenia gravis', 'role agrn myasthenia', 'agrn', 'role agrn', 'gravis', 'myasthenia', 'role']
# ✅ Found 21015 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is there any role between AGRN and Myasthenia gravis?"
#
# ❓[28/85] Question: Please list the 4 problems that are found in the tetrology of Fallot.
# 🧠 Generated Queries: ['problems tetrology fallot', 'tetrology fallot', 'list problems tetrology fallot', 'problems tetrology', 'fallot', 'list problems tetrology', 'tetrology', 'problems', 'list problems', 'list']
# ✅ Found 39284 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Please list the 4 problems that are found in the tetrology of Fallot."
#
# ❓[29/85] Question: Regarding genetic transmission of bipolar disorder, has any specific gene/mutation been identified?
# 🧠 Generated Queries: ['regarding genetic transmission bipolar disorder specific gene mutation identified', 'genetic transmission bipolar disorder specific gene', 'genetic transmission bipolar disorder specific gene mutation identified', 'genetic transmission bipolar disorder specific', 'regarding genetic transmission bipolar disorder specific gene', 'regarding genetic transmission bipolar disorder specific', 'genetic transmission bipolar disorder specific gene mutation', 'regarding genetic transmission bipolar disorder specific gene mutation', 'regarding genetic transmission bipolar disorder', 'bipolar disorder specific gene mutation identified', 'bipolar disorder specific gene mutation', 'transmission bipolar disorder specific gene mutation identified', 'genetic transmission bipolar disorder', 'transmission bipolar disorder specific gene', 'transmission bipolar disorder specific gene mutation', 'bipolar disorder specific gene', 'genetic transmission bipolar', 'regarding genetic transmission bipolar', 'transmission bipolar disorder specific', 'bipolar disorder specific']
# ✅ Found 10502 unique PMIDs for this question.
# 🎯 Found 1 out of 4 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Regarding genetic transmission of bipolar disorder, has any specific gene/mutation been identified?"
#
# ❓[30/85] Question: How does hypoxia influence the cell states of glioblastoma multiforme (GBM)?
# 🧠 Generated Queries: ['does hypoxia influence cell states glioblastoma multiforme gbm', 'hypoxia influence cell states glioblastoma multiforme gbm', 'does hypoxia influence cell states glioblastoma multiforme', 'hypoxia influence cell states glioblastoma multiforme', 'does hypoxia influence cell states glioblastoma', 'hypoxia influence cell states glioblastoma', 'influence cell states glioblastoma multiforme gbm', 'cell states glioblastoma multiforme gbm', 'states glioblastoma multiforme gbm', 'influence cell states glioblastoma multiforme', 'glioblastoma multiforme gbm', 'influence cell states glioblastoma', 'cell states glioblastoma multiforme', 'does hypoxia influence cell states', 'hypoxia influence cell states', 'hypoxia influence cell', 'cell states glioblastoma', 'does hypoxia influence cell', 'glioblastoma multiforme', 'states glioblastoma multiforme']
# ✅ Found 29785 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "How does hypoxia influence the cell states of glioblastoma multiforme (GBM)?"
#
# 📁 Saving batch at question 30...
# ✅ Batch saved and checkpoint updated at index 29
#
# ❓[31/85] Question: What's the increase in CORE profiles in JASPAR 2024 compared to the previous version?
# 🧠 Generated Queries: ['core profiles jaspar 2024 compared previous version', 'increase core profiles jaspar 2024 compared previous version', 'increase core profiles jaspar 2024 compared previous', 'increase core profiles jaspar 2024 compared', 'core profiles jaspar 2024 compared previous', 'core profiles jaspar 2024 compared', 'increase core profiles jaspar 2024', 'profiles jaspar 2024 compared previous version', 'core profiles jaspar 2024', 'increase core profiles jaspar', 'core profiles jaspar', 'profiles jaspar 2024 compared previous', 'profiles jaspar 2024 compared', 'jaspar 2024 compared previous version', 'jaspar 2024 compared previous', 'profiles jaspar 2024', 'jaspar 2024 compared', 'profiles jaspar', 'core profiles', 'increase core profiles']
# ✅ Found 15430 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What's the increase in CORE profiles in JASPAR 2024 compared to the previous version?"
#
# ❓[32/85] Question: What is the mode of action for baclofen?
# 🧠 Generated Queries: ['mode action baclofen', 'action baclofen', 'baclofen', 'mode action', 'mode', 'action']
# ✅ Found 37552 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the mode of action for baclofen?"
#
# ❓[33/85] Question: Adverse effects of metformin.
# 🧠 Generated Queries: ['adverse effects metformin', 'effects metformin', 'metformin', 'adverse effects', 'effects', 'adverse']
# ✅ Found 40144 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Adverse effects of metformin."
#
# ❓[34/85] Question: What are the main cell states of glioblastoma multiforme (GBM)?
# 🧠 Generated Queries: ['main cell states glioblastoma multiforme gbm', 'cell states glioblastoma multiforme gbm', 'states glioblastoma multiforme gbm', 'main cell states glioblastoma multiforme', 'cell states glioblastoma multiforme', 'glioblastoma multiforme gbm', 'main cell states glioblastoma', 'states glioblastoma multiforme', 'cell states glioblastoma', 'states glioblastoma', 'glioblastoma multiforme', 'glioblastoma', 'main cell states', 'multiforme gbm', 'cell states', 'main cell', 'gbm', 'cell', 'multiforme', 'main']
# ✅ Found 76056 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are the main cell states of glioblastoma multiforme (GBM)?"
#
# ❓[35/85] Question: Is high WEE1 expression linked to PARP inhibition resistance?
# 🧠 Generated Queries: ['high wee1 expression linked parp inhibition resistance', 'wee1 expression linked parp inhibition resistance', 'high wee1 expression linked parp inhibition', 'wee1 expression linked parp inhibition', 'expression linked parp inhibition resistance', 'parp inhibition resistance', 'linked parp inhibition resistance', 'expression linked parp inhibition', 'high wee1 expression linked parp', 'parp inhibition', 'linked parp inhibition', 'wee1 expression linked parp', 'high wee1 expression linked', 'wee1 expression linked', 'wee1 expression', 'high wee1 expression', 'parp', 'inhibition resistance', 'wee1', 'expression linked parp']
# ✅ Found 27761 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is high WEE1 expression linked to PARP inhibition resistance?"
#
# 📁 Saving batch at question 35...
# ✅ Batch saved and checkpoint updated at index 34
#
# ❓[36/85] Question: Please list the surgical treatments for Pilomatrix carcinoma.
# 🧠 Generated Queries: ['list surgical treatments pilomatrix carcinoma', 'surgical treatments pilomatrix carcinoma', 'treatments pilomatrix carcinoma', 'list surgical treatments pilomatrix', 'surgical treatments pilomatrix', 'pilomatrix carcinoma', 'treatments pilomatrix', 'list surgical treatments', 'surgical treatments', 'carcinoma', 'pilomatrix', 'list surgical', 'treatments', 'surgical', 'list']
# ✅ Found 54893 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Please list the surgical treatments for Pilomatrix carcinoma."
#
# ❓[37/85] Question: Vector of dengue infection.
# 🧠 Generated Queries: ['vector dengue infection', 'vector dengue', 'dengue infection', 'dengue', 'infection', 'vector']
# ✅ Found 37487 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Vector of dengue infection."
#
# ❓[38/85] Question: Is there a shift in the cell states of glioblastoma during recurrence?
# 🧠 Generated Queries: ['cell states glioblastoma recurrence', 'shift cell states glioblastoma recurrence', 'states glioblastoma recurrence', 'glioblastoma recurrence', 'shift cell states glioblastoma', 'cell states glioblastoma', 'states glioblastoma', 'glioblastoma', 'shift cell states', 'cell states', 'shift cell', 'recurrence', 'cell', 'shift', 'states']
# ✅ Found 84093 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is there a shift in the cell states of glioblastoma during recurrence?"
#
# ❓[39/85] Question: In which population has it been described an association between the CUBN gene and T2DM genetic susceptibility?
# 🧠 Generated Queries: ['population described association cubn gene t2dm genetic susceptibility', 'cubn gene t2dm genetic susceptibility', 'association cubn gene t2dm genetic susceptibility', 'described association cubn gene t2dm genetic susceptibility', 'population described association cubn gene t2dm genetic', 'population described association cubn gene t2dm', 'association cubn gene t2dm genetic', 'described association cubn gene t2dm genetic', 'cubn gene t2dm genetic', 'described association cubn gene t2dm', 'association cubn gene t2dm', 'cubn gene t2dm', 'gene t2dm genetic susceptibility', 'population described association cubn gene', 't2dm genetic susceptibility', 'gene t2dm genetic', 'association cubn gene', 'described association cubn gene', 't2dm genetic', 'cubn gene']
# ✅ Found 6575 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "In which population has it been described an association between the CUBN gene and T2DM genetic susceptibility?"
#
# ❓[40/85] Question: Can stem cell therapies be used to treat xerostomia
# 🧠 Generated Queries: ['stem cell therapies used treat xerostomia', 'cell therapies used treat xerostomia', 'therapies used treat xerostomia', 'used treat xerostomia', 'treat xerostomia', 'stem cell therapies used treat', 'stem cell therapies used', 'stem cell therapies', 'xerostomia', 'cell therapies used treat', 'stem cell', 'cell therapies used', 'cell therapies', 'therapies used treat', 'therapies used', 'stem', 'therapies', 'cell', 'used treat', 'treat']
# ✅ Found 62076 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Can stem cell therapies be used to treat xerostomia"
#
# 📁 Saving batch at question 40...
# ✅ Batch saved and checkpoint updated at index 39
#
# ❓[41/85] Question: What is the cause of African trypanosomiasis?
# 🧠 Generated Queries: ['cause african trypanosomiasis', 'african trypanosomiasis', 'trypanosomiasis', 'cause african', 'african', 'cause']
# ✅ Found 41577 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the cause of African trypanosomiasis?"
#
# ❓[42/85] Question: What is the consensus binding site of the TEAD transcription factors?
# 🧠 Generated Queries: ['consensus binding site tead transcription factors', 'binding site tead transcription factors', 'consensus binding site tead transcription', 'site tead transcription factors', 'tead transcription factors', 'binding site tead transcription', 'site tead transcription', 'tead transcription', 'transcription factors', 'consensus binding site tead', 'binding site tead', 'transcription', 'site tead', 'tead', 'consensus binding site', 'binding site', 'binding', 'consensus binding', 'factors', 'site']
# ✅ Found 65671 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the consensus binding site of the TEAD transcription factors?"
#
# ❓[43/85] Question: Describe Variant Ranker
# 🧠 Generated Queries: ['variant ranker', 'ranker', 'variant']
# ✅ Found 10223 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Describe Variant Ranker"
#
# ❓[44/85] Question: Is creatinine usually elevated in Drug-induced intestinal neuropathy(DAIN)?
# 🧠 Generated Queries: ['creatinine usually elevated drug induced intestinal neuropathy dain', 'creatinine usually elevated drug induced intestinal neuropathy', 'creatinine usually elevated drug induced intestinal', 'usually elevated drug induced intestinal neuropathy dain', 'elevated drug induced intestinal neuropathy dain', 'drug induced intestinal neuropathy dain', 'creatinine usually elevated drug induced', 'usually elevated drug induced intestinal neuropathy', 'elevated drug induced intestinal neuropathy', 'drug induced intestinal neuropathy', 'creatinine usually elevated drug', 'induced intestinal neuropathy dain', 'intestinal neuropathy dain', 'induced intestinal neuropathy', 'creatinine usually elevated', 'intestinal neuropathy', 'usually elevated drug induced intestinal', 'elevated drug induced intestinal', 'neuropathy dain', 'creatinine']
# ✅ Found 16291 unique PMIDs for this question.
# 🎯 Found 0 out of 2 ground truth PMIDs.
# 📦 Fetching details for 150 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is creatinine usually elevated in Drug-induced intestinal neuropathy(DAIN)?"
#
# ❓[45/85] Question: Are systemic beta lactams considered harmful to the human microbiome?
# 🧠 Generated Queries: ['systemic beta lactams considered harmful human microbiome', 'beta lactams considered harmful human microbiome', 'systemic beta lactams considered harmful human', 'systemic beta lactams considered harmful', 'lactams considered harmful human microbiome', 'beta lactams considered harmful human', 'beta lactams considered harmful', 'systemic beta lactams considered', 'lactams considered harmful human', 'systemic beta lactams', 'lactams considered harmful', 'beta lactams considered', 'considered harmful human microbiome', 'harmful human microbiome', 'beta lactams', 'human microbiome', 'lactams considered', 'microbiome', 'lactams', 'systemic beta']
# ✅ Found 46805 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Are systemic beta lactams considered harmful to the human microbiome?"
#
# 📁 Saving batch at question 45...
# ✅ Batch saved and checkpoint updated at index 44
#
# ❓[46/85] Question: What is the most common EGFR mutation in glioblastoma multiforme?
# 🧠 Generated Queries: ['common egfr mutation glioblastoma multiforme', 'egfr mutation glioblastoma multiforme', 'common egfr mutation glioblastoma', 'egfr mutation glioblastoma', 'mutation glioblastoma multiforme', 'common egfr mutation', 'mutation glioblastoma', 'glioblastoma multiforme', 'egfr mutation', 'glioblastoma', 'common egfr', 'egfr', 'mutation', 'multiforme', 'common']
# ✅ Found 68093 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the most common EGFR mutation in glioblastoma multiforme?"
#
# ❓[47/85] Question: Which cardiovascular events are associated with ALOX12 gene polymorphisms?
# 🧠 Generated Queries: ['cardiovascular events associated alox12 gene polymorphisms', 'cardiovascular events associated alox12 gene', 'events associated alox12 gene polymorphisms', 'cardiovascular events associated alox12', 'associated alox12 gene polymorphisms', 'alox12 gene polymorphisms', 'events associated alox12 gene', 'associated alox12 gene', 'alox12 gene', 'associated alox12', 'cardiovascular events associated', 'events associated alox12', 'gene polymorphisms', 'cardiovascular events', 'cardiovascular', 'alox12', 'polymorphisms', 'gene', 'events associated', 'associated']
# ✅ Found 58822 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which cardiovascular events are associated with ALOX12 gene polymorphisms?"
#
# ❓[48/85] Question: What is DRESS in the context of drug therapy?
# 🧠 Generated Queries: ['dress context drug therapy', 'dress context drug', 'drug therapy', 'context drug therapy', 'context drug', 'dress context', 'drug', 'dress', 'therapy', 'context']
# ✅ Found 56012 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is DRESS in the context of drug therapy?"
#
# ❓[49/85] Question: Adverse effects of statins.
# 🧠 Generated Queries: ['adverse effects statins', 'effects statins', 'statins', 'adverse effects', 'adverse', 'effects']
# ✅ Found 42953 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Adverse effects of statins."
#
# ❓[50/85] Question: Describe oncoEnrichR
# 🧠 Generated Queries: ['oncoenrichr']
# ✅ Found 2 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 2 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Describe oncoEnrichR"
#
# 📁 Saving batch at question 50...
# ✅ Batch saved and checkpoint updated at index 49
#
# ❓[51/85] Question: What are the treatments for endometrioma/endometriosis?
# 🧠 Generated Queries: ['treatments endometrioma endometriosis', 'treatments endometrioma', 'endometrioma endometriosis', 'endometrioma', 'endometriosis', 'treatments']
# ✅ Found 24458 unique PMIDs for this question.
# 🎯 Found 5 out of 5 ground truth PMIDs.
# 📦 Fetching details for 155 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are the treatments for endometrioma/endometriosis?"
#
# ❓[52/85] Question: Association between hypothyroidism and depression.
# 🧠 Generated Queries: ['association hypothyroidism depression', 'hypothyroidism depression', 'hypothyroidism', 'association hypothyroidism', 'depression', 'association']
# ✅ Found 35881 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Association between hypothyroidism and depression."
#
# ❓[53/85] Question: Which computational method exists for prediction of transcriptional condensate-associated genomic regions?
# 🧠 Generated Queries: ['computational method exists prediction transcriptional condensate associated genomic regions', 'prediction transcriptional condensate associated genomic regions', 'method exists prediction transcriptional condensate associated genomic regions', 'computational method exists prediction transcriptional condensate associated genomic', 'prediction transcriptional condensate associated genomic', 'method exists prediction transcriptional condensate associated genomic', 'exists prediction transcriptional condensate associated genomic regions', 'computational method exists prediction transcriptional condensate associated', 'transcriptional condensate associated genomic regions', 'computational method exists prediction transcriptional condensate', 'prediction transcriptional condensate associated', 'exists prediction transcriptional condensate associated genomic', 'transcriptional condensate associated genomic', 'method exists prediction transcriptional condensate associated', 'condensate associated genomic regions', 'prediction transcriptional condensate', 'method exists prediction transcriptional condensate', 'exists prediction transcriptional condensate associated', 'exists prediction transcriptional condensate', 'transcriptional condensate associated']
# ✅ Found 5203 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which computational method exists for prediction of transcriptional condensate-associated genomic regions?"
#
# ❓[54/85] Question: What tissue would be used to derive  Wharton's Jelly Mesenchymal Stem Cells?
# ...
# ✅ Found 21613 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which protein is silencing MIR139 in order to promote AML oncogenesis?"
#
# ❓[63/85] Question: On what part of the body is Fontan Palliation(AKA Fontan proceedure) performed?
# 🧠 Generated Queries: ['body fontan palliation aka fontan proceedure performed', 'body fontan palliation aka fontan proceedure', 'palliation aka fontan proceedure performed', 'body fontan palliation', 'body fontan palliation aka', 'body fontan palliation aka fontan', 'fontan palliation aka fontan proceedure performed', 'palliation aka fontan proceedure', 'palliation aka fontan', 'fontan palliation aka fontan proceedure', 'fontan palliation aka', 'fontan palliation', 'fontan palliation aka fontan', 'body fontan', 'aka fontan proceedure performed', 'fontan proceedure performed', 'fontan proceedure', 'palliation', 'aka fontan proceedure', 'palliation aka']
# ✅ Found 15490 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "On what part of the body is Fontan Palliation(AKA Fontan proceedure) performed?"
#
# ❓[64/85] Question: Is childhood asthma more common in highly polluted areas?
# 🧠 Generated Queries: ['childhood asthma common highly polluted areas', 'childhood asthma common highly polluted', 'asthma common highly polluted areas', 'childhood asthma common highly', 'childhood asthma common', 'asthma common highly polluted', 'childhood asthma', 'asthma common highly', 'asthma common', 'asthma', 'common highly polluted areas', 'highly polluted areas', 'polluted areas', 'common highly polluted', 'highly polluted', 'polluted', 'childhood', 'common highly', 'common', 'areas']
# ✅ Found 96696 unique PMIDs for this question.
# 🎯 Found 5 out of 5 ground truth PMIDs.
# 📦 Fetching details for 155 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is childhood asthma more common in highly polluted areas?"
#
# ❓[65/85] Question: Does nucleosomal DNA have topological memory?
# 🧠 Generated Queries: ['does nucleosomal dna topological memory', 'nucleosomal dna topological memory', 'dna topological memory', 'does nucleosomal dna topological', 'nucleosomal dna topological', 'does nucleosomal dna', 'dna topological', 'does nucleosomal', 'topological memory', 'nucleosomal dna', 'nucleosomal', 'dna', 'topological', 'memory', 'does']
# ✅ Found 47595 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Does nucleosomal DNA have topological memory?"
#
# 📁 Saving batch at question 65...
# ✅ Batch saved and checkpoint updated at index 64
#
# ❓[66/85] Question: What cellular process is Listeriolysin associated with?
# 🧠 Generated Queries: ['cellular process listeriolysin associated', 'cellular process listeriolysin', 'process listeriolysin associated', 'process listeriolysin', 'listeriolysin associated', 'listeriolysin', 'cellular process', 'cellular', 'process', 'associated']
# ✅ Found 34663 unique PMIDs for this question.
# 🎯 Found 5 out of 5 ground truth PMIDs.
# 📦 Fetching details for 155 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What cellular process is Listeriolysin associated with?"
#
# ❓[67/85] Question: Estimated prevalence of postpartum psychosis.
# 🧠 Generated Queries: ['estimated prevalence postpartum psychosis', 'prevalence postpartum psychosis', 'postpartum psychosis', 'prevalence postpartum', 'estimated prevalence postpartum', 'psychosis', 'postpartum', 'estimated prevalence', 'prevalence', 'estimated']
# ✅ Found 55551 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Estimated prevalence of postpartum psychosis."
#
# ❓[68/85] Question: What's the effect of liver RBFOX2?
# 🧠 Generated Queries: ['effect liver rbfox2', 'liver rbfox2', 'effect liver', 'liver', 'rbfox2', 'effect']
# ✅ Found 24968 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What's the effect of liver RBFOX2?"
#
# ❓[69/85] Question: Is Geographic Atrophy(GA) found in the hand or foot?
# 🧠 Generated Queries: ['geographic atrophy ga hand foot', 'geographic atrophy ga hand', 'atrophy ga hand foot', 'atrophy ga hand', 'geographic atrophy ga', 'geographic atrophy', 'atrophy ga', 'ga hand foot', 'atrophy', 'hand foot', 'ga hand', 'foot', 'geographic', 'hand', 'ga']
# ✅ Found 60804 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is Geographic Atrophy(GA) found in the hand or foot?"
#
# ❓[70/85] Question: Manifestations of herpes genital infection.
# 🧠 Generated Queries: ['manifestations herpes genital infection', 'manifestations herpes genital', 'herpes genital infection', 'manifestations herpes', 'herpes genital', 'herpes', 'genital infection', 'infection', 'genital', 'manifestations']
# ✅ Found 55766 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Manifestations of herpes genital infection."
#
# 📁 Saving batch at question 70...
# ✅ Batch saved and checkpoint updated at index 69
#
# ❓[71/85] Question: What is caused by heterozygous loss of function SPTAN1?
# 🧠 Generated Queries: ['caused heterozygous loss function sptan1', 'heterozygous loss function sptan1', 'caused heterozygous loss function', 'caused heterozygous loss', 'heterozygous loss', 'loss function sptan1', 'function sptan1', 'heterozygous loss function', 'caused heterozygous', 'sptan1', 'heterozygous', 'loss function', 'caused', 'function', 'loss']
# ✅ Found 51697 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is caused by heterozygous loss of function SPTAN1?"
#
# ❓[72/85] Question: Whats is the effect of berberine in ischemic stroke?
# 🧠 Generated Queries: ['whats effect berberine ischemic stroke', 'effect berberine ischemic stroke', 'berberine ischemic stroke', 'whats effect berberine ischemic', 'effect berberine ischemic', 'berberine ischemic', 'whats effect berberine', 'effect berberine', 'berberine', 'ischemic stroke', 'stroke', 'ischemic', 'whats effect', 'effect', 'whats']
# ✅ Found 53045 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Whats is the effect of berberine in ischemic stroke?"
#
# ❓[73/85] Question: Association between eating disorders and ADHD.
# 🧠 Generated Queries: ['association eating disorders adhd', 'eating disorders adhd', 'disorders adhd', 'association eating disorders', 'eating disorders', 'adhd', 'disorders', 'association eating', 'eating', 'association']
# ✅ Found 51969 unique PMIDs for this question.
# 🎯 Found 6 out of 6 ground truth PMIDs.
# 📦 Fetching details for 156 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Association between eating disorders and ADHD."
#
# ❓[74/85] Question: What is the association of ORM1 and cell-free DNA?
# 🧠 Generated Queries: ['association orm1 cell free dna', 'orm1 cell free dna', 'association orm1 cell free', 'association orm1 cell', 'orm1 cell free', 'orm1 cell', 'cell free dna', 'free dna', 'association orm1', 'dna', 'orm1', 'cell free', 'cell', 'association', 'free']
# ✅ Found 59884 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the association of ORM1 and cell-free DNA?"
#
# ❓[75/85] Question: Are ameleographics (AKA tooth prints) useful for forensic identification?
# 🧠 Generated Queries: ['ameleographics aka tooth prints useful forensic', 'ameleographics aka tooth prints useful forensic identification', 'ameleographics aka tooth prints useful', 'ameleographics aka tooth prints', 'aka tooth prints useful forensic', 'aka tooth prints useful forensic identification', 'tooth prints useful forensic', 'ameleographics aka tooth', 'tooth prints useful forensic identification', 'tooth prints useful', 'aka tooth prints useful', 'prints useful forensic identification', 'ameleographics', 'ameleographics aka', 'prints useful forensic', 'useful forensic identification', 'useful forensic', 'tooth prints', 'aka tooth prints', 'forensic identification']
# ✅ Found 26025 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Are ameleographics (AKA tooth prints) useful for forensic identification?"
#
# 📁 Saving batch at question 75...
# ✅ Batch saved and checkpoint updated at index 74
#
# ❓[76/85] Question: Characteristics of prion diseases.
# 🧠 Generated Queries: ['characteristics prion diseases', 'prion diseases', 'characteristics prion', 'prion', 'diseases', 'characteristics']
# ✅ Found 33507 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Characteristics of prion diseases."
#
# ❓[77/85] Question: Which gene shapes the 3D enhancer network of the developing T cell genome?
# 🧠 Generated Queries: ['gene shapes 3d enhancer network developing cell genome', 'shapes 3d enhancer network developing cell genome', '3d enhancer network developing cell genome', 'gene shapes 3d enhancer network developing cell', 'enhancer network developing cell genome', 'gene shapes 3d enhancer network developing', 'gene shapes 3d enhancer network', 'gene shapes 3d enhancer', 'shapes 3d enhancer network developing cell', '3d enhancer network developing cell', 'enhancer network developing cell', 'gene shapes 3d', 'network developing cell genome', 'developing cell genome', 'shapes 3d enhancer network', '3d enhancer network', 'gene shapes', 'cell genome', 'shapes 3d enhancer network developing', '3d enhancer network developing']
# ✅ Found 48714 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which gene shapes the 3D enhancer network of the developing T cell genome?"
#
# ❓[78/85] Question: How is a  neoantigen created?
# 🧠 Generated Queries: ['neoantigen created', 'neoantigen', 'created']
# ✅ Found 15409 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "How is a  neoantigen created?"
#
# ❓[79/85] Question: Causes of sudden deafness.
# 🧠 Generated Queries: ['causes sudden deafness', 'sudden deafness', 'deafness', 'causes sudden', 'causes', 'sudden']
# ✅ Found 39666 unique PMIDs for this question.
# 🎯 Found 6 out of 6 ground truth PMIDs.
# 📦 Fetching details for 156 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Causes of sudden deafness."
#
# ❓[80/85] Question: Which types of data does the EURO-NMD registry capture?
# 🧠 Generated Queries: ['data does euro nmd registry capture', 'data does euro nmd registry', 'types data does euro nmd registry capture', 'types data does euro nmd registry', 'does euro nmd registry capture', 'does euro nmd registry', 'euro nmd registry capture', 'euro nmd registry', 'data does euro nmd', 'types data does euro nmd', 'does euro nmd', 'nmd registry capture', 'nmd registry', 'data does euro', 'euro nmd', 'types data does euro', 'nmd', 'registry capture', 'does euro', 'data']
# ✅ Found 35097 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which types of data does the EURO-NMD registry capture?"
#
# 📁 Saving batch at question 80...
# ✅ Batch saved and checkpoint updated at index 79
#
# ❓[81/85] Question: What tissue is the origin of adnexal masses.
# 🧠 Generated Queries: ['tissue origin adnexal masses', 'tissue origin adnexal', 'origin adnexal masses', 'adnexal masses', 'tissue origin', 'origin adnexal', 'adnexal', 'tissue', 'masses', 'origin']
# ✅ Found 49746 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What tissue is the origin of adnexal masses."
#
# ❓[82/85] Question: Mean survival after a diagnosis of multiple sclerosis.
# 🧠 Generated Queries: ['mean survival diagnosis multiple sclerosis', 'survival diagnosis multiple sclerosis', 'diagnosis multiple sclerosis', 'multiple sclerosis', 'mean survival diagnosis multiple', 'mean survival diagnosis', 'sclerosis', 'survival diagnosis multiple', 'survival diagnosis', 'mean survival', 'diagnosis multiple', 'survival', 'diagnosis', 'mean', 'multiple']
# ✅ Found 98520 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Mean survival after a diagnosis of multiple sclerosis."
#
# ❓[83/85] Question: Describe the SEQUOIA tool for predicting cancer transcriptomics profiles from histology images
# 🧠 Generated Queries: ['sequoia tool predicting cancer transcriptomics profiles histology images', 'sequoia tool predicting cancer transcriptomics profiles histology', 'sequoia tool predicting cancer transcriptomics profiles', 'sequoia tool predicting cancer transcriptomics', 'tool predicting cancer transcriptomics profiles histology images', 'sequoia tool predicting cancer', 'predicting cancer transcriptomics profiles histology images', 'tool predicting cancer transcriptomics profiles histology', 'cancer transcriptomics profiles histology images', 'transcriptomics profiles histology images', 'predicting cancer transcriptomics profiles histology', 'tool predicting cancer transcriptomics profiles', 'cancer transcriptomics profiles histology', 'tool predicting cancer transcriptomics', 'cancer transcriptomics profiles', 'transcriptomics profiles histology', 'predicting cancer transcriptomics profiles', 'predicting cancer transcriptomics', 'cancer transcriptomics', 'sequoia tool predicting']
# ✅ Found 39109 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Describe the SEQUOIA tool for predicting cancer transcriptomics profiles from histology images"
#
# ❓[84/85] Question: What is the function of CD47
# 🧠 Generated Queries: ['function cd47', 'cd47', 'function']
# ✅ Found 13087 unique PMIDs for this question.
# 🎯 Found 5 out of 5 ground truth PMIDs.
# 📦 Fetching details for 155 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the function of CD47"
#
# ❓[85/85] Question: Is the use of surfactant restricted to neonatology?
# 🧠 Generated Queries: ['use surfactant restricted neonatology', 'surfactant restricted neonatology', 'use surfactant restricted', 'surfactant restricted', 'restricted neonatology', 'use surfactant', 'surfactant', 'neonatology', 'restricted', 'use']
# ✅ Found 43790 unique PMIDs for this question.
# 🎯 Found 1 out of 2 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is the use of surfactant restricted to neonatology?"
#
# 📁 Saving batch at question 85...
# ✅ Batch saved and checkpoint updated at index 84
