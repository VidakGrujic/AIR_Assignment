# %% [markdown]
# # Initial API retreival.
# ### Note: THIS CAN BE USED ONLY FOR TRAINING AND TEST BATCHES WHICH ARE TAKEN FROM THE PHASE B BECAUSE THEY CONTAIN GOLDEN ANSWERS AND THEREFORE THE STRUCTURE IS DIFFERENT.
# ### FOR BATCH_2, BATCH_3, BATCH_4 USE THE TEST_QUESTION_API_RETREVAL.IPYNB

# %%
from Bio import Entrez
from keybert import KeyBERT
import json
import warnings
warnings.filterwarnings("ignore")
from tqdm import tqdm
import xml.etree.ElementTree as ET
import re
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
import random
import time
from datetime import datetime

# Load spaCy model only once
'''nlp = spacy.load("en_core_web_sm")

INTENT_TERMS = {
    "synonym", "definition", "define", "meaning",
    "cause", "treatment", "therapy",
    "effect", "role", "impact", "mechanism",
    "list"
}

GENERIC_MEDICAL_TERMS = {
    "disease", "disorder", "condition", "syndrome", "illness", "diagnosis"
}'''



data_file_path = "../datasets/test_golden_answers/batch_4/BioASQ-task13bPhaseB-testset4"
output_file_path = "../datasets/test_golden_answers/batch_4/retreived_articles_sampled_test_batch_4.json"
base_pid_url = 'http://www.ncbi.nlm.nih.gov/pubmed/' 
Entrez.email = "kasapovic.m@hotmail.com"  # validan email

# %%
def load_question_from_file(file_path):
    """
    Loads the BioASQ-style JSON and extracts the list of questions.
    
    Parameters:
        file_path (str): Path to the JSON file.
    
    Returns:
        List[dict]: A list of question dictionaries.
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        questions = data.get("questions", [])
        print(f"Loaded {len(questions)} questions from {file_path}")
        return questions
    except Exception as e:
        print(f"Failed to load questions: {e}")
        return []

# %%
questions = load_question_from_file(file_path=data_file_path)
questions
# Out:
# Loaded 85 questions from ../datasets/test_golden_answers/batch_4/BioASQ-task13bPhaseB-testset4
# [{'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/38159337',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38689623'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': '.CONCLUSIONS: TG02 exhibits overlapping toxicity with alkylating agents and low single agent clinical activity in recurrent glioblastoma. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38159337',
#     'offsetInBeginSection': 1538,
#     'offsetInEndSection': 1676},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Zotiraciclib, a CDK9 inhibitor, has demonstrated efficacy in glioblastoma treatment in preclinical and clinical studies, showing its potential as a therapeutic breakthrough. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38689623',
#     'offsetInBeginSection': 498,
#     'offsetInEndSection': 672}],
#   'id': '67e6cf2618b1e36f2e0000d0',
#   'type': 'yesno',
#   'body': 'Should Zotiraciclib be used for glioblastoma?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/38676590',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38719503',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38271608'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Introduction: Bronchiectasis is a chronic inflammatory lung disease',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38676590',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 67},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Bronchiectasis is a worldwide chronic lung disorder where exacerbations are common.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38719503',
#     'offsetInBeginSection': 14,
#     'offsetInEndSection': 97},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Chronic infection and inflammation shapes the airway microbiome in bronchiectasis.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38271608',
#     'offsetInBeginSection': 11,
#     'offsetInEndSection': 93}],
#   'id': '680d5e47353a4a2e6b000005',
#   'type': 'factoid',
#   'body': 'Is bronchiectasis a chronic or acute condition?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/35843573'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Studies have suggested that tumor necrosis factor-alpha (TNF-α) and interleukins (ILs) perform vital roles in the pathogenesis and treatment of depression',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/35843573',
#     'offsetInBeginSection': 247,
#     'offsetInEndSection': 401},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Increasing evidence suggests the upregulation of TNF-α and ILs expression in patients with depression',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/35843573',
#     'offsetInBeginSection': 403,
#     'offsetInEndSection': 504},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'biologics like TNF inhibitors (etanercept, infliximab, adalimumab) and IL inhibitors (ustekinumab) have become key compounds in the treatment of depression',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/35843573',
#     'offsetInBeginSection': 517,
#     'offsetInEndSection': 672},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'symptoms have been improved by treatment with TNF-α inhibitors. Hence suggesting TNF-α inhibitors as potential new antidepressants for the management of depressive disorder',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/35843573',
#     'offsetInBeginSection': 1246,
#     'offsetInEndSection': 1418}],
#   'id': '680f4a68353a4a2e6b000007',
#   'type': 'yesno',
#   'body': 'Do biopharmaceuticals have a role in the treatment of depression?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/38915631',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38298216'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'During development, microglia prune excess synapses to refine neuronal circuits.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38915631',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 80},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Microglia are immune cells in the brain that originate from the yolk sac and enter the developing brain before birth. They play critical roles in brain development by supporting neural precursor proliferation, synaptic pruning, and circuit formation.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38298216',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 250}],
#   'id': '680a083218b1e36f2e00014d',
#   'type': 'yesno',
#   'body': 'Are microglia involved in synaptic pruning during development?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/38161058',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38818887',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38775925',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38016166'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'In March 2023, the U.S. Food and Drug Administration approved fezolinetant (Veozah), a neurokinin 3 receptor antagonist for the treatment of vasomotor symptoms of menopause. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38161058',
#     'offsetInBeginSection': 479,
#     'offsetInEndSection': 653},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'OBJECTIVE: We aimed to assess long-term safety and tolerability of fezolinetant, a nonhormonal neurokinin 3 receptor antagonist, among Chinese women with vasomotor symptoms associated with menopause participating in the MOONLIGHT 3 trial.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38818887',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 238},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Current treatment options for VMS include fezolinetant, a nonhormonal, selective neurokinin\xa03 receptor antagonist. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38775925',
#     'offsetInBeginSection': 145,
#     'offsetInEndSection': 260},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'IMPORTANCE: The neurokinin 3 receptor antagonist fezolinetant 45 mg/d significantly reduced frequency/severity of moderate to severe vasomotor symptoms (VMS) of menopause compared with placebo in two phase 3 randomized controlled trials. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38016166',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 238}],
#   'id': '67e5557c18b1e36f2e0000ac',
#   'type': 'factoid',
#   'body': 'What is the target of fezolinetant?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/23897597',
#    'http://www.ncbi.nlm.nih.gov/pubmed/17766166',
#    'http://www.ncbi.nlm.nih.gov/pubmed/15168959'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Diethylstilbestrol (DES) is a potent estrogen mimic that was predominantly used from the 1940s to the 1970s by pregnant women in hopes of preventing miscarriage. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/23897597',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 162},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'The diethylstilbestrol (DES) is a synthetic estrogen which was prescribed from 1941 onwards for the prevention of miscarriage',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/17766166',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 125},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Diethylstilbestrol is a synthetic nonsteroidal estrogen that was used to prevent miscarriage and other pregnancy complications between 1938 and 1971 in the United States.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/15168959',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 170}],
#   'id': '6810fef8353a4a2e6b000016',
#   'type': 'factoid',
#   'body': 'What complication of pregnancy was treated with  Diethylstilbestrol'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/38814297',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39079810',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39744803'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': ' Current protection against severe RSV infection is immunoprophylaxis with the monoclonal antibody palivizumab',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38814297',
#     'offsetInBeginSection': 261,
#     'offsetInEndSection': 371},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'nirsevimab to protect infants against respiratory syncytial virus',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39079810',
#     'offsetInBeginSection': 80,
#     'offsetInEndSection': 145},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': ' nirsevimab programs are the most cost-effective option',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39079810',
#     'offsetInBeginSection': 1922,
#     'offsetInEndSection': 1977},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Nirsevimab was observed to have noninferior efficacy and safety compared with palivizumab with less frequent administration. Nirsevimab is recommended to replace palivizumab for RSV prophylaxis in all eligible infants. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39744803',
#     'offsetInBeginSection': 862,
#     'offsetInEndSection': 1081}],
#   'id': '6810cb23353a4a2e6b000012',
#   'type': 'factoid',
#   'body': 'Biopharmaceuticals for pediatric bronchiolitis.'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/39221688',
#    'http://www.ncbi.nlm.nih.gov/pubmed/37820582',
#    'http://www.ncbi.nlm.nih.gov/pubmed/29232467'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'The cancer-immunity cycle provides a framework to understand the series of events that generate anti-cancer immune responses. It emphasizes the iterative nature of the response where the killing of tumor cells by T\xa0cells initiates subsequent rounds of antigen presentation and T\xa0cell stimulation, maintaining active immunity and adapting it to tumor evolution. Any step of the cycle can become rate-limiting, rendering the immune system unable to control tumor growth.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/37820582',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 468},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Immunological destruction of tumors is a multistep, coordinated process that can be modulated or targeted at several critical points to elicit tumor rejection. These steps in the cancer immunity cycle include: (i) generation of sufficient numbers of effector T cells with high avidity recognition of tumor antigens in vivo; (ii) trafficking and infiltration into the tumor; (iii) overcoming inhibitory networks in the tumor microenvironment; (iv) direct recognition of tumor antigens and generation of an effector anti-tumor response; and (v) persistence of the anti-tumor T cells.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/29232467',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 581}],
#   'id': '680bc7a718b1e36f2e000156',
#   'type': 'summary',
#   'body': 'What is the cancer-immunity cycle?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/39374533',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39774762',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38182298',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38312795',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38741947'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'ABSTRACT: Iptacopan, a novel oral factor B inhibitor, recently obtained US Food and Drug Administration approval for treating paroxysmal nocturnal hemoglobinuria, a rare blood disorder characterized by persistent complement-mediated hemolytic anemia.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39374533',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 250},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Iptacopan, a first-in-class, oral, selective complement factor B inhibitor, demonstrated efficacy and safety as monotherapy in C5 inhibitor (C5i)-experienced (APPLY-PNH [NCT04558918]) and C5i-naive (APPOINT-PNH [NCT04820530]) patients with paroxysmal nocturnal hemoglobinuria (PNH).',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39774762',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 282},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'A recent randomized controlled trial tested the efficacy and safety of iptacopan, a factor B inhibitor, in patients with IgAN. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38182298',
#     'offsetInBeginSection': 169,
#     'offsetInEndSection': 296},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Iptacopan is an oral, highly potent proximal complement inhibitor that specifically binds to factor B and inhibits the alternative pathway (AP)',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38312795',
#     'offsetInBeginSection': 416,
#     'offsetInEndSection': 559},
#    {'beginSection': 'title',
#     'endSection': 'title',
#     'text': 'Factor B Inhibition with Iptacopan in Recurrent C3 Glomerulopathy Following Kidney Transplant: A Report of Two Cases.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38741947',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 117},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Fortunately, new molecules are being developed that specifically target the proximal alternative complement pathway, such as iptacopan, a factor B inhibitor that showed promising results in native kidneys and cases of transplant recurrence in a phase 2 clinical trial. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38741947',
#     'offsetInBeginSection': 433,
#     'offsetInEndSection': 702}],
#   'id': '67e56f2018b1e36f2e0000b0',
#   'type': 'summary',
#   'body': 'What is the mechanism of action of Iptacopan?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/39352015'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Current studies emphasize the urgent need for a paradigm shift in conceptualizing nonalcoholic fatty liver disease (NAFLD), now renamed metabolic dysfunction-associated steatotic liver disease (MASLD)',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39352015',
#     'offsetInBeginSection': 178,
#     'offsetInEndSection': 378}],
#   'id': '67fe5f0918b1e36f2e000144',
#   'type': 'factoid',
#   'body': 'What is the previous acronym for Metabolic Dysfunction-Associated Steatotic Liver Diasease  (MASLD)?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/39385445',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39242950',
#    'http://www.ncbi.nlm.nih.gov/pubmed/37145176',
#    'http://www.ncbi.nlm.nih.gov/pubmed/36930441'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Associations at previously identified OPRM1 variants suggest common biology between persistent opioid use and opioid use disorder, further demonstrating connections between opioid dependence and addiction phenotypes.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39385445',
#     'offsetInBeginSection': 1101,
#     'offsetInEndSection': 1317},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'differentially expressed genes (DEGs) ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39242950',
#     'offsetInBeginSection': 974,
#     'offsetInEndSection': 1012},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Commonly dysregulated DEGs suggest conserved cross-species mechanisms for chronic alcohol consumption/AUD comprising MAPKs as well as STAT, IRF7, and TNF',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39242950',
#     'offsetInBeginSection': 1049,
#     'offsetInEndSection': 1202},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Abnormal genetic polymorphism of trace amine-associated receptor 1 (TAAR1) rs8192620 site has been confirmed to induce methamphetamine (MA) use and drug craving',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/37145176',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 160}],
#   'id': '67fbe4d718b1e36f2e00011d',
#   'type': 'summary',
#   'body': 'What is the genetic basis of addiction?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/38635551',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39075582',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39303993'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Natural Killer (NK) cells are integral to the innate immune system, renowned for their ability to target and eliminate cancer cells without the need for antigen presentation, sparing normal tissues. These cells are crucial in cancer immunosurveillance due to their diverse array of activating and inhibitory receptors that modulate their cytotoxic activity.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39303993',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 357},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Natural killer (NK) cell-based therapies have made great progress in treating both hematological and solid tumors. Their unique mechanism of action does not rely on antigen presentation to recognize and eliminate tumor cells, making them a promising approach for cancer immunotherapy.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39075582',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 284},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Natural killer (NK) cells play a crucial role in immunosurveillance independent of antigen presentation, which is regulated by signal balance via activating and inhibitory receptors. The anti-tumor activity of NK cells is largely dependent on signaling from target recognition to cytolytic degranulation; however, the underlying mechanism remains unclear, and NK cell cytotoxicity is readily impaired by tumor cells.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38635551',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 416}],
#   'id': '680a079718b1e36f2e000147',
#   'type': 'yesno',
#   'body': 'Do natural killer (NK) cells require antigen presentation to eliminate cancer cells?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/35880455',
#    'http://www.ncbi.nlm.nih.gov/pubmed/35906791',
#    'http://www.ncbi.nlm.nih.gov/pubmed/36179408',
#    'http://www.ncbi.nlm.nih.gov/pubmed/34768899',
#    'http://www.ncbi.nlm.nih.gov/pubmed/34305918'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Until very recently, only one TCE was approved, the CD19/CD3-bispecific blinatumomab.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/35880455',
#     'offsetInBeginSection': 169,
#     'offsetInEndSection': 254},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Blinatumomab is a fusion protein which consists of two single-chain variable fragments arranged in tandem: the first binds the CD19 surface antigen of all B cells and the second targets the CD3 antigen of T cells. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/35906791',
#     'offsetInBeginSection': 901,
#     'offsetInEndSection': 1115},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Since the approval of the CD19-targeted BiTE® (bispecific T-cell engager) molecule blinatumomab, multiple TCE molecules against different targets have been developed in several tumor types, with the approval of three additional TCE molecules in 2022.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/36179408',
#     'offsetInBeginSection': 125,
#     'offsetInEndSection': 375},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Anti-CD19xCD3 TCEs are being developed as well but only blinatumomab has been evaluated in clinical trials yet. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/34768899',
#     'offsetInBeginSection': 760,
#     'offsetInEndSection': 872},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'After the approval of blinatumomab, a bispecific antibody (bsAb) targeting on CD19 for acute lymphoblastic leukemia, a few of CD47-targeted bsAbs for cancer immunotherapy, are currently in clinical research.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/34305918',
#     'offsetInBeginSection': 138,
#     'offsetInEndSection': 345}],
#   'id': '67e5749b18b1e36f2e0000b5',
#   'type': 'list',
#   'body': 'What are the targets of blinatumomab?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/18035199'],
#   'snippets': [{'beginSection': 'title',
#     'endSection': 'title',
#     'text': 'Effectiveness of erdosteine in elderly patients with bronchiectasis and hypersecretion:',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/18035199',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 87},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': ' chest physiotherapy and/or the use of mucoactive agents is considered to be an effective therapeutic model in treating patients with COPD and bronchiectasis.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/18035199',
#     'offsetInBeginSection': 267,
#     'offsetInEndSection': 425},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'This pilot study found that a regimen of PO erdosteine 225 mg BID in addition to routine chest physiotherapy provided some physiologic and clinical benefits in the treatment of these elderly patients with bronchiectasis and chronic mucus hyper-secretion.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/18035199',
#     'offsetInBeginSection': 2671,
#     'offsetInEndSection': 2925}],
#   'id': '680d5f2a353a4a2e6b000006',
#   'type': 'summary',
#   'body': 'What is the relationship between bronchiectasis and Erdosteine?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/39065679',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38778795',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38941713',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38204284'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Semaglutide appeared to be the most effective and safe option among four GLP-1 RAs in children and adolescents with obesity or overweight',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39065679',
#     'offsetInBeginSection': 1279,
#     'offsetInEndSection': 1416},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': ' current practice patterns of GLP-1A use at major pediatric bariatric centers across the United States',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38941713',
#     'offsetInBeginSection': 333,
#     'offsetInEndSection': 435},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'GLP-1 RAs are safe, acceptable, and effective in weight reduction and sugar control for children with obesity.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38204284',
#     'offsetInBeginSection': 1357,
#     'offsetInEndSection': 1467}],
#   'id': '6810f6f0353a4a2e6b000015',
#   'type': 'yesno',
#   'body': 'Can GLP-1 receptor agonists be used for obesity in children under 10 years of age?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/38668068',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39099033',
#    'http://www.ncbi.nlm.nih.gov/pubmed/37751102',
#    'http://www.ncbi.nlm.nih.gov/pubmed/30449497'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Radiomics analysis, utilizing segmented perfusion and diffusion maps, provide predictive indicators of survival in IDH wild-type glioblastoma patients, revealing associations with microstructural and vascular heterogeneity in the tumor.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38668068',
#     'offsetInBeginSection': 1282,
#     'offsetInEndSection': 1518},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Extracting multiregional radiomic features from multiparametric MRI for predicting pretreatment survival in isocitrate dehydrogenase (IDH) wild-type glioblastoma (GBM) patients is a promising approach.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38668068',
#     'offsetInBeginSection': 12,
#     'offsetInEndSection': 213},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Findings suggest that a small necrotic subregion, inhomogeneous vascularization in the solid non-enhancing subregion, and edema-related tissue damage in the enhancing and edema subregions are linked to poor survival. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38668068',
#     'offsetInBeginSection': 921,
#     'offsetInEndSection': 1138},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Glioblastoma multiforme (GBM), particularly the isocitrate dehydrogenase (IDH)-wildtype type, represents a significant clinical challenge due to its aggressive nature and poor prognosis. Despite advancements in medical imaging and its modalities, survival rates have not improved significantly, demanding innovative treatment planning and outcome prediction approaches.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39099033',
#     'offsetInBeginSection': 11,
#     'offsetInEndSection': 380},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Glioblastoma Multiforme (GBM) represents the predominant aggressive primary tumor of the brain with short overall survival (OS) time. We aim to assess the potential of radiomic features in predicting the time-to-event OS of patients with GBM using machine learning (ML) algorithms.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/37751102',
#     'offsetInBeginSection': 9,
#     'offsetInEndSection': 290},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'ML algorithms are capable of predicting the time-to-event OS of patients using MRI-based radiomic and clinical features. MRI-based radiomics analysis in combination with clinical variables might appear promising in assisting clinicians in the survival prediction of patients with GBM. Further research is needed to establish the applicability of radiomics in the management of GBM in the clinic.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/37751102',
#     'offsetInBeginSection': 1488,
#     'offsetInEndSection': 1883},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'The proposed method significantly enhances the predictive accuracy of OS outcomes in GBM, IDH-wildtype patients. By integrating detailed imaging features with key clinical indicators, this model offers a robust tool for personalized treatment planning, potentially improving OS.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39099033',
#     'offsetInBeginSection': 1761,
#     'offsetInEndSection': 2039},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Glioblastoma multiforme (GBM) are aggressive brain tumors, which lead to poor overall survival (OS) of patients. OS prediction of GBM patients provides useful information for surgical and treatment planning. Radiomics research attempts at predicting disease prognosis, thus providing beneficial information for personalized treatment from a variety of imaging features extracted from multiple MR images.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/30449497',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 403}],
#   'id': '680a237618b1e36f2e000152',
#   'type': 'yesno',
#   'body': 'Are radiomic features useful in predicting survival in glioblastoma patients?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/9261645'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'N-acetylcysteine improves survival in established acute liver failure following paracetamol overdose by reducing  the incidence of multiorgan failure.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/9261645',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 150}],
#   'id': '68110110353a4a2e6b000018',
#   'type': 'yesno',
#   'body': 'In patients with acute liver failure associated with  paracetamol overdose does  N‐acetylcysteine treatment improve survival?.'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/39749885',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38943214',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38212419',
#    'http://www.ncbi.nlm.nih.gov/pubmed/36394218'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'praziquantel ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39749885',
#     'offsetInBeginSection': 862,
#     'offsetInEndSection': 875},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'praziquantel',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38943214',
#     'offsetInBeginSection': 24,
#     'offsetInEndSection': 36},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'praziquantel',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38212419',
#     'offsetInBeginSection': 1287,
#     'offsetInEndSection': 1299},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Praziquantel',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/36394218',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 12}],
#   'id': '680f4c63353a4a2e6b00000d',
#   'type': 'factoid',
#   'body': 'What is the pharmacological treatment of urinary schistosomiasis?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/32124697',
#    'http://www.ncbi.nlm.nih.gov/pubmed/32060219',
#    'http://www.ncbi.nlm.nih.gov/pubmed/37060067',
#    'http://www.ncbi.nlm.nih.gov/pubmed/35747447',
#    'http://www.ncbi.nlm.nih.gov/pubmed/34545475'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Radiomics is a rapidly evolving field of research concerned with the extraction of quantitative metrics-the so-called radiomic features-within medical images. Radiomic features capture tissue and lesion characteristics such as heterogeneity and shape and may, alone or in combination with demographic, histologic, genomic, or proteomic data, be used for clinical problem solving.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/32060219',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 379},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'The process of radiomics analysis usually includes the acquisition of image data, Region of Interest (ROI) segmentation, feature extracting, feature selection, and classification or prediction. From those radiomics methods, texture analysis occupied a large part. In addition, the extracted features include histogram, shapebased features, texture-based features, wavelet features, Gray Level Co-Occurrence Matrix (GLCM), and Run-Length Matrix (RLM).',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/32124697',
#     'offsetInBeginSection': 839,
#     'offsetInEndSection': 1289},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Texture analysis features include histogram, gray size area matrix and gray co-occurrence matrix features.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/37060067',
#     'offsetInBeginSection': 437,
#     'offsetInEndSection': 543},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'These subregions exhibited several important radiomic features that include shape, gray level size zone matrix (GLSZM), and gray level dependence matrix (GLDM), among others.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/35747447',
#     'offsetInBeginSection': 1007,
#     'offsetInEndSection': 1181},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'To better understand the variations, features are further grouped into 3 categories according to their properties: 1) morphology, 2) statistic/histogram and 3)texture features.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/34545475',
#     'offsetInBeginSection': 996,
#     'offsetInEndSection': 1172}],
#   'id': '680a087218b1e36f2e00014f',
#   'type': 'list',
#   'body': 'What types of features are typically extracted in radiomics?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/37162960',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38951925',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39403201',
#    'http://www.ncbi.nlm.nih.gov/pubmed/31936237',
#    'http://www.ncbi.nlm.nih.gov/pubmed/30789675'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'The most effective treatment for rCDI is the reestablishment of an intact microbiota via fecal microbiota transplants (FMTs).',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/37162960',
#     'offsetInBeginSection': 464,
#     'offsetInEndSection': 589},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Fecal microbiota transplantation (FMT) and fecal virome transplantation (FVT, sterile filtrated donor feces) have been effective in treating recurrent Clostridioides difficile infections, possibly through bacteriophage-mediated modulation of the gut microbiome',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38951925',
#     'offsetInBeginSection': 12,
#     'offsetInEndSection': 272},
#    {'beginSection': 'title',
#     'endSection': 'title',
#     'text': 'Fecal microbiota transplantation in a patient with chronic diarrhea and primary and secondary immunodeficiency (common variable immunodeficiency and splenectomy).',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39403201',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 162},
#    {'beginSection': 'title',
#     'endSection': 'title',
#     'text': 'Fecal Microbiota Transplantation Prevents Intestinal Injury, Upregulation of Toll-Like Receptors, and 5-Fluorouracil/Oxaliplatin-Induced Toxicity in Colorectal Cancer.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/31936237',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 167},
#    {'beginSection': 'title',
#     'endSection': 'title',
#     'text': 'ecal transplant modifies urine chemistry risk factors for urinary stone disease.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/30789675',
#     'offsetInBeginSection': 1,
#     'offsetInEndSection': 81},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': ' Our results suggest that the gut microbiome may impact metabolism, alters urinary chemistry, and thereby may influence USD; the accessibility of the GMB can potentially be leveraged for therapeutic interventions.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/30789675',
#     'offsetInBeginSection': 1506,
#     'offsetInEndSection': 1719}],
#   'id': '6810daad353a4a2e6b000013',
#   'type': 'list',
#   'body': 'What diseases are treated with fecal transplants?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/39773770',
#    'http://www.ncbi.nlm.nih.gov/pubmed/37827253',
#    'http://www.ncbi.nlm.nih.gov/pubmed/36651686'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'guidance on antidepressant prescribing choices in children',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39773770',
#     'offsetInBeginSection': 69,
#     'offsetInEndSection': 127},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': "upward trend flattened for both 'all' antidepressants and Fluoxetine and steepened for Sertraline",
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39773770',
#     'offsetInBeginSection': 1173,
#     'offsetInEndSection': 1270},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Fluoxetine and sertraline constituted the two most frequently-prescribed individual antidepressants',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/37827253',
#     'offsetInBeginSection': 1312,
#     'offsetInEndSection': 1411},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'aged 5-17\xa0years',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/37827253',
#     'offsetInBeginSection': 365,
#     'offsetInEndSection': 380},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': ' youth aged 7-17\u2009years who were treated with sertraline',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/36651686',
#     'offsetInBeginSection': 1213,
#     'offsetInEndSection': 1268}],
#   'id': '6810c27b353a4a2e6b000010',
#   'type': 'yesno',
#   'body': 'Can sertraline be used in children under 10?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/30319969',
#    'http://www.ncbi.nlm.nih.gov/pubmed/17823633'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Dendritic cells (DCs) are the primary antigen-presenting cells and play key roles in the orchestration of the innate and adaptive immune system.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/30319969',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 144},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Dendritic cells (DCs) are primary antigen-presenting cells involved in interactions with T cells leading to the proliferation of TH1 or TH2 cell types.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/17823633',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 151}],
#   'id': '680a07a418b1e36f2e000148',
#   'type': 'factoid',
#   'body': 'Which cells are the primary antigen-presenting cells?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/39667814',
#    'http://www.ncbi.nlm.nih.gov/pubmed/37186678',
#    'http://www.ncbi.nlm.nih.gov/pubmed/37334903'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Amyotrophic lateral sclerosis (ALS) is a rare neurodegenerative disease characterized by motor neuron loss in the motor cortex, brain stem, and spinal cord. Mutations in the superoxide dismutase 1 (SOD1) gene, resulting in misfolding of its protein product, are a common cause of ALS. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39667814',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 285},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Neurodegenerative diseases are a serious problem throughout the world. There are several causes of neurodegenerative diseases; these include genetic predisposition, accumulation of misfolded proteins, oxidative stress, neuroinflammation, and excitotoxicity',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/37186678',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 256},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Human prion diseases are heterogeneous, and often rapidly progressive, transmissible neurodegenerative disorders associated with misfolded prion protein (PrP) aggregation and self-propagation. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/37334903',
#     'offsetInBeginSection': 14,
#     'offsetInEndSection': 207}],
#   'id': '67fbd58c18b1e36f2e00010e',
#   'type': 'yesno',
#   'body': 'Do misfolded and aggregated proteins build up in neurodegenerative illnesses, which causes neuronal dysfunction and ultimately neuronal death?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/39762643',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38476386',
#    'http://www.ncbi.nlm.nih.gov/pubmed/35809134',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38429939'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Autistic girls were more likely to have parent-reported depression and anxiety compared to autistic boys',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39762643',
#     'offsetInBeginSection': 1781,
#     'offsetInEndSection': 1885},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Present results showed that girls with ASD had lower IQs than boys but similar adaptive functioning. The severity of symptoms of ASD was greater in boys than in girls, as were scores on psychopathological measures. With increasing age, boys with ASD showed greater impairment in social communication skills than girls and increased psychopathological comorbidities. Older girls showed fewer restricted and repetitive behaviors.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38476386',
#     'offsetInBeginSection': 839,
#     'offsetInEndSection': 1266},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'girls had higher reported instances of Bullying, less Anger Control, and poorer Emotional Self-Control ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/35809134',
#     'offsetInBeginSection': 466,
#     'offsetInEndSection': 569},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'comparable rates of suicide death among autistic males and females, and mixed findings related to sex differences in risk of other suicidal behaviors',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38429939',
#     'offsetInBeginSection': 644,
#     'offsetInEndSection': 793}],
#   'id': '67fbe10618b1e36f2e000111',
#   'type': 'list',
#   'body': 'Differential traits of autism spectrum disorders in girls.'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/47690',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39169187',
#    'http://www.ncbi.nlm.nih.gov/pubmed/23660557',
#    'http://www.ncbi.nlm.nih.gov/pubmed/31818032'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'There are five major classes of immunoglobulins - IgG, M, A, D and E. Each is made of two heavy and two light chains or polymers of this basic subunit. The structure of each heavy and light chain consists of a variable region involved in antigen specificity and binding and a constant region which is involved in the class specific properties. The different classes of immunoglobulins differ in the biological properties. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/47690',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 422},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Immunoglobulin A (IgA) is the most abundant antibody isotype produced in humans, predominantly present in the mucosal areas where its main functions are the neutralization of toxins, prevention of microbial invasion across the mucosal epithelial barrier, and simultaneous maintenance of a physiologically indispensable symbiotic relationship with commensal bacteria.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/31818032',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 366},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Immunoglobulin E (IgE) plays a pivotal role in allergic responses1,2.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39169187',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 69},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Antibodies and cells, generated in the germinal center in response to the first encounter with antigen, are highly specific, remain in the organism virtually forever and are mostly of IgG isotype.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/23660557',
#     'offsetInBeginSection': 179,
#     'offsetInEndSection': 375},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'IgM memory B cells represent our first-line defense against infections.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/23660557',
#     'offsetInBeginSection': 581,
#     'offsetInEndSection': 652}],
#   'id': '680fcb72353a4a2e6b00000e',
#   'type': 'list',
#   'body': 'What are the major classes of immunoglobulins?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/38246901',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38543128',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38622003',
#    'http://www.ncbi.nlm.nih.gov/pubmed/37950346'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'suvorexant, a dual orexin receptor antagonist (DORA), on sleep and sensory/motor symptoms in individuals with idiopathic RLS.M',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38246901',
#     'offsetInBeginSection': 305,
#     'offsetInEndSection': 431},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Daridorexant (dari), as the first dual orexin receptor antagonist (DORA) marketed in Europe, offers a novel therapeutic approach to insomnia.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38543128',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 141},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'a. Dual orexin receptor antagonists (DORAs) such as daridorexant, lemborexant, and suvorexant, represent a novel approach to insomnia treatment by inhibiting wakefulness rather than enhancing sedation.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38622003',
#     'offsetInBeginSection': 1235,
#     'offsetInEndSection': 1436},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'This meta-analysis study aimed to assess the safety of FDA-approved DORAs (suvorexant, lemborexant, and daridorexant), focusing on narcolepsy-like symptoms associated with these drugs',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/37950346',
#     'offsetInBeginSection': 97,
#     'offsetInEndSection': 280}],
#   'id': '6805568118b1e36f2e000145',
#   'type': 'list',
#   'body': 'Please list the DORA type drugs'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/38484803',
#    'http://www.ncbi.nlm.nih.gov/pubmed/37923154',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39201067',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39319103',
#    'http://www.ncbi.nlm.nih.gov/pubmed/35668627'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Takotsubo cardiomyopathy (TCM) is classically associated with significant gender disparities, such that it is more prevalent in females',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38484803',
#     'offsetInBeginSection': 12,
#     'offsetInEndSection': 147},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'The incidence of takotsubo stress cardiomyopathy (TSCM) in males is low compared with females',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/37923154',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 93},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Takotsubo syndrome (TTS), also known as the broken-heart syndrome, is a reversible condition typically observed in female patients presenting for acute coronary syndromes',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39201067',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 170},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Takotsubo cardiomyopathy (TTC) has a preponderance for females, particularly postmenopausal',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39319103',
#     'offsetInBeginSection': 12,
#     'offsetInEndSection': 103},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Takotsubo syndrome (TTS), triggered by intense emotional or physical stress, occurring most commonly in post-menopausal women',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/35668627',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 125}],
#   'id': '67e26b0b18b1e36f2e000073',
#   'type': 'yesno',
#   'body': 'Is takotsubo cardiomyopathy more common in men?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/36639175',
#    'http://www.ncbi.nlm.nih.gov/pubmed/35131965'],
#   'snippets': [{'beginSection': 'abstract',
# ...
#     'offsetInEndSection': 270},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Intra-articular injections of different doses of linear HMW HA can improve pain, stiffness, function, and quality of life in patients suffering from knee OA over a six-month period',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38160332',
#     'offsetInBeginSection': 1202,
#     'offsetInEndSection': 1382},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Intra-articular injections of PRP and HA are effective interventions for KOA. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38435440',
#     'offsetInBeginSection': 1516,
#     'offsetInEndSection': 1594}],
#   'id': '67fbe2ab18b1e36f2e000116',
#   'type': 'yesno',
#   'body': 'Do hyaluronic acid injections improve knee pain?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/30290178',
#    'http://www.ncbi.nlm.nih.gov/pubmed/34351428',
#    'http://www.ncbi.nlm.nih.gov/pubmed/30166336'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'By searching for transcription factors that function at these elements, we identified NFIA and ATF3 as drivers of astrocyte differentiation from neural precursor cells while RUNX2 promotes astrocyte maturation. These transcription factors facilitate stage-specific gene expression programs by switching the chromatin state of their target regulatory elements from primed to active. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/30290178',
#     'offsetInBeginSection': 647,
#     'offsetInEndSection': 1029},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'We report molecularly distinct phases of astrogliogenesis that exhibit stage- and lineage-specific transcriptomic and epigenetic signatures with unique primed and active chromatin regions, thereby revealing regulatory elements and transcriptional programs underlying astrocyte generation and maturation.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/30290178',
#     'offsetInBeginSection': 343,
#     'offsetInEndSection': 646},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'The transcription factor zinc finger and BTB domain-containing protein 20 (ZBTB20) has been implicated in regulation of cell specification during neocortical development.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/34351428',
#     'offsetInBeginSection': 142,
#     'offsetInEndSection': 312},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Astrogliogenesis is also affected in the mutants with an increase in the number of a specific subset of astrocytes expressing GFAP. Astrogliogenesis is more severely disrupted by a ZBTB20 protein containing dominant mutations linked to Primrose syndrome',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/34351428',
#     'offsetInBeginSection': 646,
#     'offsetInEndSection': 899},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'SOX transcription factors have important roles during astrocyte and oligodendrocyte development',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/30166336',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 95},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'In the subsequent lineage-restricted glial precursor cells, astrocyte genes become additionally targeted by SOX9 at DNA regions strongly enriched for Nfi binding motifs.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/30166336',
#     'offsetInBeginSection': 475,
#     'offsetInEndSection': 644},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Interestingly, reporter gene assays and functional studies in the spinal cord reveal that SOX3 binding represses the synergistic activation of astrocyte genes by SOX9 and NFIA',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/30166336',
#     'offsetInBeginSection': 774,
#     'offsetInEndSection': 949}],
#   'id': '67eaf14c18b1e36f2e0000de',
#   'type': 'list',
#   'body': 'Which transcription factors are important to define human astrocyte identity?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/38275822',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38970664',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39494584'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': "Peto's paradox, which highlights the lower-than-expected cancer rates in larger and/or longer-lived species, is a cornerstone of discussions at the intersection of ecology, evolution, and cancer research",
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39494584',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 203},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': "As a result, this study uncovered the sufficient conditions underlying the absence of correlation in Peto's paradox and provide insights into the reasons for the equitable distribution of cance",
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38970664',
#     'offsetInBeginSection': 611,
#     'offsetInEndSection': 804},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': " Despite this assumption, the observed uniformity in cancer rates across species, referred to as the Peto's paradox,",
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38970664',
#     'offsetInBeginSection': 160,
#     'offsetInEndSection': 276},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': "eto's paradox and the epidemiologic observation of the average six degrees of tumor prevalence are studied and hypothetically solved. A simple consideration, Petho's paradox challenges our intuitive understanding of cancer risk and prevalence. ",
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38275822',
#     'offsetInBeginSection': 1,
#     'offsetInEndSection': 245},
#    {'beginSection': 'title',
#     'endSection': 'title',
#     'text': 'Peto\'s "Paradox" and Six Degrees of Cancer Prevalence.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38275822',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 54}],
#   'id': '67c9e7ee81b1027333000007',
#   'type': 'yesno',
#   'body': "Is Peto's Paradox associated with cancer rates?"},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/8432813',
#    'http://www.ncbi.nlm.nih.gov/pubmed/29859941'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'clinical anaerobes',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/8432813',
#     'offsetInBeginSection': 1549,
#     'offsetInEndSection': 1567},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'strictly anaerobic bacterium',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/29859941',
#     'offsetInBeginSection': 121,
#     'offsetInEndSection': 149}],
#   'id': '67d71d8f18b1e36f2e00002b',
#   'type': 'factoid',
#   'body': 'Is Clostridioides difficile an aerobe or a anaerobe bacterium?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/38776437',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39506202',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39467963',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39404914',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39556474',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39762665',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39755334',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39747138'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Glucagon antagonism enhances the therapeutic effects of SGLT2 inhibition in type 1 diabetes. Combination therapy improves glycemic control, reduces insulin dosing, and suggests a strategy to unlock the benefits of SGLT2 inhibitors while mitigating the risk of diabetic ketoacidosis.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38776437',
#     'offsetInBeginSection': 1576,
#     'offsetInEndSection': 1858},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Sodium-glucose co-transporter 2 inhibitors are a novel class of antihyperglycaemic drugs used in the management of type 2 diabetes, that improve glycaemic control, cardiovascular outcomes and promote weight loss. T',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39506202',
#     'offsetInBeginSection': 14,
#     'offsetInEndSection': 228},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'n patients with AMI, treatment with SGLT2i is safe and significantly reduces the risk of hospitalization for HF, but it has no impact on all-cause death and cardiovascular death compared to placebo.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39467963',
#     'offsetInBeginSection': 1333,
#     'offsetInEndSection': 1531},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Sodium-glucose cotransporter-2 (SGLT2) inhibitors provide cardiovascular and kidney benefits to patients with heart failure (HF) and/or chronic kidney disease (CKD),',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39404914',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 165},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': ' Sodium-glucose cotransporter-2 inhibitors (SGLT2is) are the first therapy shown to improve clinical outcomes for patients with heart failure (HF) and a left ventricular ejection fraction (LVEF) greater than 40%.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39556474',
#     'offsetInBeginSection': 11,
#     'offsetInEndSection': 223},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Sodium-glucose cotransporter 2 inhibitors (SGLT2is) reportedly decreased the new-onset atrial arrhythmias in patients with type-2 diabetes (T2DM) or heart failure (HF). T',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39755334',
#     'offsetInBeginSection': 12,
#     'offsetInEndSection': 182},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'While sodium glucose cotransporter-2 inhibitors (SGLT2i) show renal benefits in randomized controlled trials (RCTs), ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39747138',
#     'offsetInBeginSection': 139,
#     'offsetInEndSection': 256}],
#   'id': '67cdb26a81b1027333000017',
#   'type': 'list',
#   'body': 'Please list the benefits of sodium-glucose cotransporter 2 inhibitors'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/37052881',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38921024'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Escherichia coli was the most identified uropathogen (60.4%) followed by Klebsiella spp. (8.7%) and Enterococcus spp. (7.7%)',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/37052881',
#     'offsetInBeginSection': 1010,
#     'offsetInEndSection': 1134},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Uropathogenic Escherichia coli (UPEC) is the main cause of urinary tract infections',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38921024',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 83}],
#   'id': '67e2b0a018b1e36f2e00008b',
#   'type': 'factoid',
#   'body': 'Bacteria that most commonly causes urinary tract infection.'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/38375835',
#    'http://www.ncbi.nlm.nih.gov/pubmed/36838205',
#    'http://www.ncbi.nlm.nih.gov/pubmed/37446403'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Bacillus clausii is a commercial spore probiotic known to treat multiple diseases.',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38375835',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 82},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Spore-forming bacteria of the Bacillus genus have demonstrated potential as probiotics for human use. Bacillus clausii have been recognized as efficacious and safe agents for preventing and treating diarrhea in children and adults, with pronounced immunomodulatory properties during several in vitro and clinical studies. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/36838205',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 322},
#    {'beginSection': 'title',
#     'endSection': 'title',
#     'text': ' Probiotic Bacillus clausii ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/36838205',
#     'offsetInBeginSection': 64,
#     'offsetInEndSection': 92},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'This 12-week open-label, single-center clinical trial evaluated the efficacy of probiotics (Bacillus indicus (HU36), Bacillus subtilis (HU58), Bacillus coagulans (SC208), Bacillus licheniformis (SL307), and Bacillus clausii (SC109))',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/37446403',
#     'offsetInBeginSection': 256,
#     'offsetInEndSection': 488}],
#   'id': '67e090be18b1e36f2e00006c',
#   'type': 'yesno',
#   'body': 'Is Bacillus Clausii a probiotic?'},
#  {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/39759166',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39117400',
#    'http://www.ncbi.nlm.nih.gov/pubmed/38622501',
#    'http://www.ncbi.nlm.nih.gov/pubmed/39651251',
#    'http://www.ncbi.nlm.nih.gov/pubmed/37005162',
#    'http://www.ncbi.nlm.nih.gov/pubmed/36759099'],
#   'snippets': [{'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'Some women infected with Chlamydia trachomatis (CT) are asymptomatic, while others experience lower abdominal discomfort when the inflammatory process extends to the fallopian tubes',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39759166',
#     'offsetInBeginSection': 0,
#     'offsetInEndSection': 181},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'salpingitis',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39759166',
#     'offsetInBeginSection': 202,
#     'offsetInEndSection': 213},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'pelvic peritonitis',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39759166',
#     'offsetInBeginSection': 230,
#     'offsetInEndSection': 248},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'peritonitis in the upper abdomen',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39759166',
#     'offsetInBeginSection': 267,
#     'offsetInEndSection': 299},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'CT and NG detected only at the anorectum',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39117400',
#     'offsetInBeginSection': 1883,
#     'offsetInEndSection': 1923},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'cervicitis, urethritis, and infertility',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/38622501',
#     'offsetInBeginSection': 131,
#     'offsetInEndSection': 170},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'pelvic inflammatory disease, infertility and other reproductive sequelae when it ascends to the upper genital tract. ',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/39651251',
#     'offsetInBeginSection': 63,
#     'offsetInEndSection': 180},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'pelvic inflammatory disease, increasing their risk for ectopic pregnancy, infertility, and chronic pelvic pain',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/37005162',
#     'offsetInBeginSection': 296,
#     'offsetInEndSection': 406},
#    {'beginSection': 'abstract',
#     'endSection': 'abstract',
#     'text': 'PID is infection of the female upper genital tract, involving the uterus, fallopian tubes, ovaries, and/or pelvic peritoneum and usually caused by Chlamydia trachomatis',
#     'document': 'http://www.ncbi.nlm.nih.gov/pubmed/36759099',
#     'offsetInBeginSection': 535,
#     'offsetInEndSection': 703}],
#   'id': '67d7fded18b1e36f2e000042',
#   'type': 'list',
#   'body': 'Symptoms of chlamydia genital infection in women.'}]

# %%
def parse_question(questions):
    """
    Parses the questions to extract relevant information.
    
    Parameters:
        questions (List[dict]): A list of question dictionaries.
    
    Returns:
        List[dict]: A list of parsed question dictionaries.
    """
    parsed_questions = []
    for question in questions:
        parsed_questions.append({
            "id": question["id"],
            "body": question["body"],
            "documents": [doc.replace(base_pid_url, '') for doc in question["documents"]],
            "snippets": question["snippets"],
        })
    return parsed_questions

# %%
def get_questions_text(questions):
    """
    Extracts the text of the questions from the parsed questions.
    
    Parameters:
        parsed_questions (List[dict]): A list of parsed question dictionaries.
    
    Returns:
        List[str]: A list of question texts.
    """
    return [{'id': question['id'],
              'body': question["body"]} for question in questions]

def get_ground_truth_documents(questions):
    """
    Extracts the ground truth from the parsed questions.
    
    Parameters:
        parsed_questions (List[dict]): A list of parsed question dictionaries.
    
    Returns:
        List[str]: A list of ground truth texts.
    """
    ground_truth = {}
    for question in questions:
        ground_truth[question['id']] = set(question["documents"])
    return ground_truth

# %%
parsed_questions = parse_question(questions=questions)
#parsed_questions[0:3]

# %%
ground_truth_documents = get_ground_truth_documents(questions=parsed_questions)
#ground_truth_documents

# %%
questions_texts = get_questions_text(questions=parsed_questions)

# %%
# compare the length of the questions and the ground truth documents
print(f"Number of questions: {len(questions_texts)}")
print(f"Number of ground truth documents: {len(ground_truth_documents)}")
# Out:
# Number of questions: 85
# Number of ground truth documents: 85

# %%
def save_to_json(data, file_path):
    """
    Saves the data to a JSON file.
    
    Parameters:
        data (any): The data to save.
        file_path (str): Path to the JSON file.
    """
    try:
        with open(file_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=4)
        print(f"Saved data to {file_path}")
    except Exception as e:
        print(f"Failed to save data: {e}")

# %%
save_to_json(data=parsed_questions, file_path="parsed_questions.json")
# Out:
# Saved data to parsed_questions.json

# %%
def parse_pubmed_abstracts_from_xml(xml_string):
    """
    Parse PubMed XML and extract PMID, title, and abstract.

    Args:
        xml_string (str): XML data as string from Entrez.efetch(..., retmode="xml")

    Returns:
        List[Dict]: List of articles with keys: 'pid', 'title', 'abstract'
    """
    root = ET.fromstring(xml_string)
    articles = []

    for article in root.findall(".//PubmedArticle"):
        pid = article.findtext(".//PMID")
        title = article.findtext(".//ArticleTitle")

        # Handle multiple AbstractText parts (can have labels, e.g. "BACKGROUND", "METHODS", etc.)
        abstract_parts = article.findall(".//Abstract/AbstractText")
        abstract = " ".join([part.text for part in abstract_parts if part.text])

        articles.append({
            "pid": pid,
            "title": title,
            "abstract": abstract
        })

    return articles

# %%
# Generate semantic queries
def generate_queries_BERT(question, model, keyphrase_ngram_range=(1, 3), top_n=7):
    keywords = model.extract_keywords(question, keyphrase_ngram_range=keyphrase_ngram_range, stop_words='english', top_n=top_n)
    return [kw for kw, _ in keywords]

'''
def generate_queries_BERT(question, model=KeyBERT('all-MiniLM-L6-v2'), keyphrase_ngram_range=(1, 3), top_n=7):
    keywords = model.extract_keywords(question, keyphrase_ngram_range=keyphrase_ngram_range, stop_words='english', top_n=top_n)

    cleaned_keywords = []

    for phrase, _ in keywords:
        doc = nlp(phrase)

        # Remove verbs, auxiliaries, stopwords, and short words
        filtered_tokens = [
            token.lemma_.lower()
            for token in doc
            if token.pos_ not in {"VERB", "AUX"}
            and token.lemma_.lower() not in ENGLISH_STOP_WORDS
            and len(token.lemma_) > 2
        ]

        # Reconstruct cleaned phrase
        cleaned_phrase = " ".join(filtered_tokens).strip()

        if cleaned_phrase:  # Only keep non-empty results
            cleaned_keywords.append(cleaned_phrase)

    return list(sorted(set(cleaned_keywords)))  # deduplicate + sort
'''

# Search PubMed for each query
def search_pubmed(query, retmax=500):
    handle = Entrez.esearch(db="pubmed", term=query, retmax=retmax)
    record = Entrez.read(handle)
    handle.close()
    return record["IdList"]

# Fetch details in JSON and decode
def fetch_details(id_list):
    ids = ",".join(id_list)
    handle = Entrez.efetch(db="pubmed", id=ids, rettype="medline", retmode="xml")
    xml_data = handle.read()  
    handle.close()
    records = parse_pubmed_abstracts_from_xml(xml_data)
    return records

# %%
questions = get_questions_text(questions=parsed_questions)
for i in range(len(questions)):
    if questions[i]['id'] == "516c0ebc298dcd4e5100006e":
        print(i)

# %%
import random
import time
import json
import os
import shutil
from datetime import datetime

# 🔧 Parameters
BATCH_SIZE = 5
RESULTS_FILE = output_file_path
CHECKPOINT_FILE = "checkpoint.json"

# 📌 Load checkpoint if it exists
if os.path.exists(CHECKPOINT_FILE):
    with open(CHECKPOINT_FILE, "r") as f:
        checkpoint = json.load(f)
        start_index = checkpoint.get("last_index", 0) + 1
else:
    start_index = 0

# 🚀 Initialize
questions = get_questions_text(questions=parsed_questions)
kw_model = KeyBERT(model='all-MiniLM-L6-v2')
results = []

# 📝 Resume from saved results file if available
if os.path.exists(RESULTS_FILE):
    try:
        with open(RESULTS_FILE, "r") as f:
            results = json.load(f)["results"]
    except json.JSONDecodeError:
        print("⚡ Warning: Results file is corrupted. Starting with empty results.")
        results = []

# 🔁 Process from start_index
for i in range(start_index, len(questions)):
    question = questions[i]
    qid = question['id']
    print(f"❓[{i+1}/{len(questions)}] Question: {question['body']}")
    
    queries = generate_queries_BERT(question['body'], keyphrase_ngram_range=(1, 10), top_n=20, model=kw_model)
    print(f"🧠 Generated Queries: {queries}")
    
    all_ids = set()
    for q in queries:
        try:
            ids = search_pubmed(q, retmax=20000)
            all_ids.update(ids)
            time.sleep(0.7)
        except Exception as e:
            print(f"⚠️ Failed to search PubMed with query '{q}': {e}")
    
    print(f"✅ Found {len(all_ids)} unique PMIDs for this question.")
    
    ground_truth = ground_truth_documents[qid]
    found_gt = ground_truth.intersection(all_ids)
    print(f"🎯 Found {len(found_gt)} out of {len(ground_truth)} ground truth PMIDs.")
    
    non_gt = list(all_ids - found_gt)
    sampled_random = random.sample(non_gt, min(150, len(non_gt)))
    
    selected_ids = list(found_gt) + sampled_random
    print(f"📦 Fetching details for {len(selected_ids)} PMIDs (GT + Random Sample)")

    try:
        details = fetch_details(selected_ids)
    except Exception as e:
        print(f"❌ Error fetching details: {e}")
        details = []

    results.append({
        "qid": qid,
        "question": question['body'],
        "queries": queries,
        "ground_truth": list(ground_truth),
        "ground_truth_total": len(ground_truth),
        "ground_truth_found": list(found_gt),
        "ground_truth_found_count": len(found_gt),
        "random_sampled_count": len(sampled_random),
        "random_sampled_pmids": sampled_random,
        "selected_pmids": selected_ids,
        "error_rate": {
            "value": len(found_gt) / len(ground_truth) if len(ground_truth) > 0 else 0,
            "details": f"{len(found_gt)} found out of {len(ground_truth)}"
        },
        "details": details
    })

    print(f"✅ Saved result for question \"{question['body']}\"\n")

    # 💾 Save batch and update checkpoint
    if (i + 1) % BATCH_SIZE == 0 or i == len(questions) - 1:
        print(f"📁 Saving batch at question {i+1}...")

        # Save to a temporary file first
        temp_file = RESULTS_FILE + ".tmp"
        with open(temp_file, "w") as f:
            json.dump({"results": results}, f, indent=2)

        # Move temp file to final results file (atomic save)
        shutil.move(temp_file, RESULTS_FILE)

        # Save checkpoint
        with open(CHECKPOINT_FILE, "w") as f:
            json.dump({"last_index": i}, f)

        print(f"✅ Batch saved and checkpoint updated at index {i}\n")
# Out:
# ❓[1/85] Question: Should Zotiraciclib be used for glioblastoma?
# 🧠 Generated Queries: ['zotiraciclib used glioblastoma', 'used glioblastoma', 'zotiraciclib used', 'glioblastoma', 'zotiraciclib', 'used']
# ✅ Found 10003 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Should Zotiraciclib be used for glioblastoma?"
#
# ❓[2/85] Question: Is bronchiectasis a chronic or acute condition?
# 🧠 Generated Queries: ['bronchiectasis chronic acute condition', 'bronchiectasis chronic acute', 'bronchiectasis chronic', 'bronchiectasis', 'chronic acute condition', 'chronic acute', 'acute condition', 'chronic', 'acute', 'condition']
# ✅ Found 54729 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is bronchiectasis a chronic or acute condition?"
#
# ❓[3/85] Question: Do biopharmaceuticals have a role in the treatment of depression?
# 🧠 Generated Queries: ['biopharmaceuticals role treatment depression', 'treatment depression', 'biopharmaceuticals role', 'biopharmaceuticals role treatment', 'role treatment depression', 'biopharmaceuticals', 'depression', 'treatment', 'role treatment', 'role']
# ✅ Found 71874 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Do biopharmaceuticals have a role in the treatment of depression?"
#
# ❓[4/85] Question: Are microglia involved in synaptic pruning during development?
# 🧠 Generated Queries: ['microglia involved synaptic pruning development', 'microglia involved synaptic pruning', 'microglia involved synaptic', 'microglia involved', 'microglia', 'involved synaptic pruning development', 'synaptic pruning development', 'involved synaptic pruning', 'synaptic pruning', 'synaptic', 'involved synaptic', 'pruning development', 'pruning', 'development', 'involved']
# ✅ Found 79944 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Are microglia involved in synaptic pruning during development?"
#
# ❓[5/85] Question: What is the target of fezolinetant?
# 🧠 Generated Queries: ['target fezolinetant', 'fezolinetant', 'target']
# ✅ Found 10107 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the target of fezolinetant?"
#
# 📁 Saving batch at question 5...
# ✅ Batch saved and checkpoint updated at index 4
#
# ❓[6/85] Question: What complication of pregnancy was treated with  Diethylstilbestrol
# 🧠 Generated Queries: ['complication pregnancy treated diethylstilbestrol', 'pregnancy treated diethylstilbestrol', 'treated diethylstilbestrol', 'diethylstilbestrol', 'complication pregnancy treated', 'pregnancy treated', 'complication pregnancy', 'pregnancy', 'treated', 'complication']
# ✅ Found 53874 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What complication of pregnancy was treated with  Diethylstilbestrol"
#
# ❓[7/85] Question: Biopharmaceuticals for pediatric bronchiolitis.
# 🧠 Generated Queries: ['biopharmaceuticals pediatric bronchiolitis', 'pediatric bronchiolitis', 'biopharmaceuticals pediatric', 'bronchiolitis', 'biopharmaceuticals', 'pediatric']
# ✅ Found 40041 unique PMIDs for this question.
# 🎯 Found 0 out of 3 ground truth PMIDs.
# 📦 Fetching details for 150 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Biopharmaceuticals for pediatric bronchiolitis."
#
# ❓[8/85] Question: What is the cancer-immunity cycle?
# 🧠 Generated Queries: ['cancer immunity cycle', 'immunity cycle', 'cancer immunity', 'cancer', 'immunity', 'cycle']
# ✅ Found 48041 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the cancer-immunity cycle?"
#
# ❓[9/85] Question: What is the mechanism of action of Iptacopan?
# 🧠 Generated Queries: ['mechanism action iptacopan', 'action iptacopan', 'iptacopan', 'mechanism action', 'mechanism', 'action']
# ✅ Found 25322 unique PMIDs for this question.
# 🎯 Found 5 out of 5 ground truth PMIDs.
# 📦 Fetching details for 155 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the mechanism of action of Iptacopan?"
#
# ❓[10/85] Question: What is the previous acronym for Metabolic Dysfunction-Associated Steatotic Liver Diasease  (MASLD)?
# 🧠 Generated Queries: ['previous acronym metabolic dysfunction associated steatotic liver diasease masld', 'acronym metabolic dysfunction associated steatotic liver diasease masld', 'previous acronym metabolic dysfunction associated steatotic liver diasease', 'acronym metabolic dysfunction associated steatotic liver diasease', 'metabolic dysfunction associated steatotic liver diasease masld', 'dysfunction associated steatotic liver diasease masld', 'previous acronym metabolic dysfunction associated steatotic liver', 'associated steatotic liver diasease masld', 'acronym metabolic dysfunction associated steatotic liver', 'steatotic liver diasease masld', 'metabolic dysfunction associated steatotic liver diasease', 'liver diasease masld', 'previous acronym metabolic dysfunction associated steatotic', 'acronym metabolic dysfunction associated steatotic', 'dysfunction associated steatotic liver diasease', 'associated steatotic liver diasease', 'steatotic liver diasease', 'liver diasease', 'previous acronym metabolic dysfunction associated', 'previous acronym metabolic dysfunction']
# ✅ Found 17 unique PMIDs for this question.
# 🎯 Found 0 out of 1 ground truth PMIDs.
# 📦 Fetching details for 17 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the previous acronym for Metabolic Dysfunction-Associated Steatotic Liver Diasease  (MASLD)?"
#
# 📁 Saving batch at question 10...
# ✅ Batch saved and checkpoint updated at index 9
#
# ❓[11/85] Question: What is the genetic basis of addiction?
# 🧠 Generated Queries: ['genetic basis addiction', 'addiction', 'basis addiction', 'genetic', 'genetic basis', 'basis']
# ✅ Found 41066 unique PMIDs for this question.
# 🎯 Found 2 out of 4 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the genetic basis of addiction?"
#
# ❓[12/85] Question: Do natural killer (NK) cells require antigen presentation to eliminate cancer cells?
# 🧠 Generated Queries: ['natural killer nk cells require antigen presentation eliminate cancer', 'natural killer nk cells require antigen presentation eliminate cancer cells', 'killer nk cells require antigen presentation eliminate cancer', 'killer nk cells require antigen presentation eliminate cancer cells', 'natural killer nk cells require antigen presentation eliminate', 'killer nk cells require antigen presentation eliminate', 'natural killer nk cells require antigen presentation', 'nk cells require antigen presentation eliminate cancer cells', 'nk cells require antigen presentation eliminate cancer', 'killer nk cells require antigen presentation', 'natural killer nk cells require antigen', 'killer nk cells require antigen', 'nk cells require antigen presentation eliminate', 'natural killer nk cells require', 'nk cells require antigen presentation', 'nk cells require antigen', 'killer nk cells require', 'natural killer nk cells', 'cells require antigen presentation eliminate cancer cells', 'killer nk cells']
# ✅ Found 16426 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Do natural killer (NK) cells require antigen presentation to eliminate cancer cells?"
#
# ❓[13/85] Question: What are the targets of blinatumomab?
# 🧠 Generated Queries: ['targets blinatumomab', 'blinatumomab', 'targets']
# ✅ Found 11109 unique PMIDs for this question.
# 🎯 Found 5 out of 5 ground truth PMIDs.
# 📦 Fetching details for 155 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are the targets of blinatumomab?"
#
# ❓[14/85] Question: What is the relationship between bronchiectasis and Erdosteine?
# 🧠 Generated Queries: ['relationship bronchiectasis erdosteine', 'bronchiectasis erdosteine', 'bronchiectasis', 'relationship bronchiectasis', 'erdosteine', 'relationship']
# ✅ Found 20374 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the relationship between bronchiectasis and Erdosteine?"
#
# ❓[15/85] Question: Can GLP-1 receptor agonists be used for obesity in children under 10 years of age?
# 🧠 Generated Queries: ['glp receptor agonists used obesity children 10 years age', 'glp receptor agonists used obesity children 10 years', 'glp receptor agonists used obesity children 10', 'glp receptor agonists used obesity children', 'glp receptor agonists used obesity', 'receptor agonists used obesity children 10 years age', 'receptor agonists used obesity children 10 years', 'receptor agonists used obesity children 10', 'receptor agonists used obesity children', 'agonists used obesity children 10 years age', 'agonists used obesity children 10 years', 'agonists used obesity children 10', 'agonists used obesity children', 'receptor agonists used obesity', 'glp receptor agonists used', 'glp receptor agonists', 'agonists used obesity', 'used obesity children 10 years age', 'used obesity children 10 years', 'obesity children 10 years age']
# ✅ Found 29294 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Can GLP-1 receptor agonists be used for obesity in children under 10 years of age?"
#
# 📁 Saving batch at question 15...
# ✅ Batch saved and checkpoint updated at index 14
#
# ❓[16/85] Question: Are radiomic features useful in predicting survival in glioblastoma patients?
# 🧠 Generated Queries: ['radiomic features useful predicting survival glioblastoma patients', 'radiomic features useful predicting survival glioblastoma', 'features useful predicting survival glioblastoma patients', 'features useful predicting survival glioblastoma', 'useful predicting survival glioblastoma patients', 'predicting survival glioblastoma patients', 'useful predicting survival glioblastoma', 'predicting survival glioblastoma', 'survival glioblastoma patients', 'radiomic features useful predicting survival', 'survival glioblastoma', 'glioblastoma patients', 'glioblastoma', 'radiomic features useful predicting', 'features useful predicting survival', 'radiomic features useful', 'radiomic features', 'useful predicting survival', 'predicting survival', 'radiomic']
# ✅ Found 54709 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Are radiomic features useful in predicting survival in glioblastoma patients?"
#
# ❓[17/85] Question: In patients with acute liver failure associated with  paracetamol overdose does  N‐acetylcysteine treatment improve survival?.
# 🧠 Generated Queries: ['liver failure associated paracetamol overdose does acetylcysteine treatment improve survival', 'acute liver failure associated paracetamol overdose does acetylcysteine treatment improve', 'patients acute liver failure associated paracetamol overdose does acetylcysteine treatment', 'liver failure associated paracetamol overdose does acetylcysteine treatment improve', 'acute liver failure associated paracetamol overdose does acetylcysteine treatment', 'liver failure associated paracetamol overdose does acetylcysteine treatment', 'patients acute liver failure associated paracetamol overdose does acetylcysteine', 'acute liver failure associated paracetamol overdose does acetylcysteine', 'liver failure associated paracetamol overdose does acetylcysteine', 'failure associated paracetamol overdose does acetylcysteine treatment improve survival', 'associated paracetamol overdose does acetylcysteine treatment improve survival', 'paracetamol overdose does acetylcysteine treatment improve survival', 'failure associated paracetamol overdose does acetylcysteine treatment improve', 'patients acute liver failure associated paracetamol overdose does', 'paracetamol overdose does acetylcysteine treatment improve', 'failure associated paracetamol overdose does acetylcysteine treatment', 'associated paracetamol overdose does acetylcysteine treatment improve', 'patients acute liver failure associated paracetamol overdose', 'liver failure associated paracetamol overdose does', 'acute liver failure associated paracetamol overdose does']
# ✅ Found 414 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "In patients with acute liver failure associated with  paracetamol overdose does  N‐acetylcysteine treatment improve survival?."
#
# ❓[18/85] Question: What is the pharmacological treatment of urinary schistosomiasis?
# 🧠 Generated Queries: ['pharmacological treatment urinary schistosomiasis', 'treatment urinary schistosomiasis', 'urinary schistosomiasis', 'schistosomiasis', 'pharmacological treatment urinary', 'treatment urinary', 'pharmacological treatment', 'pharmacological', 'treatment', 'urinary']
# ✅ Found 57479 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the pharmacological treatment of urinary schistosomiasis?"
#
# ❓[19/85] Question: What types of features are typically extracted in radiomics?
# 🧠 Generated Queries: ['types features typically extracted radiomics', 'features typically extracted radiomics', 'typically extracted radiomics', 'extracted radiomics', 'radiomics', 'features typically extracted', 'types features typically extracted', 'features typically', 'types features typically', 'types features', 'features', 'typically extracted', 'extracted', 'types', 'typically']
# ✅ Found 80810 unique PMIDs for this question.
# 🎯 Found 5 out of 5 ground truth PMIDs.
# 📦 Fetching details for 155 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What types of features are typically extracted in radiomics?"
#
# ❓[20/85] Question: What diseases are treated with fecal transplants?
# 🧠 Generated Queries: ['diseases treated fecal transplants', 'treated fecal transplants', 'fecal transplants', 'diseases treated fecal', 'treated fecal', 'diseases treated', 'transplants', 'diseases', 'fecal', 'treated']
# ✅ Found 55781 unique PMIDs for this question.
# 🎯 Found 5 out of 5 ground truth PMIDs.
# 📦 Fetching details for 155 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What diseases are treated with fecal transplants?"
#
# 📁 Saving batch at question 20...
# ✅ Batch saved and checkpoint updated at index 19
#
# ❓[21/85] Question: Can sertraline be used in children under 10?
# 🧠 Generated Queries: ['sertraline used children 10', 'sertraline used children', 'sertraline used', 'sertraline', 'used children 10', 'children 10', 'used children', 'children', '10', 'used']
# ✅ Found 24549 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Can sertraline be used in children under 10?"
#
# ❓[22/85] Question: Which cells are the primary antigen-presenting cells?
# 🧠 Generated Queries: ['cells primary antigen presenting cells', 'primary antigen presenting cells', 'cells primary antigen', 'cells primary antigen presenting', 'antigen presenting cells', 'primary antigen', 'primary antigen presenting', 'cells primary', 'antigen presenting', 'antigen', 'presenting cells', 'cells', 'primary', 'presenting']
# ✅ Found 94666 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which cells are the primary antigen-presenting cells?"
#
# ❓[23/85] Question: Do misfolded and aggregated proteins build up in neurodegenerative illnesses, which causes neuronal dysfunction and ultimately neuronal death?
# 🧠 Generated Queries: ['misfolded aggregated proteins build neurodegenerative illnesses causes neuronal dysfunction ultimately', 'misfolded aggregated proteins build neurodegenerative illnesses causes neuronal dysfunction', 'misfolded aggregated proteins build neurodegenerative illnesses causes neuronal', 'misfolded aggregated proteins build neurodegenerative illnesses causes', 'misfolded aggregated proteins build neurodegenerative illnesses', 'aggregated proteins build neurodegenerative illnesses causes neuronal dysfunction ultimately', 'aggregated proteins build neurodegenerative illnesses causes neuronal dysfunction ultimately neuronal', 'aggregated proteins build neurodegenerative illnesses causes neuronal dysfunction', 'aggregated proteins build neurodegenerative illnesses causes neuronal', 'aggregated proteins build neurodegenerative illnesses causes', 'misfolded aggregated proteins build neurodegenerative', 'aggregated proteins build neurodegenerative illnesses', 'proteins build neurodegenerative illnesses causes neuronal dysfunction ultimately neuronal death', 'proteins build neurodegenerative illnesses causes neuronal dysfunction ultimately neuronal', 'proteins build neurodegenerative illnesses causes neuronal dysfunction ultimately', 'proteins build neurodegenerative illnesses causes neuronal dysfunction', 'aggregated proteins build neurodegenerative', 'proteins build neurodegenerative illnesses causes neuronal', 'proteins build neurodegenerative illnesses', 'proteins build neurodegenerative illnesses causes']
# ✅ Found 462 unique PMIDs for this question.
# 🎯 Found 0 out of 3 ground truth PMIDs.
# 📦 Fetching details for 150 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Do misfolded and aggregated proteins build up in neurodegenerative illnesses, which causes neuronal dysfunction and ultimately neuronal death?"
#
# ❓[24/85] Question: Differential traits of autism spectrum disorders in girls.
# 🧠 Generated Queries: ['differential traits autism spectrum disorders girls', 'traits autism spectrum disorders girls', 'autism spectrum disorders girls', 'differential traits autism spectrum disorders', 'traits autism spectrum disorders', 'differential traits autism spectrum', 'traits autism spectrum', 'differential traits autism', 'traits autism', 'autism spectrum', 'autism spectrum disorders', 'autism', 'disorders girls', 'spectrum disorders girls', 'disorders', 'traits', 'spectrum disorders', 'differential traits', 'girls', 'spectrum']
# ✅ Found 82325 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Differential traits of autism spectrum disorders in girls."
#
# ❓[25/85] Question: What are the major classes of immunoglobulins?
# 🧠 Generated Queries: ['major classes immunoglobulins', 'classes immunoglobulins', 'immunoglobulins', 'major classes', 'classes', 'major']
# ✅ Found 55597 unique PMIDs for this question.
# 🎯 Found 1 out of 4 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are the major classes of immunoglobulins?"
#
# 📁 Saving batch at question 25...
# ✅ Batch saved and checkpoint updated at index 24
#
# ❓[26/85] Question: Please list the DORA type drugs
# 🧠 Generated Queries: ['list dora type drugs', 'dora type drugs', 'list dora type', 'dora type', 'list dora', 'type drugs', 'dora', 'drugs', 'type', 'list']
# ✅ Found 40620 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Please list the DORA type drugs"
#
# ❓[27/85] Question: Is takotsubo cardiomyopathy more common in men?
# 🧠 Generated Queries: ['takotsubo cardiomyopathy common men', 'takotsubo cardiomyopathy common', 'takotsubo cardiomyopathy', 'cardiomyopathy common men', 'cardiomyopathy common', 'cardiomyopathy', 'takotsubo', 'common men', 'men', 'common']
# ✅ Found 53735 unique PMIDs for this question.
# 🎯 Found 5 out of 5 ground truth PMIDs.
# 📦 Fetching details for 155 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is takotsubo cardiomyopathy more common in men?"
#
# ❓[28/85] Question: What is radiomics?
# 🧠 Generated Queries: ['radiomics']
# ✅ Found 9999 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is radiomics?"
#
# ❓[29/85] Question: What is the cause of Fibromyalgia?
# 🧠 Generated Queries: ['cause fibromyalgia', 'fibromyalgia', 'cause']
# ✅ Found 22585 unique PMIDs for this question.
# 🎯 Found 6 out of 6 ground truth PMIDs.
# 📦 Fetching details for 156 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the cause of Fibromyalgia?"
#
# ❓[30/85] Question: Recommended prevention of osteoporosis in postmenopausal women.
# 🧠 Generated Queries: ['recommended prevention osteoporosis postmenopausal women', 'prevention osteoporosis postmenopausal women', 'recommended prevention osteoporosis postmenopausal', 'prevention osteoporosis postmenopausal', 'osteoporosis postmenopausal women', 'prevention osteoporosis', 'recommended prevention osteoporosis', 'osteoporosis postmenopausal', 'osteoporosis', 'postmenopausal women', 'postmenopausal', 'recommended prevention', 'prevention', 'women', 'recommended']
# ✅ Found 78607 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Recommended prevention of osteoporosis in postmenopausal women."
#
# 📁 Saving batch at question 30...
# ✅ Batch saved and checkpoint updated at index 29
#
# ❓[31/85] Question: What are the functions of astrocytes in the CNS?
# 🧠 Generated Queries: ['functions astrocytes cns', 'astrocytes cns', 'functions astrocytes', 'astrocytes', 'cns', 'functions']
# ✅ Found 40628 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are the functions of astrocytes in the CNS?"
#
# ❓[32/85] Question: Is Laparoscopic salpingectomy used to treat testicular cancer?
# 🧠 Generated Queries: ['laparoscopic salpingectomy used treat testicular cancer', 'laparoscopic salpingectomy used treat testicular', 'salpingectomy used treat testicular cancer', 'salpingectomy used treat testicular', 'laparoscopic salpingectomy used treat', 'used treat testicular cancer', 'laparoscopic salpingectomy used', 'treat testicular cancer', 'laparoscopic salpingectomy', 'salpingectomy used', 'salpingectomy used treat', 'used treat testicular', 'testicular cancer', 'treat testicular', 'salpingectomy', 'laparoscopic', 'testicular', 'cancer', 'used treat', 'treat']
# ✅ Found 56380 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is Laparoscopic salpingectomy used to treat testicular cancer?"
#
# ❓[33/85] Question: Factors that are associated with thyroid cancer.
# 🧠 Generated Queries: ['factors associated thyroid cancer', 'associated thyroid cancer', 'factors associated thyroid', 'thyroid cancer', 'associated thyroid', 'thyroid', 'cancer', 'factors associated', 'factors', 'associated']
# ✅ Found 61475 unique PMIDs for this question.
# 🎯 Found 3 out of 4 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Factors that are associated with thyroid cancer."
#
# ❓[34/85] Question: Do glioblastoma tumors have a high degree of lymphocyte infiltration?
# 🧠 Generated Queries: ['glioblastoma tumors high degree lymphocyte infiltration', 'glioblastoma tumors high degree lymphocyte', 'tumors high degree lymphocyte infiltration', 'tumors high degree lymphocyte', 'glioblastoma tumors high degree', 'glioblastoma tumors high', 'glioblastoma tumors', 'high degree lymphocyte infiltration', 'glioblastoma', 'degree lymphocyte infiltration', 'lymphocyte infiltration', 'high degree lymphocyte', 'lymphocyte', 'degree lymphocyte', 'tumors high degree', 'tumors high', 'tumors', 'infiltration', 'high degree', 'high']
# ✅ Found 99247 unique PMIDs for this question.
# 🎯 Found 0 out of 1 ground truth PMIDs.
# 📦 Fetching details for 150 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Do glioblastoma tumors have a high degree of lymphocyte infiltration?"
#
# ❓[35/85] Question: Please list the types of Videolaryngoscopy for adults undergoing tracheal intubation
# 🧠 Generated Queries: ['list types videolaryngoscopy adults undergoing tracheal intubation', 'types videolaryngoscopy adults undergoing tracheal intubation', 'videolaryngoscopy adults undergoing tracheal intubation', 'types videolaryngoscopy adults undergoing tracheal', 'list types videolaryngoscopy adults undergoing tracheal', 'videolaryngoscopy adults undergoing tracheal', 'types videolaryngoscopy adults undergoing', 'list types videolaryngoscopy adults undergoing', 'types videolaryngoscopy adults', 'videolaryngoscopy adults undergoing', 'types videolaryngoscopy', 'list types videolaryngoscopy adults', 'videolaryngoscopy adults', 'videolaryngoscopy', 'tracheal intubation', 'undergoing tracheal intubation', 'adults undergoing tracheal intubation', 'list types videolaryngoscopy', 'adults undergoing tracheal', 'undergoing tracheal']
# ✅ Found 16645 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Please list the types of Videolaryngoscopy for adults undergoing tracheal intubation"
#
# 📁 Saving batch at question 35...
# ✅ Batch saved and checkpoint updated at index 34
#
# ❓[36/85] Question: Is Electroconvulsive Therapy used for any type of epilepsy?
# 🧠 Generated Queries: ['electroconvulsive therapy used type epilepsy', 'electroconvulsive therapy used type', 'therapy used type epilepsy', 'electroconvulsive therapy used', 'electroconvulsive therapy', 'used type epilepsy', 'type epilepsy', 'epilepsy', 'electroconvulsive', 'therapy used type', 'therapy used', 'therapy', 'used type', 'used', 'type']
# ✅ Found 59026 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is Electroconvulsive Therapy used for any type of epilepsy?"
#
# ❓[37/85] Question: What are the characteristics of the M1/M2 macrophage polarization paradigm in the tumor microenvironment?
# 🧠 Generated Queries: ['characteristics m1 m2 macrophage polarization paradigm tumor microenvironment', 'm1 m2 macrophage polarization paradigm tumor microenvironment', 'm2 macrophage polarization paradigm tumor microenvironment', 'characteristics m1 m2 macrophage polarization paradigm tumor', 'm1 m2 macrophage polarization paradigm tumor', 'macrophage polarization paradigm tumor microenvironment', 'm2 macrophage polarization paradigm tumor', 'm1 m2 macrophage polarization paradigm', 'characteristics m1 m2 macrophage polarization paradigm', 'm2 macrophage polarization paradigm', 'm1 m2 macrophage polarization', 'characteristics m1 m2 macrophage polarization', 'm2 macrophage polarization', 'macrophage polarization paradigm tumor', 'macrophage polarization paradigm', 'polarization paradigm tumor microenvironment', 'macrophage polarization', 'characteristics m1 m2 macrophage', 'm1 m2 macrophage', 'm2 macrophage']
# ✅ Found 24488 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are the characteristics of the M1/M2 macrophage polarization paradigm in the tumor microenvironment?"
#
# ❓[38/85] Question: What is Nissen fundoplication
# 🧠 Generated Queries: ['nissen fundoplication', 'fundoplication', 'nissen']
# ✅ Found 13713 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is Nissen fundoplication"
#
# ❓[39/85] Question: What are the genetic variants in Turner syndrome?
# 🧠 Generated Queries: ['genetic variants turner syndrome', 'variants turner syndrome', 'genetic variants turner', 'turner syndrome', 'genetic variants', 'variants turner', 'genetic', 'syndrome', 'turner', 'variants']
# ✅ Found 50446 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are the genetic variants in Turner syndrome?"
#
# ❓[40/85] Question: What organelle is responsible for ATP production?
# 🧠 Generated Queries: ['organelle responsible atp production', 'organelle responsible atp', 'responsible atp production', 'atp production', 'responsible atp', 'atp', 'organelle responsible', 'organelle', 'production', 'responsible']
# ✅ Found 64007 unique PMIDs for this question.
# 🎯 Found 2 out of 4 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What organelle is responsible for ATP production?"
#
# 📁 Saving batch at question 40...
# ✅ Batch saved and checkpoint updated at index 39
#
# ❓[41/85] Question: What age group is commonly affected by biliary atresia?
# 🧠 Generated Queries: ['age group commonly affected biliary atresia', 'age group commonly affected biliary', 'group commonly affected biliary atresia', 'commonly affected biliary atresia', 'biliary atresia', 'affected biliary atresia', 'group commonly affected biliary', 'commonly affected biliary', 'affected biliary', 'biliary', 'age group commonly affected', 'age group commonly', 'age group', 'atresia', 'group commonly affected', 'commonly affected', 'age', 'affected', 'group commonly', 'group']
# ✅ Found 94489 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What age group is commonly affected by biliary atresia?"
#
# ❓[42/85] Question: Manifestations of gluten allergy/intolerance.
# 🧠 Generated Queries: ['manifestations gluten allergy intolerance', 'manifestations gluten allergy', 'gluten allergy intolerance', 'gluten allergy', 'manifestations gluten', 'allergy intolerance', 'allergy', 'gluten', 'intolerance', 'manifestations']
# ✅ Found 45069 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Manifestations of gluten allergy/intolerance."
#
# ❓[43/85] Question: Do T cells enter the CNS in healthy individuals?
# 🧠 Generated Queries: ['cells enter cns healthy individuals', 'cells enter cns healthy', 'cells enter cns', 'enter cns healthy individuals', 'enter cns healthy', 'cns healthy individuals', 'cns healthy', 'enter cns', 'cells enter', 'cns', 'cells', 'healthy individuals', 'healthy', 'enter', 'individuals']
# ✅ Found 68255 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Do T cells enter the CNS in healthy individuals?"
#
# ❓[44/85] Question: Is urolithiasis the same thing as kidney stones?
# 🧠 Generated Queries: ['urolithiasis thing kidney stones', 'urolithiasis thing kidney', 'kidney stones', 'urolithiasis', 'urolithiasis thing', 'thing kidney stones', 'kidney', 'stones', 'thing kidney', 'thing']
# ✅ Found 41067 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is urolithiasis the same thing as kidney stones?"
#
# ❓[45/85] Question: How do you acquire Legionella pneumophila?
# 🧠 Generated Queries: ['acquire legionella pneumophila', 'legionella pneumophila', 'acquire legionella', 'legionella', 'pneumophila', 'acquire']
# ✅ Found 20799 unique PMIDs for this question.
# 🎯 Found 5 out of 5 ground truth PMIDs.
# 📦 Fetching details for 155 PMIDs (GT + Random Sample)
# ✅ Saved result for question "How do you acquire Legionella pneumophila?"
#
# 📁 Saving batch at question 45...
# ✅ Batch saved and checkpoint updated at index 44
#
# ❓[46/85] Question: What is the role of the choroid plexus in immune surveillance?
# 🧠 Generated Queries: ['role choroid plexus immune surveillance', 'choroid plexus immune surveillance', 'role choroid plexus immune', 'choroid plexus immune', 'role choroid plexus', 'choroid plexus', 'plexus immune surveillance', 'plexus immune', 'role choroid', 'choroid', 'immune surveillance', 'immune', 'plexus', 'surveillance', 'role']
# ✅ Found 67018 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the role of the choroid plexus in immune surveillance?"
#
# ❓[47/85] Question: Has Antibiotic use induced hiccups?
# 🧠 Generated Queries: ['antibiotic use induced hiccups', 'induced hiccups', 'use induced hiccups', 'antibiotic use induced', 'antibiotic use', 'hiccups', 'antibiotic', 'use induced', 'induced', 'use']
# ✅ Found 39659 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Has Antibiotic use induced hiccups?"
#
# ❓[48/85] Question: What do snake antivenoms contain?
# 🧠 Generated Queries: ['snake antivenoms contain', 'snake antivenoms', 'antivenoms contain', 'antivenoms', 'snake', 'contain']
# ✅ Found 24293 unique PMIDs for this question.
# 🎯 Found 7 out of 7 ground truth PMIDs.
# 📦 Fetching details for 157 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What do snake antivenoms contain?"
#
# ❓[49/85] Question: Are microglia derived from the same lineage as peripheral macrophages?
# 🧠 Generated Queries: ['microglia derived lineage peripheral macrophages', 'microglia derived lineage peripheral', 'microglia derived lineage', 'microglia derived', 'derived lineage peripheral macrophages', 'microglia', 'lineage peripheral macrophages', 'peripheral macrophages', 'macrophages', 'derived lineage peripheral', 'lineage peripheral', 'derived lineage', 'lineage', 'derived', 'peripheral']
# ✅ Found 81186 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Are microglia derived from the same lineage as peripheral macrophages?"
#
# ❓[50/85] Question: How does a gastric pacemaker work?
# 🧠 Generated Queries: ['does gastric pacemaker', 'gastric pacemaker work', 'gastric pacemaker', 'does gastric pacemaker work', 'pacemaker work', 'pacemaker', 'does gastric', 'gastric', 'work', 'does']
# ✅ Found 31577 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "How does a gastric pacemaker work?"
#
# 📁 Saving batch at question 50...
# ✅ Batch saved and checkpoint updated at index 49
#
# ❓[51/85] Question: Can newborns have glaucoma?
# 🧠 Generated Queries: ['newborns glaucoma', 'glaucoma', 'newborns']
# ✅ Found 21456 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Can newborns have glaucoma?"
#
# ❓[52/85] Question: What are some recent advances in cancer immunotherapy?
# 🧠 Generated Queries: ['advances cancer immunotherapy', 'recent advances cancer immunotherapy', 'cancer immunotherapy', 'recent advances cancer', 'advances cancer', 'immunotherapy', 'cancer', 'advances', 'recent advances', 'recent']
# ✅ Found 68762 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are some recent advances in cancer immunotherapy?"
#
# ❓[53/85] Question: Is delirium a frequent complication after cardiac surgery?
# 🧠 Generated Queries: ['delirium frequent complication cardiac surgery', 'delirium frequent complication cardiac', 'delirium frequent complication', 'delirium frequent', 'delirium', 'frequent complication cardiac surgery', 'complication cardiac surgery', 'cardiac surgery', 'frequent complication cardiac', 'complication cardiac', 'surgery', 'cardiac', 'frequent complication', 'complication', 'frequent']
# ✅ Found 87713 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is delirium a frequent complication after cardiac surgery?"
#
# ❓[54/85] Question: Phobias affecting humans.
# 🧠 Generated Queries: ['phobias affecting humans', 'phobias affecting', 'phobias', 'affecting humans', 'affecting', 'humans']
# ✅ Found 35878 unique PMIDs for this question.
# 🎯 Found 6 out of 6 ground truth PMIDs.
# 📦 Fetching details for 156 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Phobias affecting humans."
#
# ❓[55/85] Question: How can convolutional neural networks (CNNs) be utilized in radiomics?
# 🧠 Generated Queries: ['convolutional neural networks cnns utilized radiomics', 'neural networks cnns utilized radiomics', 'cnns utilized radiomics', 'networks cnns utilized radiomics', 'utilized radiomics', 'radiomics', 'convolutional neural networks cnns', 'convolutional neural networks cnns utilized', 'convolutional neural networks', 'networks cnns utilized', 'neural networks cnns utilized', 'networks cnns', 'cnns utilized', 'neural networks cnns', 'cnns', 'convolutional neural', 'convolutional', 'networks', 'neural networks', 'neural']
# ✅ Found 50662 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "How can convolutional neural networks (CNNs) be utilized in radiomics?"
#
# 📁 Saving batch at question 55...
# ✅ Batch saved and checkpoint updated at index 54
#
# ❓[56/85] Question: Please summarize Graves disease
# 🧠 Generated Queries: ['summarize graves disease', 'graves disease', 'summarize graves', 'graves', 'disease', 'summarize']
# ✅ Found 35054 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Please summarize Graves disease"
#
# ❓[57/85] Question: Are there any studies on the genetics of suicide?
# 🧠 Generated Queries: ['studies genetics suicide', 'genetics suicide', 'studies genetics', 'genetics', 'suicide', 'studies']
# ✅ Found 40770 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Are there any studies on the genetics of suicide?"
#
# ❓[58/85] Question: What are some common post-translational modifications of proteins?
# 🧠 Generated Queries: ['common post translational modifications proteins', 'post translational modifications proteins', 'translational modifications proteins', 'modifications proteins', 'common post translational modifications', 'translational modifications', 'post translational modifications', 'proteins', 'common post translational', 'post translational', 'modifications', 'translational', 'post', 'common post', 'common']
# ✅ Found 87022 unique PMIDs for this question.
# 🎯 Found 0 out of 1 ground truth PMIDs.
# 📦 Fetching details for 150 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are some common post-translational modifications of proteins?"
#
# ❓[59/85] Question: Do MiOXSYS and OxiSperm measure ROS(Reactive Oxygen Species) in sperm?
# 🧠 Generated Queries: ['mioxsys oxisperm measure ros reactive oxygen species sperm', 'oxisperm measure ros reactive oxygen species sperm', 'measure ros reactive oxygen species sperm', 'ros reactive oxygen species sperm', 'mioxsys oxisperm measure ros reactive oxygen', 'mioxsys oxisperm measure ros reactive oxygen species', 'mioxsys oxisperm measure ros reactive', 'oxisperm measure ros reactive oxygen', 'oxisperm measure ros reactive oxygen species', 'reactive oxygen species sperm', 'mioxsys oxisperm measure ros', 'oxisperm measure ros reactive', 'measure ros reactive oxygen species', 'oxygen species sperm', 'measure ros reactive oxygen', 'mioxsys oxisperm measure', 'ros reactive oxygen', 'ros reactive oxygen species', 'mioxsys oxisperm', 'oxisperm measure ros']
# ✅ Found 22729 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Do MiOXSYS and OxiSperm measure ROS(Reactive Oxygen Species) in sperm?"
#
# ❓[60/85] Question: Which parasitic infections can cause anemia?
# 🧠 Generated Queries: ['parasitic infections cause anemia', 'infections cause anemia', 'parasitic infections cause', 'parasitic infections', 'cause anemia', 'infections cause', 'anemia', 'parasitic', 'infections', 'cause']
# ✅ Found 67290 unique PMIDs for this question.
# 🎯 Found 5 out of 6 ground truth PMIDs.
# 📦 Fetching details for 155 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which parasitic infections can cause anemia?"
#
# 📁 Saving batch at question 60...
# ✅ Batch saved and checkpoint updated at index 59
#
# ❓[61/85] Question: What neurotransmitter is most associated with muscle activation?
# 🧠 Generated Queries: ['neurotransmitter associated muscle activation', 'neurotransmitter associated muscle', 'neurotransmitter associated', 'neurotransmitter', 'associated muscle activation', 'muscle activation', 'associated muscle', 'muscle', 'activation', 'associated']
# ✅ Found 72608 unique PMIDs for this question.
# 🎯 Found 0 out of 1 ground truth PMIDs.
# 📦 Fetching details for 150 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What neurotransmitter is most associated with muscle activation?"
#
# ❓[62/85] Question: What medical proceedure causes nephrogenic systemic fibrosis?
# 🧠 Generated Queries: ['medical proceedure causes nephrogenic systemic fibrosis', 'causes nephrogenic systemic fibrosis', 'nephrogenic systemic fibrosis', 'proceedure causes nephrogenic systemic fibrosis', 'causes nephrogenic systemic', 'medical proceedure causes nephrogenic systemic', 'nephrogenic systemic', 'systemic fibrosis', 'proceedure causes nephrogenic systemic', 'fibrosis', 'medical proceedure causes nephrogenic', 'causes nephrogenic', 'proceedure causes nephrogenic', 'nephrogenic', 'systemic', 'medical proceedure causes', 'causes', 'proceedure causes', 'medical proceedure', 'medical']
# ✅ Found 49945 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What medical proceedure causes nephrogenic systemic fibrosis?"
#
# ❓[63/85] Question: Is obesity a risk factor for sleep apnea?
# 🧠 Generated Queries: ['obesity risk factor sleep apnea', 'obesity risk factor sleep', 'risk factor sleep apnea', 'factor sleep apnea', 'sleep apnea', 'obesity risk factor', 'obesity risk', 'risk factor sleep', 'obesity', 'apnea', 'factor sleep', 'sleep', 'risk factor', 'risk', 'factor']
# ✅ Found 80914 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is obesity a risk factor for sleep apnea?"
#
# ❓[64/85] Question: What cancer hallmarks are characteristically promoted by tumor microenvironment components, such as pericytes?
# 🧠 Generated Queries: ['cancer hallmarks characteristically promoted tumor microenvironment components pericytes', 'hallmarks characteristically promoted tumor microenvironment components pericytes', 'characteristically promoted tumor microenvironment components pericytes', 'promoted tumor microenvironment components pericytes', 'hallmarks characteristically promoted tumor microenvironment components', 'hallmarks characteristically promoted tumor microenvironment', 'tumor microenvironment components pericytes', 'cancer hallmarks characteristically promoted tumor microenvironment components', 'cancer hallmarks characteristically promoted tumor microenvironment', 'characteristically promoted tumor microenvironment components', 'promoted tumor microenvironment components', 'characteristically promoted tumor microenvironment', 'tumor microenvironment components', 'promoted tumor microenvironment', 'hallmarks characteristically promoted tumor', 'cancer hallmarks characteristically', 'cancer hallmarks characteristically promoted tumor', 'cancer hallmarks characteristically promoted', 'cancer hallmarks', 'tumor microenvironment']
# ✅ Found 34408 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What cancer hallmarks are characteristically promoted by tumor microenvironment components, such as pericytes?"
#
# ❓[65/85] Question: XIST proteins mediate what cellular process?
# 🧠 Generated Queries: ['xist proteins mediate cellular process', 'xist proteins mediate cellular', 'xist proteins mediate', 'xist proteins', 'proteins mediate cellular process', 'proteins mediate cellular', 'proteins mediate', 'proteins', 'mediate cellular process', 'cellular process', 'mediate cellular', 'xist', 'cellular', 'process', 'mediate']
# ✅ Found 54991 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "XIST proteins mediate what cellular process?"
#
# 📁 Saving batch at question 65...
# ✅ Batch saved and checkpoint updated at index 64
#
# ❓[66/85] Question: Typical age range of onset of systemic scleroderma.
# 🧠 Generated Queries: ['typical age range onset systemic scleroderma', 'age range onset systemic scleroderma', 'onset systemic scleroderma', 'range onset systemic scleroderma', 'systemic scleroderma', 'scleroderma', 'typical age range onset systemic', 'age range onset systemic', 'typical age range onset', 'age range onset', 'onset systemic', 'typical age range', 'range onset systemic', 'age range', 'typical age', 'age', 'systemic', 'onset', 'range onset', 'range']
# ✅ Found 98312 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Typical age range of onset of systemic scleroderma."
#
# ❓[67/85] Question: What glial cells are responsible for myelination in the CNS?
# 🧠 Generated Queries: ['glial cells responsible myelination cns', 'glial cells responsible myelination', 'cells responsible myelination cns', 'cells responsible myelination', 'responsible myelination cns', 'myelination cns', 'responsible myelination', 'glial cells responsible', 'glial cells', 'myelination', 'glial', 'cells responsible', 'cells', 'cns', 'responsible']
# ✅ Found 70473 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What glial cells are responsible for myelination in the CNS?"
#
# ❓[68/85] Question: What is BIONDA
# 🧠 Generated Queries: ['bionda']
# ✅ Found 163 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is BIONDA"
#
# ❓[69/85] Question: Indications for Electro-convulsive therapy.
# 🧠 Generated Queries: ['indications electro convulsive therapy', 'electro convulsive therapy', 'indications electro convulsive', 'electro convulsive', 'convulsive therapy', 'indications electro', 'convulsive', 'electro', 'indications', 'therapy']
# ✅ Found 50586 unique PMIDs for this question.
# 🎯 Found 9 out of 9 ground truth PMIDs.
# 📦 Fetching details for 159 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Indications for Electro-convulsive therapy."
#
# ❓[70/85] Question: What is a common chromosome-level gain in glioblastoma?
# 🧠 Generated Queries: ['common chromosome level gain glioblastoma', 'chromosome level gain glioblastoma', 'level gain glioblastoma', 'gain glioblastoma', 'common chromosome level gain', 'glioblastoma', 'chromosome level gain', 'common chromosome level', 'chromosome level', 'common chromosome', 'chromosome', 'level gain', 'gain', 'common', 'level']
# ✅ Found 80453 unique PMIDs for this question.
# 🎯 Found 2 out of 3 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is a common chromosome-level gain in glioblastoma?"
#
# 📁 Saving batch at question 70...
# ✅ Batch saved and checkpoint updated at index 69
#
# ❓[71/85] Question: What is the gene target for  Zanidatamab?
# 🧠 Generated Queries: ['gene target zanidatamab', 'target zanidatamab', 'zanidatamab', 'gene target', 'gene', 'target']
# ✅ Found 24725 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the gene target for  Zanidatamab?"
#
# ❓[72/85] Question: How do you diagnose HIV infection?
# 🧠 Generated Queries: ['diagnose hiv infection', 'diagnose hiv', 'hiv infection', 'hiv', 'infection', 'diagnose']
# ✅ Found 38698 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "How do you diagnose HIV infection?"
#
# ❓[73/85] Question: Is a single-nucleotide polymorphism (SNP) the same as a mutation?
# 🧠 Generated Queries: ['single nucleotide polymorphism snp mutation', 'nucleotide polymorphism snp mutation', 'single nucleotide polymorphism snp', 'polymorphism snp mutation', 'nucleotide polymorphism snp', 'single nucleotide polymorphism', 'snp mutation', 'polymorphism snp', 'nucleotide polymorphism', 'single nucleotide', 'snp', 'mutation', 'nucleotide', 'polymorphism', 'single']
# ✅ Found 66533 unique PMIDs for this question.
# 🎯 Found 0 out of 1 ground truth PMIDs.
# 📦 Fetching details for 150 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is a single-nucleotide polymorphism (SNP) the same as a mutation?"
#
# ❓[74/85] Question: Is Melatonin found in human milk?
# 🧠 Generated Queries: ['melatonin human milk', 'melatonin human', 'melatonin', 'human milk', 'milk', 'human']
# ✅ Found 42117 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is Melatonin found in human milk?"
#
# ❓[75/85] Question: Physiopathology of alopecia.
# 🧠 Generated Queries: ['physiopathology alopecia', 'alopecia', 'physiopathology']
# ✅ Found 21030 unique PMIDs for this question.
# 🎯 Found 6 out of 6 ground truth PMIDs.
# 📦 Fetching details for 156 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Physiopathology of alopecia."
#
# 📁 Saving batch at question 75...
# ✅ Batch saved and checkpoint updated at index 74
#
# ❓[76/85] Question: What is phenotype switching in melanoma?
# 🧠 Generated Queries: ['phenotype switching melanoma', 'switching melanoma', 'phenotype switching', 'melanoma', 'phenotype', 'switching']
# ✅ Found 39805 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is phenotype switching in melanoma?"
#
# ❓[77/85] Question: What is a neoantigen?
# 🧠 Generated Queries: ['neoantigen']
# ✅ Found 5441 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is a neoantigen?"
#
# ❓[78/85] Question: Do hyaluronic acid injections improve knee pain?
# 🧠 Generated Queries: ['hyaluronic acid injections improve knee pain', 'hyaluronic acid injections improve knee', 'acid injections improve knee pain', 'injections improve knee pain', 'acid injections improve knee', 'injections improve knee', 'hyaluronic acid injections improve', 'improve knee pain', 'hyaluronic acid injections', 'improve knee', 'hyaluronic acid', 'knee pain', 'acid injections improve', 'hyaluronic', 'acid injections', 'knee', 'injections improve', 'injections', 'pain', 'acid']
# ✅ Found 90518 unique PMIDs for this question.
# 🎯 Found 3 out of 4 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Do hyaluronic acid injections improve knee pain?"
#
# ❓[79/85] Question: Which transcription factors are important to define human astrocyte identity?
# 🧠 Generated Queries: ['transcription factors important define human astrocyte identity', 'transcription factors important define human astrocyte', 'factors important define human astrocyte identity', 'important define human astrocyte identity', 'human astrocyte identity', 'define human astrocyte identity', 'factors important define human astrocyte', 'astrocyte identity', 'important define human astrocyte', 'transcription factors important define human', 'human astrocyte', 'transcription factors important', 'define human astrocyte', 'transcription factors important define', 'transcription factors', 'astrocyte', 'transcription', 'factors important define human', 'factors important', 'factors important define']
# ✅ Found 70790 unique PMIDs for this question.
# 🎯 Found 1 out of 3 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which transcription factors are important to define human astrocyte identity?"
#
# ❓[80/85] Question: Is Peto's Paradox associated with cancer rates?
# 🧠 Generated Queries: ['peto paradox associated cancer rates', 'peto paradox associated cancer', 'paradox associated cancer rates', 'peto paradox associated', 'paradox associated cancer', 'peto paradox', 'cancer rates', 'associated cancer rates', 'peto', 'cancer', 'associated cancer', 'paradox associated', 'paradox', 'rates', 'associated']
# ✅ Found 67546 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is Peto's Paradox associated with cancer rates?"
#
# 📁 Saving batch at question 80...
# ✅ Batch saved and checkpoint updated at index 79
#
# ❓[81/85] Question: Is Clostridioides difficile an aerobe or a anaerobe bacterium?
# 🧠 Generated Queries: ['clostridioides difficile aerobe anaerobe bacterium', 'clostridioides difficile aerobe anaerobe', 'clostridioides difficile aerobe', 'difficile aerobe anaerobe bacterium', 'aerobe anaerobe bacterium', 'clostridioides difficile', 'difficile aerobe anaerobe', 'anaerobe bacterium', 'clostridioides', 'bacterium', 'difficile aerobe', 'aerobe anaerobe', 'aerobe', 'anaerobe', 'difficile']
# ✅ Found 60043 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is Clostridioides difficile an aerobe or a anaerobe bacterium?"
#
# ❓[82/85] Question: Please list the benefits of sodium-glucose cotransporter 2 inhibitors
# 🧠 Generated Queries: ['list benefits sodium glucose cotransporter inhibitors', 'benefits sodium glucose cotransporter inhibitors', 'list benefits sodium glucose cotransporter', 'sodium glucose cotransporter inhibitors', 'benefits sodium glucose cotransporter', 'glucose cotransporter inhibitors', 'list benefits sodium glucose', 'benefits sodium glucose', 'sodium glucose cotransporter', 'cotransporter inhibitors', 'glucose cotransporter', 'list benefits sodium', 'benefits sodium', 'sodium glucose', 'inhibitors', 'glucose', 'benefits', 'cotransporter', 'list benefits', 'sodium']
# ✅ Found 69495 unique PMIDs for this question.
# 🎯 Found 8 out of 8 ground truth PMIDs.
# 📦 Fetching details for 158 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Please list the benefits of sodium-glucose cotransporter 2 inhibitors"
#
# ❓[83/85] Question: Bacteria that most commonly causes urinary tract infection.
# 🧠 Generated Queries: ['bacteria commonly causes urinary tract infection', 'bacteria commonly causes urinary tract', 'bacteria commonly causes urinary', 'commonly causes urinary tract infection', 'causes urinary tract infection', 'urinary tract infection', 'commonly causes urinary tract', 'causes urinary tract', 'commonly causes urinary', 'causes urinary', 'urinary tract', 'bacteria commonly causes', 'bacteria commonly', 'tract infection', 'urinary', 'bacteria', 'infection', 'commonly causes', 'tract', 'causes']
# ✅ Found 93035 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Bacteria that most commonly causes urinary tract infection."
#
# ❓[84/85] Question: Is Bacillus Clausii a probiotic?
# 🧠 Generated Queries: ['bacillus clausii probiotic', 'bacillus clausii', 'clausii probiotic', 'bacillus', 'probiotic', 'clausii']
# ✅ Found 19530 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is Bacillus Clausii a probiotic?"
#
# ❓[85/85] Question: Symptoms of chlamydia genital infection in women.
# 🧠 Generated Queries: ['symptoms chlamydia genital infection women', 'symptoms chlamydia genital infection', 'symptoms chlamydia genital', 'symptoms chlamydia', 'chlamydia genital infection women', 'chlamydia genital infection', 'chlamydia genital', 'chlamydia', 'genital infection women', 'genital infection', 'infection women', 'symptoms', 'genital', 'infection', 'women']
# ✅ Found 78273 unique PMIDs for this question.
# 🎯 Found 6 out of 6 ground truth PMIDs.
# 📦 Fetching details for 156 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Symptoms of chlamydia genital infection in women."
#
# 📁 Saving batch at question 85...
# ✅ Batch saved and checkpoint updated at index 84
