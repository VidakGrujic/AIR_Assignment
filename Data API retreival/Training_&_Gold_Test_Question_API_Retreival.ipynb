# %% [markdown]
# # Initial API retreival.
# ### Note: THIS CAN BE USED ONLY FOR TRAINING AND TEST BATCHES WHICH ARE TAKEN FROM THE PHASE B BECAUSE THEY CONTAIN GOLDEN ANSWERS AND THEREFORE THE STRUCTURE IS DIFFERENT.
# ### FOR BATCH_2, BATCH_3, BATCH_4 USE THE TEST_QUESTION_API_RETREVAL.IPYNB

# %%
from Bio import Entrez
from keybert import KeyBERT
import json
import warnings
warnings.filterwarnings("ignore")
from tqdm import tqdm
import xml.etree.ElementTree as ET
import re
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
import random
import time
from datetime import datetime

# Load spaCy model only once
'''nlp = spacy.load("en_core_web_sm")

INTENT_TERMS = {
    "synonym", "definition", "define", "meaning",
    "cause", "treatment", "therapy",
    "effect", "role", "impact", "mechanism",
    "list"
}

GENERIC_MEDICAL_TERMS = {
    "disease", "disorder", "condition", "syndrome", "illness", "diagnosis"
}'''



data_file_path = "../datasets/test_golden_answers/batch_3/BioASQ-task13bPhaseB-testset3"
output_file_path = "../datasets/test_golden_answers/batch_3/retreived_articles_sampled_test_batch_3.json"
base_pid_url = 'http://www.ncbi.nlm.nih.gov/pubmed/' 
Entrez.email = "kasapovic.m@hotmail.com"  # validan email

# %%
def load_question_from_file(file_path):
    """
    Loads the BioASQ-style JSON and extracts the list of questions.
    
    Parameters:
        file_path (str): Path to the JSON file.
    
    Returns:
        List[dict]: A list of question dictionaries.
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        questions = data.get("questions", [])
        print(f"Loaded {len(questions)} questions from {file_path}")
        return questions
    except Exception as e:
        print(f"Failed to load questions: {e}")
        return []

# %%
questions = load_question_from_file(file_path=data_file_path)
questions[0]
# Out:
# Loaded 85 questions from ../datasets/test_golden_answers/batch_3/BioASQ-task13bPhaseB-testset3
# {'documents': ['http://www.ncbi.nlm.nih.gov/pubmed/37794186'],
#  'snippets': [{'beginSection': 'abstract',
#    'endSection': 'abstract',
#    'text': 'The Pharma Proteomics Project is a precompetitive biopharmaceutical consortium characterizing the plasma proteomic profiles of 54,219 UK Biobank participants. Here we provide a detailed summary of this initiative, including technical and biological validations, insights into proteomic disease signatures, and prediction modelling for various demographic and health indicators. We present comprehensive protein quantitative trait locus (pQTL) mapping of 2,923 proteins that identifies 14,287 primary genetic associations, of which 81% are previously undescribed, alongside ancestry-specific pQTL mapping in non-European individuals.',
#    'document': 'http://www.ncbi.nlm.nih.gov/pubmed/37794186',
#    'offsetInBeginSection': 0,
#    'offsetInEndSection': 632}],
#  'id': '67e6ce6e18b1e36f2e0000cf',
#  'type': 'factoid',
#  'body': 'How many primary genetic associations were identified through pQTL mapping within the Pharma Proteomics Project?'}

# %%
def parse_question(questions):
    """
    Parses the questions to extract relevant information.
    
    Parameters:
        questions (List[dict]): A list of question dictionaries.
    
    Returns:
        List[dict]: A list of parsed question dictionaries.
    """
    parsed_questions = []
    for question in questions:
        parsed_questions.append({
            "id": question["id"],
            "body": question["body"],
            "documents": [doc.replace(base_pid_url, '') for doc in question["documents"]],
            "snippets": question["snippets"],
        })
    return parsed_questions

# %%
def get_questions_text(questions):
    """
    Extracts the text of the questions from the parsed questions.
    
    Parameters:
        parsed_questions (List[dict]): A list of parsed question dictionaries.
    
    Returns:
        List[str]: A list of question texts.
    """
    return [{'id': question['id'],
              'body': question["body"]} for question in questions]

def get_ground_truth_documents(questions):
    """
    Extracts the ground truth from the parsed questions.
    
    Parameters:
        parsed_questions (List[dict]): A list of parsed question dictionaries.
    
    Returns:
        List[str]: A list of ground truth texts.
    """
    ground_truth = {}
    for question in questions:
        ground_truth[question['id']] = set(question["documents"])
    return ground_truth

# %%
parsed_questions = parse_question(questions=questions)
#parsed_questions[0:3]

# %%
ground_truth_documents = get_ground_truth_documents(questions=parsed_questions)
#ground_truth_documents

# %%
questions_texts = get_questions_text(questions=parsed_questions)

# %%
# compare the length of the questions and the ground truth documents
print(f"Number of questions: {len(questions_texts)}")
print(f"Number of ground truth documents: {len(ground_truth_documents)}")
# Out:
# Number of questions: 85
# Number of ground truth documents: 85

# %%
def save_to_json(data, file_path):
    """
    Saves the data to a JSON file.
    
    Parameters:
        data (any): The data to save.
        file_path (str): Path to the JSON file.
    """
    try:
        with open(file_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=4)
        print(f"Saved data to {file_path}")
    except Exception as e:
        print(f"Failed to save data: {e}")

# %%
save_to_json(data=parsed_questions, file_path="parsed_questions.json")
# Out:
# Saved data to parsed_questions.json

# %%
def parse_pubmed_abstracts_from_xml(xml_string):
    """
    Parse PubMed XML and extract PMID, title, and abstract.

    Args:
        xml_string (str): XML data as string from Entrez.efetch(..., retmode="xml")

    Returns:
        List[Dict]: List of articles with keys: 'pid', 'title', 'abstract'
    """
    root = ET.fromstring(xml_string)
    articles = []

    for article in root.findall(".//PubmedArticle"):
        pid = article.findtext(".//PMID")
        title = article.findtext(".//ArticleTitle")

        # Handle multiple AbstractText parts (can have labels, e.g. "BACKGROUND", "METHODS", etc.)
        abstract_parts = article.findall(".//Abstract/AbstractText")
        abstract = " ".join([part.text for part in abstract_parts if part.text])

        articles.append({
            "pid": pid,
            "title": title,
            "abstract": abstract
        })

    return articles

# %%
# Generate semantic queries
def generate_queries_BERT(question, model, keyphrase_ngram_range=(1, 3), top_n=7):
    keywords = model.extract_keywords(question, keyphrase_ngram_range=keyphrase_ngram_range, stop_words='english', top_n=top_n)
    return [kw for kw, _ in keywords]

'''
def generate_queries_BERT(question, model=KeyBERT('all-MiniLM-L6-v2'), keyphrase_ngram_range=(1, 3), top_n=7):
    keywords = model.extract_keywords(question, keyphrase_ngram_range=keyphrase_ngram_range, stop_words='english', top_n=top_n)

    cleaned_keywords = []

    for phrase, _ in keywords:
        doc = nlp(phrase)

        # Remove verbs, auxiliaries, stopwords, and short words
        filtered_tokens = [
            token.lemma_.lower()
            for token in doc
            if token.pos_ not in {"VERB", "AUX"}
            and token.lemma_.lower() not in ENGLISH_STOP_WORDS
            and len(token.lemma_) > 2
        ]

        # Reconstruct cleaned phrase
        cleaned_phrase = " ".join(filtered_tokens).strip()

        if cleaned_phrase:  # Only keep non-empty results
            cleaned_keywords.append(cleaned_phrase)

    return list(sorted(set(cleaned_keywords)))  # deduplicate + sort
'''

# Search PubMed for each query
def search_pubmed(query, retmax=500):
    handle = Entrez.esearch(db="pubmed", term=query, retmax=retmax)
    record = Entrez.read(handle)
    handle.close()
    return record["IdList"]

# Fetch details in JSON and decode
def fetch_details(id_list):
    ids = ",".join(id_list)
    handle = Entrez.efetch(db="pubmed", id=ids, rettype="medline", retmode="xml")
    xml_data = handle.read()  
    handle.close()
    records = parse_pubmed_abstracts_from_xml(xml_data)
    return records

# %%
questions = get_questions_text(questions=parsed_questions)
for i in range(len(questions)):
    if questions[i]['id'] == "516c0ebc298dcd4e5100006e":
        print(i)

# %%
import random
import time
import json
import os
import shutil
from datetime import datetime

# 🔧 Parameters
BATCH_SIZE = 5
RESULTS_FILE = output_file_path
CHECKPOINT_FILE = "checkpoint.json"

# 📌 Load checkpoint if it exists
if os.path.exists(CHECKPOINT_FILE):
    with open(CHECKPOINT_FILE, "r") as f:
        checkpoint = json.load(f)
        start_index = checkpoint.get("last_index", 0) + 1
else:
    start_index = 0

# 🚀 Initialize
questions = get_questions_text(questions=parsed_questions)
kw_model = KeyBERT(model='all-MiniLM-L6-v2')
results = []

# 📝 Resume from saved results file if available
if os.path.exists(RESULTS_FILE):
    try:
        with open(RESULTS_FILE, "r") as f:
            results = json.load(f)["results"]
    except json.JSONDecodeError:
        print("⚡ Warning: Results file is corrupted. Starting with empty results.")
        results = []

# 🔁 Process from start_index
for i in range(start_index, len(questions)):
    question = questions[i]
    qid = question['id']
    print(f"❓[{i+1}/{len(questions)}] Question: {question['body']}")
    
    queries = generate_queries_BERT(question['body'], keyphrase_ngram_range=(1, 10), top_n=20, model=kw_model)
    print(f"🧠 Generated Queries: {queries}")
    
    all_ids = set()
    for q in queries:
        try:
            ids = search_pubmed(q, retmax=20000)
            all_ids.update(ids)
            time.sleep(0.7)
        except Exception as e:
            print(f"⚠️ Failed to search PubMed with query '{q}': {e}")
    
    print(f"✅ Found {len(all_ids)} unique PMIDs for this question.")
    
    ground_truth = ground_truth_documents[qid]
    found_gt = ground_truth.intersection(all_ids)
    print(f"🎯 Found {len(found_gt)} out of {len(ground_truth)} ground truth PMIDs.")
    
    non_gt = list(all_ids - found_gt)
    sampled_random = random.sample(non_gt, min(150, len(non_gt)))
    
    selected_ids = list(found_gt) + sampled_random
    print(f"📦 Fetching details for {len(selected_ids)} PMIDs (GT + Random Sample)")

    try:
        details = fetch_details(selected_ids)
    except Exception as e:
        print(f"❌ Error fetching details: {e}")
        details = []

    results.append({
        "qid": qid,
        "question": question['body'],
        "queries": queries,
        "ground_truth": list(ground_truth),
        "ground_truth_total": len(ground_truth),
        "ground_truth_found": list(found_gt),
        "ground_truth_found_count": len(found_gt),
        "random_sampled_count": len(sampled_random),
        "random_sampled_pmids": sampled_random,
        "selected_pmids": selected_ids,
        "error_rate": {
            "value": len(found_gt) / len(ground_truth) if len(ground_truth) > 0 else 0,
            "details": f"{len(found_gt)} found out of {len(ground_truth)}"
        },
        "details": details
    })

    print(f"✅ Saved result for question \"{question['body']}\"\n")

    # 💾 Save batch and update checkpoint
    if (i + 1) % BATCH_SIZE == 0 or i == len(questions) - 1:
        print(f"📁 Saving batch at question {i+1}...")

        # Save to a temporary file first
        temp_file = RESULTS_FILE + ".tmp"
        with open(temp_file, "w") as f:
            json.dump({"results": results}, f, indent=2)

        # Move temp file to final results file (atomic save)
        shutil.move(temp_file, RESULTS_FILE)

        # Save checkpoint
        with open(CHECKPOINT_FILE, "w") as f:
            json.dump({"last_index": i}, f)

        print(f"✅ Batch saved and checkpoint updated at index {i}\n")
# Out:
# ❓[21/85] Question: Which CARD8 variants confer decreased risk in diabetic nephropathy?
# 🧠 Generated Queries: ['card8 variants confer decreased risk diabetic nephropathy', 'card8 variants confer decreased risk diabetic', 'variants confer decreased risk diabetic nephropathy', 'card8 variants confer decreased risk', 'risk diabetic nephropathy', 'decreased risk diabetic nephropathy', 'confer decreased risk diabetic nephropathy', 'diabetic nephropathy', 'card8 variants confer decreased', 'variants confer decreased risk diabetic', 'card8 variants confer', 'card8 variants', 'risk diabetic', 'nephropathy', 'decreased risk diabetic', 'diabetic', 'variants confer decreased risk', 'confer decreased risk diabetic', 'card8', 'variants confer decreased']
# ✅ Found 51492 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which CARD8 variants confer decreased risk in diabetic nephropathy?"
#
# ❓[22/85] Question: Can Fasudil be used for subarachnoid haemorrhage?
# 🧠 Generated Queries: ['fasudil used subarachnoid haemorrhage', 'fasudil used subarachnoid', 'used subarachnoid haemorrhage', 'subarachnoid haemorrhage', 'fasudil used', 'used subarachnoid', 'fasudil', 'subarachnoid', 'haemorrhage', 'used']
# ✅ Found 23200 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Can Fasudil be used for subarachnoid haemorrhage?"
#
# ❓[23/85] Question: Please explain how  activation likelihood estimation (ALE) is used
# 🧠 Generated Queries: ['explain activation likelihood estimation ale used', 'explain activation likelihood estimation ale', 'activation likelihood estimation ale used', 'activation likelihood estimation ale', 'explain activation likelihood estimation', 'likelihood estimation ale used', 'likelihood estimation ale', 'explain activation likelihood', 'activation likelihood estimation', 'activation likelihood', 'estimation ale used', 'estimation ale', 'explain activation', 'likelihood estimation', 'activation', 'likelihood', 'ale', 'ale used', 'estimation', 'explain']
# ✅ Found 84021 unique PMIDs for this question.
# 🎯 Found 6 out of 6 ground truth PMIDs.
# 📦 Fetching details for 156 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Please explain how  activation likelihood estimation (ALE) is used"
#
# ❓[24/85] Question: Which mutations increase the risk for pancreatic cancer?
# 🧠 Generated Queries: ['mutations increase risk pancreatic cancer', 'mutations increase risk pancreatic', 'increase risk pancreatic cancer', 'risk pancreatic cancer', 'pancreatic cancer', 'mutations increase risk', 'increase risk pancreatic', 'risk pancreatic', 'mutations increase', 'mutations', 'pancreatic', 'cancer', 'increase risk', 'risk', 'increase']
# ✅ Found 88441 unique PMIDs for this question.
# 🎯 Found 3 out of 8 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which mutations increase the risk for pancreatic cancer?"
#
# ❓[25/85] Question: How does GBM heterogeneity affect treatment response?
# 🧠 Generated Queries: ['does gbm heterogeneity affect treatment response', 'does gbm heterogeneity affect treatment', 'gbm heterogeneity affect treatment response', 'gbm heterogeneity affect treatment', 'does gbm heterogeneity affect', 'gbm heterogeneity affect', 'does gbm heterogeneity', 'gbm heterogeneity', 'does gbm', 'heterogeneity affect treatment response', 'heterogeneity affect treatment', 'gbm', 'treatment response', 'heterogeneity affect', 'affect treatment response', 'heterogeneity', 'treatment', 'affect treatment', 'response', 'affect']
# ✅ Found 81795 unique PMIDs for this question.
# 🎯 Found 2 out of 3 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "How does GBM heterogeneity affect treatment response?"
#
# 📁 Saving batch at question 25...
# ✅ Batch saved and checkpoint updated at index 24
#
# ❓[26/85] Question: Describe FINDbase
# 🧠 Generated Queries: ['findbase']
# ✅ Found 10 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 10 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Describe FINDbase"
#
# ❓[27/85] Question: What is included in the VRd regiment for myeloma?
# 🧠 Generated Queries: ['included vrd regiment myeloma', 'vrd regiment myeloma', 'included vrd regiment', 'regiment myeloma', 'vrd regiment', 'included vrd', 'myeloma', 'vrd', 'regiment', 'included']
# ✅ Found 22679 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is included in the VRd regiment for myeloma?"
#
# ❓[28/85] Question: Is pollinosis another name for allergies to tree or grass pollen?
# 🧠 Generated Queries: ['pollinosis allergies tree grass pollen', 'pollinosis allergies tree grass', 'pollinosis allergies tree', 'allergies tree grass pollen', 'pollinosis allergies', 'tree grass pollen', 'grass pollen', 'allergies tree grass', 'pollen', 'allergies tree', 'allergies', 'pollinosis', 'tree grass', 'grass', 'tree']
# ✅ Found 60840 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is pollinosis another name for allergies to tree or grass pollen?"
#
# ❓[29/85] Question: Which diet is recommended for people with Irritable Bowel Syndrome?
# 🧠 Generated Queries: ['diet recommended people irritable bowel syndrome', 'diet recommended people irritable bowel', 'recommended people irritable bowel syndrome', 'recommended people irritable bowel', 'diet recommended people irritable', 'irritable bowel syndrome', 'people irritable bowel syndrome', 'irritable bowel', 'bowel syndrome', 'people irritable bowel', 'diet recommended', 'diet recommended people', 'bowel', 'diet', 'recommended people irritable', 'people irritable', 'irritable', 'syndrome', 'recommended people', 'people']
# ✅ Found 87080 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which diet is recommended for people with Irritable Bowel Syndrome?"
#
# ❓[30/85] Question: How do macrophages influence the glioblastoma microenvironment?
# 🧠 Generated Queries: ['macrophages influence glioblastoma microenvironment', 'macrophages influence glioblastoma', 'influence glioblastoma microenvironment', 'glioblastoma microenvironment', 'macrophages influence', 'macrophages', 'influence glioblastoma', 'glioblastoma', 'microenvironment', 'influence']
# ✅ Found 50135 unique PMIDs for this question.
# 🎯 Found 2 out of 3 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "How do macrophages influence the glioblastoma microenvironment?"
#
# 📁 Saving batch at question 30...
# ✅ Batch saved and checkpoint updated at index 29
#
# ❓[31/85] Question: Which are the main findings from the AURA3 trial on acquired resistance to osimertinib?
# 🧠 Generated Queries: ['main findings aura3 trial acquired resistance osimertinib', 'findings aura3 trial acquired resistance osimertinib', 'aura3 trial acquired resistance osimertinib', 'trial acquired resistance osimertinib', 'acquired resistance osimertinib', 'resistance osimertinib', 'main findings aura3 trial acquired resistance', 'findings aura3 trial acquired resistance', 'main findings aura3 trial acquired', 'findings aura3 trial acquired', 'main findings aura3 trial', 'osimertinib', 'findings aura3 trial', 'aura3 trial acquired resistance', 'aura3 trial acquired', 'main findings aura3', 'findings aura3', 'trial acquired resistance', 'aura3 trial', 'main findings']
# ✅ Found 19400 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which are the main findings from the AURA3 trial on acquired resistance to osimertinib?"
#
# ❓[32/85] Question: Is Luvadaxistat effective for Friedreich's Ataxia?
# 🧠 Generated Queries: ['luvadaxistat effective friedreich ataxia', 'effective friedreich ataxia', 'friedreich ataxia', 'luvadaxistat effective', 'luvadaxistat effective friedreich', 'ataxia', 'luvadaxistat', 'effective friedreich', 'friedreich', 'effective']
# ✅ Found 23687 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is Luvadaxistat effective for Friedreich's Ataxia?"
#
# ❓[33/85] Question: Please summarize the relationship between Xylazine and illicit drug use.
# 🧠 Generated Queries: ['summarize relationship xylazine illicit drug use', 'relationship xylazine illicit drug use', 'summarize relationship xylazine illicit drug', 'xylazine illicit drug use', 'relationship xylazine illicit drug', 'xylazine illicit drug', 'relationship xylazine illicit', 'xylazine illicit', 'summarize relationship xylazine illicit', 'relationship xylazine', 'xylazine', 'summarize relationship xylazine', 'illicit drug use', 'illicit drug', 'drug use', 'drug', 'illicit', 'relationship', 'summarize', 'summarize relationship']
# ✅ Found 50970 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Please summarize the relationship between Xylazine and illicit drug use."
#
# ❓[34/85] Question: Is obesity a familial syndrome?
# 🧠 Generated Queries: ['obesity familial syndrome', 'obesity familial', 'familial syndrome', 'obesity', 'familial', 'syndrome']
# ✅ Found 50693 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is obesity a familial syndrome?"
#
# ❓[35/85] Question: What proportion of the cells in GBM are typically macrophages/microglia?
# 🧠 Generated Queries: ['proportion cells gbm typically macrophages microglia', 'cells gbm typically macrophages microglia', 'gbm typically macrophages microglia', 'proportion cells gbm typically macrophages', 'cells gbm typically macrophages', 'typically macrophages microglia', 'gbm typically macrophages', 'macrophages microglia', 'proportion cells gbm typically', 'proportion cells gbm', 'cells gbm typically', 'microglia', 'cells gbm', 'typically macrophages', 'macrophages', 'proportion cells', 'gbm typically', 'cells', 'gbm', 'proportion']
# ✅ Found 76798 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What proportion of the cells in GBM are typically macrophages/microglia?"
#
# 📁 Saving batch at question 35...
# ✅ Batch saved and checkpoint updated at index 34
#
# ❓[36/85] Question: Describe Chimira
# 🧠 Generated Queries: ['chimira']
# ✅ Found 5 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 5 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Describe Chimira"
#
# ❓[37/85] Question: What is the mechanism of action of Talquetamab?
# 🧠 Generated Queries: ['mechanism action talquetamab', 'action talquetamab', 'talquetamab', 'mechanism', 'mechanism action', 'action']
# ✅ Found 25282 unique PMIDs for this question.
# 🎯 Found 6 out of 6 ground truth PMIDs.
# 📦 Fetching details for 156 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the mechanism of action of Talquetamab?"
#
# ❓[38/85] Question: What is the difference in action between fomoterol and salmeterol?
# 🧠 Generated Queries: ['action fomoterol salmeterol', 'fomoterol salmeterol', 'difference action fomoterol salmeterol', 'difference action fomoterol', 'action fomoterol', 'fomoterol', 'salmeterol', 'difference action', 'difference', 'action']
# ✅ Found 30679 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the difference in action between fomoterol and salmeterol?"
#
# ❓[39/85] Question: Is there any biomarker for borderline personality disorder?
# 🧠 Generated Queries: ['biomarker borderline personality disorder', 'biomarker borderline personality', 'borderline personality disorder', 'biomarker borderline', 'borderline personality', 'personality disorder', 'biomarker', 'disorder', 'borderline', 'personality']
# ✅ Found 54255 unique PMIDs for this question.
# 🎯 Found 8 out of 8 ground truth PMIDs.
# 📦 Fetching details for 158 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is there any biomarker for borderline personality disorder?"
#
# ❓[40/85] Question: What is the main function of plasmacytoid dendritic cells (pDCs)?
# 🧠 Generated Queries: ['main function plasmacytoid dendritic cells pdcs', 'function plasmacytoid dendritic cells pdcs', 'main function plasmacytoid dendritic cells', 'plasmacytoid dendritic cells pdcs', 'function plasmacytoid dendritic cells', 'main function plasmacytoid dendritic', 'function plasmacytoid dendritic', 'plasmacytoid dendritic cells', 'dendritic cells pdcs', 'plasmacytoid dendritic', 'dendritic cells', 'main function plasmacytoid', 'cells pdcs', 'function plasmacytoid', 'plasmacytoid', 'dendritic', 'cells', 'pdcs', 'main function', 'main']
# ✅ Found 53763 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the main function of plasmacytoid dendritic cells (pDCs)?"
#
# 📁 Saving batch at question 40...
# ✅ Batch saved and checkpoint updated at index 39
#
# ❓[41/85] Question: List primary sclerosing cholangitis effector genes and biological mechanisms
# 🧠 Generated Queries: ['list primary sclerosing cholangitis effector genes biological mechanisms', 'primary sclerosing cholangitis effector genes biological mechanisms', 'list primary sclerosing cholangitis effector genes biological', 'primary sclerosing cholangitis effector genes biological', 'sclerosing cholangitis effector genes biological mechanisms', 'list primary sclerosing cholangitis effector genes', 'primary sclerosing cholangitis effector genes', 'sclerosing cholangitis effector genes biological', 'sclerosing cholangitis effector genes', 'list primary sclerosing cholangitis effector', 'primary sclerosing cholangitis effector', 'cholangitis effector genes biological mechanisms', 'cholangitis effector genes biological', 'cholangitis effector genes', 'list primary sclerosing cholangitis', 'sclerosing cholangitis effector', 'primary sclerosing cholangitis', 'sclerosing cholangitis', 'cholangitis effector', 'cholangitis']
# ✅ Found 15184 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "List primary sclerosing cholangitis effector genes and biological mechanisms"
#
# ❓[42/85] Question: What are targets of Tirzepatide?
# 🧠 Generated Queries: ['targets tirzepatide', 'tirzepatide', 'targets']
# ✅ Found 10939 unique PMIDs for this question.
# 🎯 Found 6 out of 6 ground truth PMIDs.
# 📦 Fetching details for 156 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are targets of Tirzepatide?"
#
# ❓[43/85] Question: Have high values of blood pressure, body mass index (BMI), and non-high-density lipoprotein (HDL) cholesterol been associated with increased dementia risk in late life?
# 🧠 Generated Queries: ['density lipoprotein hdl cholesterol associated increased dementia risk late life', 'lipoprotein hdl cholesterol associated increased dementia risk late life', 'non high density lipoprotein hdl cholesterol associated increased dementia risk', 'bmi non high density lipoprotein hdl cholesterol associated increased dementia', 'cholesterol associated increased dementia risk', 'high density lipoprotein hdl cholesterol associated increased dementia risk', 'lipoprotein hdl cholesterol associated increased dementia risk', 'density lipoprotein hdl cholesterol associated increased dementia risk', 'cholesterol associated increased dementia risk late life', 'hdl cholesterol associated increased dementia risk late life', 'high density lipoprotein hdl cholesterol associated increased dementia risk late', 'non high density lipoprotein hdl cholesterol associated increased dementia', 'density lipoprotein hdl cholesterol associated increased dementia risk late', 'hdl cholesterol associated increased dementia risk', 'lipoprotein hdl cholesterol associated increased dementia risk late', 'high density lipoprotein hdl cholesterol associated increased dementia', 'density lipoprotein hdl cholesterol associated increased dementia', 'lipoprotein hdl cholesterol associated increased dementia', 'cholesterol associated increased dementia', 'hdl cholesterol associated increased dementia risk late']
# ✅ Found 1050 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Have high values of blood pressure, body mass index (BMI), and non-high-density lipoprotein (HDL) cholesterol been associated with increased dementia risk in late life?"
#
# ❓[44/85] Question: What are indications for autologous blood use?
# 🧠 Generated Queries: ['indications autologous blood use', 'indications autologous blood', 'autologous blood use', 'autologous blood', 'indications autologous', 'blood use', 'indications', 'autologous', 'blood', 'use']
# ✅ Found 47646 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are indications for autologous blood use?"
#
# ❓[45/85] Question: What are some commonly used markers to identify exhausted T cells?
# 🧠 Generated Queries: ['commonly used markers identify exhausted cells', 'used markers identify exhausted cells', 'markers identify exhausted cells', 'identify exhausted cells', 'commonly used markers identify exhausted', 'exhausted cells', 'markers identify exhausted', 'used markers identify exhausted', 'commonly used markers identify', 'identify exhausted', 'commonly used markers', 'cells', 'markers identify', 'markers', 'used markers identify', 'used markers', 'exhausted', 'commonly used', 'identify', 'commonly']
# ✅ Found 78634 unique PMIDs for this question.
# 🎯 Found 4 out of 6 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are some commonly used markers to identify exhausted T cells?"
#
# 📁 Saving batch at question 45...
# ✅ Batch saved and checkpoint updated at index 44
#
# ❓[46/85] Question: Which approaches are used for selecting the right target in kidney disease?
# 🧠 Generated Queries: ['approaches used selecting right target kidney disease', 'approaches used selecting right target kidney', 'selecting right target kidney disease', 'used selecting right target kidney disease', 'selecting right target kidney', 'used selecting right target kidney', 'target kidney disease', 'right target kidney disease', 'target kidney', 'right target kidney', 'approaches used selecting right target', 'kidney disease', 'approaches used selecting right', 'approaches used selecting', 'kidney', 'selecting right target', 'used selecting right target', 'approaches used', 'approaches', 'selecting right']
# ✅ Found 61375 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which approaches are used for selecting the right target in kidney disease?"
#
# ❓[47/85] Question: Which drugs are included in the epclusa pill?
# 🧠 Generated Queries: ['drugs included epclusa pill', 'drugs included epclusa', 'included epclusa pill', 'epclusa pill', 'included epclusa', 'epclusa', 'pill', 'drugs included', 'drugs', 'included']
# ✅ Found 39559 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Which drugs are included in the epclusa pill?"
#
# ❓[48/85] Question: What proteins are measured in a blood test for Alzheimers disease?
# 🧠 Generated Queries: ['proteins measured blood test alzheimers', 'proteins measured blood test alzheimers disease', 'blood test alzheimers disease', 'measured blood test alzheimers disease', 'blood test alzheimers', 'measured blood test alzheimers', 'test alzheimers disease', 'proteins measured blood test', 'test alzheimers', 'proteins measured blood', 'proteins measured', 'alzheimers disease', 'alzheimers', 'blood test', 'measured blood test', 'proteins', 'measured blood', 'test', 'blood', 'disease']
# ✅ Found 93223 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What proteins are measured in a blood test for Alzheimers disease?"
#
# ❓[49/85] Question: How many types of poliovirus vaccines are currently used?
# 🧠 Generated Queries: ['types poliovirus vaccines currently used', 'types poliovirus vaccines currently', 'types poliovirus vaccines', 'poliovirus vaccines currently used', 'poliovirus vaccines currently', 'poliovirus vaccines', 'types poliovirus', 'vaccines currently used', 'poliovirus', 'vaccines currently', 'vaccines', 'types', 'currently used', 'currently', 'used']
# ✅ Found 50861 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "How many types of poliovirus vaccines are currently used?"
#
# ❓[50/85] Question: What type of T cell memory subset is characterized by high CD45RO and CCR7 expression?
# 🧠 Generated Queries: ['type cell memory subset characterized high cd45ro ccr7 expression', 'cell memory subset characterized high cd45ro ccr7 expression', 'type cell memory subset characterized high cd45ro ccr7', 'cell memory subset characterized high cd45ro ccr7', 'memory subset characterized high cd45ro ccr7 expression', 'type cell memory subset characterized high cd45ro', 'cell memory subset characterized high cd45ro', 'memory subset characterized high cd45ro ccr7', 'subset characterized high cd45ro ccr7 expression', 'characterized high cd45ro ccr7 expression', 'subset characterized high cd45ro ccr7', 'type cell memory subset characterized high', 'cell memory subset characterized high', 'memory subset characterized high cd45ro', 'characterized high cd45ro ccr7', 'type cell memory subset characterized', 'high cd45ro ccr7 expression', 'type cell memory', 'cell memory subset characterized', 'type cell memory subset']
# ✅ Found 13298 unique PMIDs for this question.
# 🎯 Found 0 out of 4 ground truth PMIDs.
# 📦 Fetching details for 150 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What type of T cell memory subset is characterized by high CD45RO and CCR7 expression?"
#
# 📁 Saving batch at question 50...
# ✅ Batch saved and checkpoint updated at index 49
#
# ❓[51/85] Question: What is the mechanism of action of Xalnesiran?
# 🧠 Generated Queries: ['mechanism action xalnesiran', 'action xalnesiran', 'xalnesiran', 'mechanism action', 'mechanism', 'action']
# ✅ Found 25214 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the mechanism of action of Xalnesiran?"
#
# ❓[52/85] Question: What is Tenecteplase?
# 🧠 Generated Queries: ['tenecteplase']
# ✅ Found 1126 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is Tenecteplase?"
#
# ❓[53/85] Question: Is there any DNA vaccine approved for use in humans?
# 🧠 Generated Queries: ['dna vaccine approved use humans', 'dna vaccine approved use', 'dna vaccine approved', 'vaccine approved use humans', 'dna vaccine', 'vaccine approved use', 'vaccine approved', 'vaccine', 'approved use humans', 'dna', 'use humans', 'approved use', 'humans', 'approved', 'use']
# ✅ Found 65674 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is there any DNA vaccine approved for use in humans?"
#
# ❓[54/85] Question: What are the glioblastoma stem cell (GSC) states identified through chromatin accessibility profiling?
# 🧠 Generated Queries: ['glioblastoma stem cell gsc states identified chromatin accessibility profiling', 'glioblastoma stem cell gsc states identified chromatin accessibility', 'glioblastoma stem cell gsc states identified chromatin', 'stem cell gsc states identified chromatin accessibility profiling', 'glioblastoma stem cell gsc states identified', 'cell gsc states identified chromatin accessibility profiling', 'stem cell gsc states identified chromatin accessibility', 'gsc states identified chromatin accessibility profiling', 'cell gsc states identified chromatin accessibility', 'glioblastoma stem cell gsc states', 'gsc states identified chromatin accessibility', 'stem cell gsc states identified chromatin', 'states identified chromatin accessibility profiling', 'cell gsc states identified chromatin', 'glioblastoma stem cell gsc', 'gsc states identified chromatin', 'identified chromatin accessibility profiling', 'stem cell gsc states identified', 'states identified chromatin accessibility', 'chromatin accessibility profiling']
# ✅ Found 5016 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are the glioblastoma stem cell (GSC) states identified through chromatin accessibility profiling?"
#
# ❓[55/85] Question: What is the target of Zolbetuximab?
# 🧠 Generated Queries: ['target zolbetuximab', 'zolbetuximab', 'target']
# ✅ Found 10115 unique PMIDs for this question.
# 🎯 Found 5 out of 5 ground truth PMIDs.
# 📦 Fetching details for 155 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the target of Zolbetuximab?"
#
# 📁 Saving batch at question 55...
# ✅ Batch saved and checkpoint updated at index 54
#
# ❓[56/85] Question: Please list the active compounds that can be extracted from Sophora tonkinensis
# 🧠 Generated Queries: ['list active compounds extracted sophora tonkinensis', 'active compounds extracted sophora tonkinensis', 'compounds extracted sophora tonkinensis', 'list active compounds extracted sophora', 'active compounds extracted sophora', 'compounds extracted sophora', 'extracted sophora tonkinensis', 'sophora tonkinensis', 'extracted sophora', 'list active compounds extracted', 'compounds extracted', 'active compounds extracted', 'tonkinensis', 'list active compounds', 'compounds', 'sophora', 'active compounds', 'extracted', 'list', 'list active']
# ✅ Found 56305 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Please list the active compounds that can be extracted from Sophora tonkinensis"
#
# ❓[57/85] Question: What are the main causes of iatrogenic mortality?
# 🧠 Generated Queries: ['main causes iatrogenic mortality', 'causes iatrogenic mortality', 'iatrogenic mortality', 'main causes iatrogenic', 'causes iatrogenic', 'mortality', 'main causes', 'iatrogenic', 'causes', 'main']
# ✅ Found 54033 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are the main causes of iatrogenic mortality?"
#
# ❓[58/85] Question: What is a frequently lost chromosomal region in secondary glioblastoma?
# 🧠 Generated Queries: ['frequently lost chromosomal region secondary glioblastoma', 'lost chromosomal region secondary glioblastoma', 'chromosomal region secondary glioblastoma', 'region secondary glioblastoma', 'secondary glioblastoma', 'frequently lost chromosomal region secondary', 'frequently lost chromosomal region', 'lost chromosomal region secondary', 'chromosomal region secondary', 'lost chromosomal region', 'glioblastoma', 'chromosomal region', 'frequently lost chromosomal', 'lost chromosomal', 'chromosomal', 'region secondary', 'region', 'frequently lost', 'secondary', 'lost']
# ✅ Found 87897 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is a frequently lost chromosomal region in secondary glioblastoma?"
#
# ❓[59/85] Question: What is the mechanism of action of Nexiguran Ziclumeran?
# 🧠 Generated Queries: ['mechanism action nexiguran ziclumeran', 'action nexiguran ziclumeran', 'mechanism action nexiguran', 'nexiguran ziclumeran', 'action nexiguran', 'nexiguran', 'ziclumeran', 'mechanism', 'mechanism action', 'action']
# ✅ Found 25212 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the mechanism of action of Nexiguran Ziclumeran?"
#
# ❓[60/85] Question: Is suicide ideation associated with GLP-1 agonists?
# 🧠 Generated Queries: ['suicide ideation associated glp agonists', 'suicide ideation associated glp', 'ideation associated glp agonists', 'associated glp agonists', 'glp agonists', 'suicide ideation associated', 'ideation associated glp', 'suicide ideation', 'associated glp', 'glp', 'suicide', 'agonists', 'ideation associated', 'ideation', 'associated']
# ✅ Found 57266 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is suicide ideation associated with GLP-1 agonists?"
#
# 📁 Saving batch at question 60...
# ✅ Batch saved and checkpoint updated at index 59
#
# ❓[61/85] Question: Are physicians at higher risk of suicide than the general population?
# 🧠 Generated Queries: ['physicians higher risk suicide general population', 'physicians higher risk suicide', 'physicians higher risk suicide general', 'higher risk suicide general population', 'risk suicide general population', 'physicians higher risk', 'suicide general population', 'higher risk suicide', 'higher risk suicide general', 'risk suicide general', 'risk suicide', 'physicians higher', 'physicians', 'suicide general', 'suicide', 'general population', 'higher risk', 'population', 'risk', 'general']
# ✅ Found 95850 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Are physicians at higher risk of suicide than the general population?"
#
# ❓[62/85] Question: What chemokine is involved in recruiting myeloid-derived suppressor cells to GBM?
# 🧠 Generated Queries: ['chemokine involved recruiting myeloid derived suppressor cells gbm', 'involved recruiting myeloid derived suppressor cells gbm', 'recruiting myeloid derived suppressor cells gbm', 'chemokine involved recruiting myeloid derived suppressor cells', 'myeloid derived suppressor cells gbm', 'chemokine involved recruiting myeloid derived suppressor', 'involved recruiting myeloid derived suppressor cells', 'recruiting myeloid derived suppressor cells', 'chemokine involved recruiting myeloid derived', 'myeloid derived suppressor cells', 'derived suppressor cells gbm', 'suppressor cells gbm', 'myeloid derived suppressor', 'involved recruiting myeloid derived suppressor', 'chemokine involved recruiting myeloid', 'recruiting myeloid derived suppressor', 'derived suppressor cells', 'suppressor cells', 'cells gbm', 'involved recruiting myeloid derived']
# ✅ Found 30848 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What chemokine is involved in recruiting myeloid-derived suppressor cells to GBM?"
#
# ❓[63/85] Question: Is Infigratinib effective for Achondroplasia?
# 🧠 Generated Queries: ['infigratinib effective achondroplasia', 'effective achondroplasia', 'infigratinib effective', 'infigratinib', 'achondroplasia', 'effective']
# ✅ Found 13539 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is Infigratinib effective for Achondroplasia?"
#
# ❓[64/85] Question: What is anthropogenic gadolinium?
# 🧠 Generated Queries: ['anthropogenic gadolinium', 'gadolinium', 'anthropogenic']
# ✅ Found 20012 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is anthropogenic gadolinium?"
#
# ❓[65/85] Question: Causes of testicular torsion.
# 🧠 Generated Queries: ['causes testicular torsion', 'testicular torsion', 'causes testicular', 'testicular', 'torsion', 'causes']
# ✅ Found 38048 unique PMIDs for this question.
# 🎯 Found 7 out of 7 ground truth PMIDs.
# 📦 Fetching details for 157 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Causes of testicular torsion."
#
# 📁 Saving batch at question 65...
# ✅ Batch saved and checkpoint updated at index 64
#
# ❓[66/85] Question: Does neuroblastoma share mesenchymal-like transcriptional programs with triple-negative breast cancer (TNBC)?
# 🧠 Generated Queries: ['neuroblastoma share mesenchymal like transcriptional programs triple negative breast cancer', 'does neuroblastoma share mesenchymal like transcriptional programs triple negative breast', 'neuroblastoma share mesenchymal like transcriptional programs triple negative breast', 'does neuroblastoma share mesenchymal like transcriptional programs triple negative', 'does neuroblastoma share mesenchymal like transcriptional programs triple', 'neuroblastoma share mesenchymal like transcriptional programs triple negative', 'does neuroblastoma share mesenchymal like transcriptional programs', 'neuroblastoma share mesenchymal like transcriptional programs triple', 'neuroblastoma share mesenchymal like transcriptional programs', 'does neuroblastoma share mesenchymal like transcriptional', 'share mesenchymal like transcriptional programs triple negative breast cancer tnbc', 'neuroblastoma share mesenchymal like transcriptional', 'mesenchymal like transcriptional programs triple negative breast cancer tnbc', 'share mesenchymal like transcriptional programs triple negative breast cancer', 'mesenchymal like transcriptional programs triple negative breast cancer', 'does neuroblastoma share mesenchymal', 'does neuroblastoma share mesenchymal like', 'neuroblastoma share mesenchymal', 'neuroblastoma share mesenchymal like', 'share mesenchymal like transcriptional programs triple negative breast']
# ✅ Found 65 unique PMIDs for this question.
# 🎯 Found 1 out of 2 ground truth PMIDs.
# 📦 Fetching details for 65 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Does neuroblastoma share mesenchymal-like transcriptional programs with triple-negative breast cancer (TNBC)?"
#
# ❓[67/85] Question: Is perampanel associated with homicidal ideation?
# 🧠 Generated Queries: ['perampanel associated homicidal ideation', 'perampanel associated homicidal', 'perampanel associated', 'associated homicidal ideation', 'homicidal ideation', 'perampanel', 'associated homicidal', 'homicidal', 'ideation', 'associated']
# ✅ Found 32494 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Is perampanel associated with homicidal ideation?"
#
# ❓[68/85] Question: Please sumarize the symptoms of Ankylosing Spondylitis
# 🧠 Generated Queries: ['symptoms ankylosing spondylitis', 'sumarize symptoms ankylosing spondylitis', 'ankylosing spondylitis', 'spondylitis', 'symptoms ankylosing', 'sumarize symptoms ankylosing', 'symptoms', 'ankylosing', 'sumarize symptoms', 'sumarize']
# ✅ Found 29702 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Please sumarize the symptoms of Ankylosing Spondylitis"
#
# ❓[69/85] Question: Presentation of ADHD in girls.
# 🧠 Generated Queries: ['presentation adhd girls', 'adhd girls', 'adhd', 'presentation adhd', 'girls', 'presentation']
# ✅ Found 39526 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Presentation of ADHD in girls."
#
# ❓[70/85] Question: What is the term for when a structural rearrangement places an oncogene under the control of a foreign enhancer?
# 🧠 Generated Queries: ['term structural rearrangement places oncogene control foreign enhancer', 'term structural rearrangement places oncogene control foreign', 'structural rearrangement places oncogene control foreign enhancer', 'rearrangement places oncogene control foreign enhancer', 'structural rearrangement places oncogene control foreign', 'term structural rearrangement places oncogene control', 'rearrangement places oncogene control foreign', 'term structural rearrangement places oncogene', 'structural rearrangement places oncogene control', 'structural rearrangement places oncogene', 'places oncogene control foreign enhancer', 'rearrangement places oncogene control', 'oncogene control foreign enhancer', 'rearrangement places oncogene', 'term structural rearrangement', 'term structural rearrangement places', 'foreign enhancer', 'control foreign enhancer', 'structural rearrangement', 'oncogene control foreign']
# ✅ Found 21155 unique PMIDs for this question.
# 🎯 Found 1 out of 3 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the term for when a structural rearrangement places an oncogene under the control of a foreign enhancer?"
#
# 📁 Saving batch at question 70...
# ✅ Batch saved and checkpoint updated at index 69
#
# ❓[71/85] Question: What is the mechanism of action of Vutrisiran?
# 🧠 Generated Queries: ['mechanism action vutrisiran', 'action vutrisiran', 'vutrisiran', 'mechanism action', 'mechanism', 'action']
# ✅ Found 25276 unique PMIDs for this question.
# 🎯 Found 8 out of 8 ground truth PMIDs.
# 📦 Fetching details for 158 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the mechanism of action of Vutrisiran?"
#
# ❓[72/85] Question: What is a payload in the context of a drug?
# 🧠 Generated Queries: ['payload context drug', 'payload', 'payload context', 'context drug', 'drug', 'context']
# ✅ Found 37279 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is a payload in the context of a drug?"
#
# ❓[73/85] Question: Can schizophrenia be diagnosed after 50?
# 🧠 Generated Queries: ['schizophrenia diagnosed 50', 'schizophrenia diagnosed', 'schizophrenia', 'diagnosed 50', 'diagnosed', '50']
# ✅ Found 38910 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Can schizophrenia be diagnosed after 50?"
#
# ❓[74/85] Question: What is the purpose of tumor-treating fields (TTFields) in GBM therapy?
# 🧠 Generated Queries: ['purpose tumor treating fields ttfields gbm therapy', 'purpose tumor treating fields ttfields gbm', 'tumor treating fields ttfields gbm therapy', 'tumor treating fields ttfields gbm', 'purpose tumor treating fields ttfields', 'treating fields ttfields gbm therapy', 'fields ttfields gbm therapy', 'tumor treating fields ttfields', 'purpose tumor treating fields', 'ttfields gbm therapy', 'tumor treating fields', 'treating fields ttfields gbm', 'fields ttfields gbm', 'purpose tumor treating', 'ttfields gbm', 'gbm therapy', 'tumor treating', 'treating fields ttfields', 'purpose tumor', 'fields ttfields']
# ✅ Found 50460 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the purpose of tumor-treating fields (TTFields) in GBM therapy?"
#
# ❓[75/85] Question: What is the target of axatilimab?
# 🧠 Generated Queries: ['target axatilimab', 'axatilimab', 'target']
# ✅ Found 10014 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the target of axatilimab?"
#
# 📁 Saving batch at question 75...
# ✅ Batch saved and checkpoint updated at index 74
#
# ❓[76/85] Question: How are molecular polaritons made?
# 🧠 Generated Queries: ['molecular polaritons', 'polaritons', 'molecular']
# ✅ Found 15864 unique PMIDs for this question.
# 🎯 Found 1 out of 1 ground truth PMIDs.
# 📦 Fetching details for 151 PMIDs (GT + Random Sample)
# ✅ Saved result for question "How are molecular polaritons made?"
#
# ❓[77/85] Question: Has any single infectious agent been identified as the cause of irritable bowel syndrome?
# 🧠 Generated Queries: ['infectious agent identified cause irritable bowel syndrome', 'single infectious agent identified cause irritable bowel syndrome', 'infectious agent identified cause irritable bowel', 'single infectious agent identified cause irritable bowel', 'agent identified cause irritable bowel syndrome', 'identified cause irritable bowel', 'identified cause irritable bowel syndrome', 'infectious agent identified cause irritable', 'agent identified cause irritable bowel', 'irritable bowel syndrome', 'cause irritable bowel syndrome', 'single infectious agent identified cause irritable', 'cause irritable bowel', 'irritable bowel', 'identified cause irritable', 'bowel syndrome', 'agent identified cause irritable', 'infectious agent identified cause', 'single infectious agent identified cause', 'infectious agent identified']
# ✅ Found 36423 unique PMIDs for this question.
# 🎯 Found 8 out of 8 ground truth PMIDs.
# 📦 Fetching details for 158 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Has any single infectious agent been identified as the cause of irritable bowel syndrome?"
#
# ❓[78/85] Question: Where do infiltrating macrophages in GBM derive from?
# 🧠 Generated Queries: ['infiltrating macrophages gbm derive', 'infiltrating macrophages gbm', 'macrophages gbm derive', 'macrophages gbm', 'infiltrating macrophages', 'macrophages', 'gbm derive', 'gbm', 'infiltrating', 'derive']
# ✅ Found 48830 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Where do infiltrating macrophages in GBM derive from?"
#
# ❓[79/85] Question: What medications are included in the CAPIRI regimen?
# 🧠 Generated Queries: ['medications included capiri regimen', 'medications included capiri', 'included capiri regimen', 'capiri regimen', 'medications included', 'medications', 'included capiri', 'capiri', 'regimen', 'included']
# ✅ Found 30351 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What medications are included in the CAPIRI regimen?"
#
# ❓[80/85] Question: What are aptamers made of?
# 🧠 Generated Queries: ['aptamers']
# ✅ Found 9999 unique PMIDs for this question.
# 🎯 Found 3 out of 3 ground truth PMIDs.
# 📦 Fetching details for 153 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What are aptamers made of?"
#
# 📁 Saving batch at question 80...
# ✅ Batch saved and checkpoint updated at index 79
#
# ❓[81/85] Question: Can a mother positive for Hepatitis B breastfeed?
# 🧠 Generated Queries: ['mother positive hepatitis breastfeed', 'positive hepatitis breastfeed', 'hepatitis breastfeed', 'mother positive hepatitis', 'positive hepatitis', 'hepatitis', 'mother positive', 'breastfeed', 'positive', 'mother']
# ✅ Found 56458 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Can a mother positive for Hepatitis B breastfeed?"
#
# ❓[82/85] Question: How do tumors evade immune responses?
# 🧠 Generated Queries: ['tumors evade immune responses', 'tumors evade immune', 'tumors evade', 'immune responses', 'evade immune responses', 'immune', 'tumors', 'evade immune', 'evade', 'responses']
# ✅ Found 47187 unique PMIDs for this question.
# 🎯 Found 2 out of 2 ground truth PMIDs.
# 📦 Fetching details for 152 PMIDs (GT + Random Sample)
# ✅ Saved result for question "How do tumors evade immune responses?"
#
# ❓[83/85] Question: Lenacapavir is tested in which disease?
# 🧠 Generated Queries: ['lenacapavir tested disease', 'lenacapavir tested', 'lenacapavir', 'tested disease', 'disease', 'tested']
# ✅ Found 26000 unique PMIDs for this question.
# 🎯 Found 5 out of 5 ground truth PMIDs.
# 📦 Fetching details for 155 PMIDs (GT + Random Sample)
# ✅ Saved result for question "Lenacapavir is tested in which disease?"
#
# ❓[84/85] Question: is Anopheles the genus of a parasitic fly?
# 🧠 Generated Queries: ['anopheles genus parasitic fly', 'anopheles genus parasitic', 'anopheles genus', 'genus parasitic fly', 'anopheles', 'parasitic fly', 'genus parasitic', 'parasitic', 'genus', 'fly']
# ✅ Found 52738 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "is Anopheles the genus of a parasitic fly?"
#
# ❓[85/85] Question: What is the treatment for restless leg syndrome?
# 🧠 Generated Queries: ['treatment restless leg syndrome', 'treatment restless leg', 'restless leg syndrome', 'restless leg', 'treatment restless', 'leg syndrome', 'restless', 'treatment', 'leg', 'syndrome']
# ✅ Found 52137 unique PMIDs for this question.
# 🎯 Found 4 out of 4 ground truth PMIDs.
# 📦 Fetching details for 154 PMIDs (GT + Random Sample)
# ✅ Saved result for question "What is the treatment for restless leg syndrome?"
#
# 📁 Saving batch at question 85...
# ✅ Batch saved and checkpoint updated at index 84
